# %% [markdown]
# <a href="https://colab.research.google.com/github/Jahan08/Amber-tutorial/blob/main/Mtb_H37Rv_MIC_nM_MolDes_noDup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install chembl_webresource_client
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.8-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 KB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: easydict in /usr/local/lib/python3.8/dist-packages (from chembl_webresource_client) (1.10)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.8/dist-packages (from chembl_webresource_client) (2.25.1)
# Collecting requests-cache~=0.7.0
#   Downloading requests_cache-0.7.5-py3-none-any.whl (39 kB)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.8/dist-packages (from chembl_webresource_client) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.18.4->chembl_webresource_client) (4.0.0)
# Collecting itsdangerous>=2.0.1
#   Downloading itsdangerous-2.1.2-py3-none-any.whl (15 kB)
# Requirement already satisfied: pyyaml>=5.4 in /usr/local/lib/python3.8/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (6.0)
# Collecting url-normalize<2.0,>=1.4
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Collecting attrs<22.0,>=21.2
#   Downloading attrs-21.4.0-py2.py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 KB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from url-normalize<2.0,>=1.4->requests-cache~=0.7.0->chembl_webresource_client) (1.15.0)
# Installing collected packages: url-normalize, itsdangerous, attrs, requests-cache, chembl_webresource_client
#   Attempting uninstall: itsdangerous
#     Found existing installation: itsdangerous 1.1.0
#     Uninstalling itsdangerous-1.1.0:
#       Successfully uninstalled itsdangerous-1.1.0
#   Attempting uninstall: attrs
#     Found existing installation: attrs 22.2.0
#     Uninstalling attrs-22.2.0:
#       Successfully uninstalled attrs-22.2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# flask 1.1.4 requires itsdangerous<2.0,>=0.24, but you have itsdangerous 2.1.2 which is incompatible.
# Successfully installed attrs-21.4.0 chembl_webresource_client-0.10.8 itsdangerous-2.1.2 requests-cache-0.7.5 url-normalize-1.4.3

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# target serach for Mtb

# %%
target = new_client.target
target_query = target.search('mycobacterium tuberculosis')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#     cross_references                          organism  \
# 0                 []        Mycobacterium tuberculosis
# 1                 []  Mycobacterium tuberculosis H37Rv
# 2                 []  Mycobacterium tuberculosis H37Ra
# 3                 []                     Mycobacterium
# 4                 []        Mycobacterium tuberculosis
# ..               ...                               ...
# 117               []        Mycobacterium tuberculosis
# 118               []        Mycobacterium tuberculosis
# 119               []        Mycobacterium tuberculosis
# 120               []        Mycobacterium tuberculosis
# 121               []        Mycobacterium tuberculosis
#
#                                              pref_name  score  \
# 0                           Mycobacterium tuberculosis   27.0
# 1                     Mycobacterium tuberculosis H37Rv   24.0
# 2                     Mycobacterium tuberculosis H37Ra   24.0
# 3                                        Mycobacterium   13.0
# 4            PYRAZINAMIDASE/NICOTINAMIDAS PNCA (PZase)   13.0
# ..                                                 ...    ...
# 117                                       70S ribosome    7.0
# 118                                       ATP synthase    7.0
# 119                              Thioredoxin reductase    7.0
# 120  ATP-dependent Clp protease ATP-binding subunit...    7.0
# 121   1,4-dihydroxy-2-naphthoate octaprenyltransferase    7.0
#
#      species_group_flag target_chembl_id  \
# 0                 False        CHEMBL360
# 1                 False    CHEMBL2111188
# 2                 False    CHEMBL2366634
# 3                  True     CHEMBL614981
# 4                 False    CHEMBL1697663
# ..                  ...              ...
# 117               False    CHEMBL2363965
# 118               False    CHEMBL2364166
# 119               False    CHEMBL2390811
# 120               False    CHEMBL4630874
# 121               False    CHEMBL4879548
#
#                                      target_components  \
# 0                                                   []
# 1                                                   []
# 2                                                   []
# 3                                                   []
# 4    [{'accession': 'Q50575', 'component_descriptio...
# ..                                                 ...
# 117  [{'accession': 'P9WHE1', 'component_descriptio...
# 118  [{'accession': 'P9WPU9', 'component_descriptio...
# 119  [{'accession': 'P9WHH1', 'component_descriptio...
# 120  [{'accession': 'P9WPC9', 'component_descriptio...
# 121  [{'accession': 'P9WIP3', 'component_descriptio...
#
#                       target_type  tax_id
# 0                        ORGANISM    1773
# 1                        ORGANISM   83332
# 2                        ORGANISM  419947
# 3                        ORGANISM    1763
# 4                  SINGLE PROTEIN    1773
# ..                            ...     ...
# 117  PROTEIN NUCLEIC-ACID COMPLEX    1773
# 118               PROTEIN COMPLEX    1773
# 119                SINGLE PROTEIN    1773
# 120                SINGLE PROTEIN    1773
# 121                SINGLE PROTEIN    1773
#
# [122 rows x 9 columns]

# %% [markdown]
# selecting the target

# %%
selected_target = targets.target_chembl_id[1]
selected_target
# Out:
# 'CHEMBL2111188'

# %%
activity = new_client.activity
SEL = activity.filter(target_chembl_id=selected_target)
df = pd.DataFrame.from_dict(SEL)
df
# Out:
#       activity_comment  activity_id activity_properties assay_chembl_id  \
# 0                 None      2910524                  []   CHEMBL1045696
# 1                 None      2910525                  []   CHEMBL1045697
# 2                 None      2910526                  []   CHEMBL1045696
# 3                 None      2910527                  []   CHEMBL1045696
# 4                 None      2910528                  []   CHEMBL1045697
# ...                ...          ...                 ...             ...
# 23504             None     18244553                  []   CHEMBL4053106
# 23505             None     18244554                  []   CHEMBL4053106
# 23506             None     18244555                  []   CHEMBL4053106
# 23507             None     18244556                  []   CHEMBL4053106
# 23508             None     18244557                  []   CHEMBL4053106
#
#                                        assay_description assay_type  \
# 0      Antimycobacterial activity against Mycobacteri...          F
# 1      Antimycobacterial activity against Mycobacteri...          F
# 2      Antimycobacterial activity against Mycobacteri...          F
# 3      Antimycobacterial activity against Mycobacteri...          F
# 4      Antimycobacterial activity against Mycobacteri...          F
# ...                                                  ...        ...
# 23504  Selectivity ratio of MIC for Mycobacterium tub...          F
# 23505  Selectivity ratio of MIC for Mycobacterium tub...          F
# 23506  Selectivity ratio of MIC for Mycobacterium tub...          F
# 23507  Selectivity ratio of MIC for Mycobacterium tub...          F
# 23508  Selectivity ratio of MIC for Mycobacterium tub...          F
#
#       assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0                        None                   None  BAO_0002146
# 1                        None                   None  BAO_0002146
# 2                        None                   None  BAO_0002146
# 3                        None                   None  BAO_0002146
# 4                        None                   None  BAO_0002146
# ...                       ...                    ...          ...
# 23504                    None                   None  BAO_0002136
# 23505                    None                   None  BAO_0002136
# 23506                    None                   None  BAO_0002136
# 23507                    None                   None  BAO_0002136
# 23508                    None                   None  BAO_0002136
#
#         bao_format  ...                   target_organism  \
# 0      BAO_0000218  ...  Mycobacterium tuberculosis H37Rv
# 1      BAO_0000218  ...  Mycobacterium tuberculosis H37Rv
# 2      BAO_0000218  ...  Mycobacterium tuberculosis H37Rv
# 3      BAO_0000218  ...  Mycobacterium tuberculosis H37Rv
# 4      BAO_0000218  ...  Mycobacterium tuberculosis H37Rv
# ...            ...  ...                               ...
# 23504  BAO_0000019  ...  Mycobacterium tuberculosis H37Rv
# 23505  BAO_0000019  ...  Mycobacterium tuberculosis H37Rv
# 23506  BAO_0000019  ...  Mycobacterium tuberculosis H37Rv
# 23507  BAO_0000019  ...  Mycobacterium tuberculosis H37Rv
# 23508  BAO_0000019  ...  Mycobacterium tuberculosis H37Rv
#
#                        target_pref_name target_tax_id text_value  toid  \
# 0      Mycobacterium tuberculosis H37Rv         83332       None  None
# 1      Mycobacterium tuberculosis H37Rv         83332       None  None
# 2      Mycobacterium tuberculosis H37Rv         83332       None  None
# 3      Mycobacterium tuberculosis H37Rv         83332       None  None
# 4      Mycobacterium tuberculosis H37Rv         83332       None  None
# ...                                 ...           ...        ...   ...
# 23504  Mycobacterium tuberculosis H37Rv         83332       None  None
# 23505  Mycobacterium tuberculosis H37Rv         83332       None  None
# 23506  Mycobacterium tuberculosis H37Rv         83332       None  None
# 23507  Mycobacterium tuberculosis H37Rv         83332       None  None
# 23508  Mycobacterium tuberculosis H37Rv         83332       None  None
#
#                     type    units    uo_units upper_value value
# 0                    MIC  ug ml-1  UO_0000274        None   5.0
# 1                    MIC  ug ml-1  UO_0000274        None   5.0
# 2                    MIC  ug ml-1  UO_0000274        None   5.0
# 3                    MIC  ug ml-1  UO_0000274        None   5.0
# 4                    MIC  ug ml-1  UO_0000274        None   5.0
# ...                  ...      ...         ...         ...   ...
# 23504  Selectivity ratio     None        None        None   8.0
# 23505  Selectivity ratio     None        None        None   8.0
# 23506  Selectivity ratio     None        None        None   8.0
# 23507  Selectivity ratio     None        None        None   4.0
# 23508  Selectivity ratio     None        None        None   4.0
#
# [23509 rows x 45 columns]

# %% [markdown]
# Consider MIC as Bioactivity property

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="MIC")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#       activity_comment  activity_id activity_properties assay_chembl_id  \
# 0                 None      2910524                  []   CHEMBL1045696
# 1                 None      2910525                  []   CHEMBL1045697
# 2                 None      2910526                  []   CHEMBL1045696
# 3                 None      2910527                  []   CHEMBL1045696
# 4                 None      2910528                  []   CHEMBL1045697
# ...                ...          ...                 ...             ...
# 13365             None     16651095                  []   CHEMBL3830122
# 13366             None     16651096                  []   CHEMBL3830122
# 13367             None     16651097                  []   CHEMBL3830122
# 13368             None     16651098                  []   CHEMBL3830122
# 13369             None     16651099                  []   CHEMBL3830122
#
#                                        assay_description assay_type  \
# 0      Antimycobacterial activity against Mycobacteri...          F
# 1      Antimycobacterial activity against Mycobacteri...          F
# 2      Antimycobacterial activity against Mycobacteri...          F
# 3      Antimycobacterial activity against Mycobacteri...          F
# 4      Antimycobacterial activity against Mycobacteri...          F
# ...                                                  ...        ...
# 13365  Antimycobacterial activity against Mycobacteri...          F
# 13366  Antimycobacterial activity against Mycobacteri...          F
# 13367  Antimycobacterial activity against Mycobacteri...          F
# 13368  Antimycobacterial activity against Mycobacteri...          F
# 13369  Antimycobacterial activity against Mycobacteri...          F
#
#       assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0                        None                   None  BAO_0002146
# 1                        None                   None  BAO_0002146
# 2                        None                   None  BAO_0002146
# 3                        None                   None  BAO_0002146
# 4                        None                   None  BAO_0002146
# ...                       ...                    ...          ...
# 13365                    None                   None  BAO_0002146
# 13366                    None                   None  BAO_0002146
# 13367                    None                   None  BAO_0002146
# 13368                    None                   None  BAO_0002146
# 13369                    None                   None  BAO_0002146
#
#         bao_format  ...                   target_organism  \
# 0      BAO_0000218  ...  Mycobacterium tuberculosis H37Rv
# 1      BAO_0000218  ...  Mycobacterium tuberculosis H37Rv
# 2      BAO_0000218  ...  Mycobacterium tuberculosis H37Rv
# 3      BAO_0000218  ...  Mycobacterium tuberculosis H37Rv
# 4      BAO_0000218  ...  Mycobacterium tuberculosis H37Rv
# ...            ...  ...                               ...
# 13365  BAO_0000218  ...  Mycobacterium tuberculosis H37Rv
# 13366  BAO_0000218  ...  Mycobacterium tuberculosis H37Rv
# 13367  BAO_0000218  ...  Mycobacterium tuberculosis H37Rv
# 13368  BAO_0000218  ...  Mycobacterium tuberculosis H37Rv
# 13369  BAO_0000218  ...  Mycobacterium tuberculosis H37Rv
#
#                        target_pref_name target_tax_id text_value  toid type  \
# 0      Mycobacterium tuberculosis H37Rv         83332       None  None  MIC
# 1      Mycobacterium tuberculosis H37Rv         83332       None  None  MIC
# 2      Mycobacterium tuberculosis H37Rv         83332       None  None  MIC
# 3      Mycobacterium tuberculosis H37Rv         83332       None  None  MIC
# 4      Mycobacterium tuberculosis H37Rv         83332       None  None  MIC
# ...                                 ...           ...        ...   ...  ...
# 13365  Mycobacterium tuberculosis H37Rv         83332       None  None  MIC
# 13366  Mycobacterium tuberculosis H37Rv         83332       None  None  MIC
# 13367  Mycobacterium tuberculosis H37Rv         83332       None  None  MIC
# 13368  Mycobacterium tuberculosis H37Rv         83332       None  None  MIC
# 13369  Mycobacterium tuberculosis H37Rv         83332       None  None  MIC
#
#          units    uo_units upper_value value
# 0      ug ml-1  UO_0000274        None   5.0
# 1      ug ml-1  UO_0000274        None   5.0
# 2      ug ml-1  UO_0000274        None   5.0
# 3      ug ml-1  UO_0000274        None   5.0
# 4      ug ml-1  UO_0000274        None   5.0
# ...        ...         ...         ...   ...
# 13365  ug ml-1  UO_0000274        None  50.0
# 13366  ug ml-1  UO_0000274        None  6.25
# 13367  ug ml-1  UO_0000274        None  25.0
# 13368  ug ml-1  UO_0000274        None  25.0
# 13369  ug ml-1  UO_0000274        None  50.0
#
# [13370 rows x 45 columns]

# %%
# considering nM unit for MIC
df = df[(df['standard_units'] == 'nM')]
len(df)
# Out:
# 6543

# %%
df.standard_type.unique()
# Out:
# array(['MIC'], dtype=object)

# %%
df
# Out:
#       activity_comment  activity_id activity_properties assay_chembl_id  \
# 137               None      2923079                  []   CHEMBL1044039
# 138               None      2923080                  []   CHEMBL1044039
# 139               None      2923081                  []   CHEMBL1044039
# 140               None      2923082                  []   CHEMBL1044039
# 141               None      2923083                  []   CHEMBL1044039
# ...                ...          ...                 ...             ...
# 13331             None     16649305                  []   CHEMBL3830494
# 13332             None     16649306                  []   CHEMBL3830494
# 13333             None     16649307                  []   CHEMBL3830494
# 13334             None     16649308                  []   CHEMBL3830494
# 13335             None     16649309                  []   CHEMBL3830494
#
#                                        assay_description assay_type  \
# 137    Antimycobacterial activity against Mycobacteri...          F
# 138    Antimycobacterial activity against Mycobacteri...          F
# 139    Antimycobacterial activity against Mycobacteri...          F
# 140    Antimycobacterial activity against Mycobacteri...          F
# 141    Antimycobacterial activity against Mycobacteri...          F
# ...                                                  ...        ...
# 13331  Antibacterial activity against actively replic...          F
# 13332  Antibacterial activity against actively replic...          F
# 13333  Antibacterial activity against actively replic...          F
# 13334  Antibacterial activity against actively replic...          F
# 13335  Antibacterial activity against actively replic...          F
#
#       assay_variant_accession assay_variant_mutation bao_endpoint  \
# 137                      None                   None  BAO_0002146
# 138                      None                   None  BAO_0002146
# 139                      None                   None  BAO_0002146
# 140                      None                   None  BAO_0002146
# 141                      None                   None  BAO_0002146
# ...                       ...                    ...          ...
# 13331                    None                   None  BAO_0002146
# 13332                    None                   None  BAO_0002146
# 13333                    None                   None  BAO_0002146
# 13334                    None                   None  BAO_0002146
# 13335                    None                   None  BAO_0002146
#
#         bao_format  ...                   target_organism  \
# 137    BAO_0000218  ...  Mycobacterium tuberculosis H37Rv
# 138    BAO_0000218  ...  Mycobacterium tuberculosis H37Rv
# 139    BAO_0000218  ...  Mycobacterium tuberculosis H37Rv
# 140    BAO_0000218  ...  Mycobacterium tuberculosis H37Rv
# 141    BAO_0000218  ...  Mycobacterium tuberculosis H37Rv
# ...            ...  ...                               ...
# 13331  BAO_0000218  ...  Mycobacterium tuberculosis H37Rv
# 13332  BAO_0000218  ...  Mycobacterium tuberculosis H37Rv
# 13333  BAO_0000218  ...  Mycobacterium tuberculosis H37Rv
# 13334  BAO_0000218  ...  Mycobacterium tuberculosis H37Rv
# 13335  BAO_0000218  ...  Mycobacterium tuberculosis H37Rv
#
#                        target_pref_name target_tax_id text_value  toid type  \
# 137    Mycobacterium tuberculosis H37Rv         83332       None  None  MIC
# 138    Mycobacterium tuberculosis H37Rv         83332       None  None  MIC
# 139    Mycobacterium tuberculosis H37Rv         83332       None  None  MIC
# 140    Mycobacterium tuberculosis H37Rv         83332       None  None  MIC
# 141    Mycobacterium tuberculosis H37Rv         83332       None  None  MIC
# ...                                 ...           ...        ...   ...  ...
# 13331  Mycobacterium tuberculosis H37Rv         83332       None  None  MIC
# 13332  Mycobacterium tuberculosis H37Rv         83332       None  None  MIC
# 13333  Mycobacterium tuberculosis H37Rv         83332       None  None  MIC
# 13334  Mycobacterium tuberculosis H37Rv         83332       None  None  MIC
# 13335  Mycobacterium tuberculosis H37Rv         83332       None  None  MIC
#
#        units    uo_units upper_value value
# 137       uM  UO_0000065        None  84.0
# 138       uM  UO_0000065        None  24.0
# 139       uM  UO_0000065        None   3.6
# 140       uM  UO_0000065        None  16.6
# 141       uM  UO_0000065        None   3.1
# ...      ...         ...         ...   ...
# 13331     uM  UO_0000065        None  5.93
# 13332     uM  UO_0000065        None  0.72
# 13333     uM  UO_0000065        None  7.64
# 13334     uM  UO_0000065        None  0.15
# 13335     uM  UO_0000065        None  1.24
#
# [6543 rows x 45 columns]

# %%
df.to_csv('bioactivity_data_H37Rv_MIC_nM.csv', index=False)

# %% [markdown]
# handling the missing data

# %%
df = df[df.standard_value.notna()]
df = df[df.value.notna()]
df
# Out:
#       activity_comment  activity_id activity_properties assay_chembl_id  \
# 137               None      2923079                  []   CHEMBL1044039
# 138               None      2923080                  []   CHEMBL1044039
# 139               None      2923081                  []   CHEMBL1044039
# 140               None      2923082                  []   CHEMBL1044039
# 141               None      2923083                  []   CHEMBL1044039
# ...                ...          ...                 ...             ...
# 13331             None     16649305                  []   CHEMBL3830494
# 13332             None     16649306                  []   CHEMBL3830494
# 13333             None     16649307                  []   CHEMBL3830494
# 13334             None     16649308                  []   CHEMBL3830494
# 13335             None     16649309                  []   CHEMBL3830494
#
#                                        assay_description assay_type  \
# 137    Antimycobacterial activity against Mycobacteri...          F
# 138    Antimycobacterial activity against Mycobacteri...          F
# 139    Antimycobacterial activity against Mycobacteri...          F
# 140    Antimycobacterial activity against Mycobacteri...          F
# 141    Antimycobacterial activity against Mycobacteri...          F
# ...                                                  ...        ...
# 13331  Antibacterial activity against actively replic...          F
# 13332  Antibacterial activity against actively replic...          F
# 13333  Antibacterial activity against actively replic...          F
# 13334  Antibacterial activity against actively replic...          F
# 13335  Antibacterial activity against actively replic...          F
#
#       assay_variant_accession assay_variant_mutation bao_endpoint  \
# 137                      None                   None  BAO_0002146
# 138                      None                   None  BAO_0002146
# 139                      None                   None  BAO_0002146
# 140                      None                   None  BAO_0002146
# 141                      None                   None  BAO_0002146
# ...                       ...                    ...          ...
# 13331                    None                   None  BAO_0002146
# 13332                    None                   None  BAO_0002146
# 13333                    None                   None  BAO_0002146
# 13334                    None                   None  BAO_0002146
# 13335                    None                   None  BAO_0002146
#
#         bao_format  ...                   target_organism  \
# 137    BAO_0000218  ...  Mycobacterium tuberculosis H37Rv
# 138    BAO_0000218  ...  Mycobacterium tuberculosis H37Rv
# 139    BAO_0000218  ...  Mycobacterium tuberculosis H37Rv
# 140    BAO_0000218  ...  Mycobacterium tuberculosis H37Rv
# 141    BAO_0000218  ...  Mycobacterium tuberculosis H37Rv
# ...            ...  ...                               ...
# 13331  BAO_0000218  ...  Mycobacterium tuberculosis H37Rv
# 13332  BAO_0000218  ...  Mycobacterium tuberculosis H37Rv
# 13333  BAO_0000218  ...  Mycobacterium tuberculosis H37Rv
# 13334  BAO_0000218  ...  Mycobacterium tuberculosis H37Rv
# 13335  BAO_0000218  ...  Mycobacterium tuberculosis H37Rv
#
#                        target_pref_name target_tax_id text_value  toid type  \
# 137    Mycobacterium tuberculosis H37Rv         83332       None  None  MIC
# 138    Mycobacterium tuberculosis H37Rv         83332       None  None  MIC
# 139    Mycobacterium tuberculosis H37Rv         83332       None  None  MIC
# 140    Mycobacterium tuberculosis H37Rv         83332       None  None  MIC
# 141    Mycobacterium tuberculosis H37Rv         83332       None  None  MIC
# ...                                 ...           ...        ...   ...  ...
# 13331  Mycobacterium tuberculosis H37Rv         83332       None  None  MIC
# 13332  Mycobacterium tuberculosis H37Rv         83332       None  None  MIC
# 13333  Mycobacterium tuberculosis H37Rv         83332       None  None  MIC
# 13334  Mycobacterium tuberculosis H37Rv         83332       None  None  MIC
# 13335  Mycobacterium tuberculosis H37Rv         83332       None  None  MIC
#
#        units    uo_units upper_value value
# 137       uM  UO_0000065        None  84.0
# 138       uM  UO_0000065        None  24.0
# 139       uM  UO_0000065        None   3.6
# 140       uM  UO_0000065        None  16.6
# 141       uM  UO_0000065        None   3.1
# ...      ...         ...         ...   ...
# 13331     uM  UO_0000065        None  5.93
# 13332     uM  UO_0000065        None  0.72
# 13333     uM  UO_0000065        None  7.64
# 13334     uM  UO_0000065        None  0.15
# 13335     uM  UO_0000065        None  1.24
#
# [6543 rows x 45 columns]

# %%
df = df[df.canonical_smiles.notna()]
df
# Out:
#       activity_comment  activity_id activity_properties assay_chembl_id  \
# 137               None      2923079                  []   CHEMBL1044039
# 138               None      2923080                  []   CHEMBL1044039
# 139               None      2923081                  []   CHEMBL1044039
# 140               None      2923082                  []   CHEMBL1044039
# 141               None      2923083                  []   CHEMBL1044039
# ...                ...          ...                 ...             ...
# 13331             None     16649305                  []   CHEMBL3830494
# 13332             None     16649306                  []   CHEMBL3830494
# 13333             None     16649307                  []   CHEMBL3830494
# 13334             None     16649308                  []   CHEMBL3830494
# 13335             None     16649309                  []   CHEMBL3830494
#
#                                        assay_description assay_type  \
# 137    Antimycobacterial activity against Mycobacteri...          F
# 138    Antimycobacterial activity against Mycobacteri...          F
# 139    Antimycobacterial activity against Mycobacteri...          F
# 140    Antimycobacterial activity against Mycobacteri...          F
# 141    Antimycobacterial activity against Mycobacteri...          F
# ...                                                  ...        ...
# 13331  Antibacterial activity against actively replic...          F
# 13332  Antibacterial activity against actively replic...          F
# 13333  Antibacterial activity against actively replic...          F
# 13334  Antibacterial activity against actively replic...          F
# 13335  Antibacterial activity against actively replic...          F
#
#       assay_variant_accession assay_variant_mutation bao_endpoint  \
# 137                      None                   None  BAO_0002146
# 138                      None                   None  BAO_0002146
# 139                      None                   None  BAO_0002146
# 140                      None                   None  BAO_0002146
# 141                      None                   None  BAO_0002146
# ...                       ...                    ...          ...
# 13331                    None                   None  BAO_0002146
# 13332                    None                   None  BAO_0002146
# 13333                    None                   None  BAO_0002146
# 13334                    None                   None  BAO_0002146
# 13335                    None                   None  BAO_0002146
#
#         bao_format  ...                   target_organism  \
# 137    BAO_0000218  ...  Mycobacterium tuberculosis H37Rv
# 138    BAO_0000218  ...  Mycobacterium tuberculosis H37Rv
# 139    BAO_0000218  ...  Mycobacterium tuberculosis H37Rv
# 140    BAO_0000218  ...  Mycobacterium tuberculosis H37Rv
# 141    BAO_0000218  ...  Mycobacterium tuberculosis H37Rv
# ...            ...  ...                               ...
# 13331  BAO_0000218  ...  Mycobacterium tuberculosis H37Rv
# 13332  BAO_0000218  ...  Mycobacterium tuberculosis H37Rv
# 13333  BAO_0000218  ...  Mycobacterium tuberculosis H37Rv
# 13334  BAO_0000218  ...  Mycobacterium tuberculosis H37Rv
# 13335  BAO_0000218  ...  Mycobacterium tuberculosis H37Rv
#
#                        target_pref_name target_tax_id text_value  toid type  \
# 137    Mycobacterium tuberculosis H37Rv         83332       None  None  MIC
# 138    Mycobacterium tuberculosis H37Rv         83332       None  None  MIC
# 139    Mycobacterium tuberculosis H37Rv         83332       None  None  MIC
# 140    Mycobacterium tuberculosis H37Rv         83332       None  None  MIC
# 141    Mycobacterium tuberculosis H37Rv         83332       None  None  MIC
# ...                                 ...           ...        ...   ...  ...
# 13331  Mycobacterium tuberculosis H37Rv         83332       None  None  MIC
# 13332  Mycobacterium tuberculosis H37Rv         83332       None  None  MIC
# 13333  Mycobacterium tuberculosis H37Rv         83332       None  None  MIC
# 13334  Mycobacterium tuberculosis H37Rv         83332       None  None  MIC
# 13335  Mycobacterium tuberculosis H37Rv         83332       None  None  MIC
#
#        units    uo_units upper_value value
# 137       uM  UO_0000065        None  84.0
# 138       uM  UO_0000065        None  24.0
# 139       uM  UO_0000065        None   3.6
# 140       uM  UO_0000065        None  16.6
# 141       uM  UO_0000065        None   3.1
# ...      ...         ...         ...   ...
# 13331     uM  UO_0000065        None  5.93
# 13332     uM  UO_0000065        None  0.72
# 13333     uM  UO_0000065        None  7.64
# 13334     uM  UO_0000065        None  0.15
# 13335     uM  UO_0000065        None  1.24
#
# [6543 rows x 45 columns]

# %% [markdown]
# Define the activity
#
# <=1000 nM active
# rather inactive

# %%
fix = []

for i in df.standard_value:
    fix.append(float(i))

# %%
STATUS = []

for i in fix:
    if i <=1000:
        STATUS.append("Yes") #active
        
    #elif i >=10000:
        #STATUS.append("No") #inactive
        
    else:
        STATUS.append("No") #intermediate

# %%
df = df.drop('value', 1)
df['value'] = fix
df['Activity'] = STATUS
df.head(3)
# Out:
# <ipython-input-120-90299a80648f>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df = df.drop('value', 1)
#     activity_comment  activity_id activity_properties assay_chembl_id  \
# 137             None      2923079                  []   CHEMBL1044039
# 138             None      2923080                  []   CHEMBL1044039
# 139             None      2923081                  []   CHEMBL1044039
#
#                                      assay_description assay_type  \
# 137  Antimycobacterial activity against Mycobacteri...          F
# 138  Antimycobacterial activity against Mycobacteri...          F
# 139  Antimycobacterial activity against Mycobacteri...          F
#
#     assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 137                    None                   None  BAO_0002146  BAO_0000218
# 138                    None                   None  BAO_0002146  BAO_0000218
# 139                    None                   None  BAO_0002146  BAO_0000218
#
#      ...                  target_pref_name target_tax_id text_value  toid  \
# 137  ...  Mycobacterium tuberculosis H37Rv         83332       None  None
# 138  ...  Mycobacterium tuberculosis H37Rv         83332       None  None
# 139  ...  Mycobacterium tuberculosis H37Rv         83332       None  None
#
#     type units    uo_units upper_value    value Activity
# 137  MIC    uM  UO_0000065        None  84000.0       No
# 138  MIC    uM  UO_0000065        None  24000.0       No
# 139  MIC    uM  UO_0000065        None   3600.0       No
#
# [3 rows x 46 columns]

# %%
selection = ['molecule_chembl_id', 'canonical_smiles', 'type', 'value', 'standard_units', 'Activity']
df2 = df[selection]
df2
# Out:
#       molecule_chembl_id                                   canonical_smiles  \
# 137         CHEMBL312865                 CCCCCCCCCCCCCCC(CO)NC(=O)OC(C)(C)C
# 138          CHEMBL85287                               CCCCCCCCCCCCCCC(N)CO
# 139          CHEMBL86788                      CCCCCCCCCCCCCCC(N)COCc1ccccc1
# 140          CHEMBL92431                    CCCCCCCCCCCCCCC(COCc1ccccc1)NCC
# 141          CHEMBL87006                CCCCCCCCCCCCCCC(COCc1ccccc1)N(CC)CC
# ...                  ...                                                ...
# 13331      CHEMBL3828141  O=C(NN1C(C(=O)Nc2nc3ccccc3s2)CC1C(=O)Nc1nc2ccc...
# 13332           CHEMBL64                                    NNC(=O)c1ccncc1
# 13333        CHEMBL44884                       CC[C@@H](CO)NCCN[C@@H](CC)CO
# 13334       CHEMBL374478  CO[C@H]1/C=C/O[C@@]2(C)Oc3c(C)c(O)c4c(O)c(c(/C...
# 13335           CHEMBL32  COc1c(N2C[C@@H]3CCCN[C@@H]3C2)c(F)cc2c(=O)c(C(...
#
#       type    value standard_units Activity
# 137    MIC  84000.0             nM       No
# 138    MIC  24000.0             nM       No
# 139    MIC   3600.0             nM       No
# 140    MIC  16600.0             nM       No
# 141    MIC   3100.0             nM       No
# ...    ...      ...            ...      ...
# 13331  MIC   5930.0             nM       No
# 13332  MIC    720.0             nM      Yes
# 13333  MIC   7640.0             nM       No
# 13334  MIC    150.0             nM      Yes
# 13335  MIC   1240.0             nM       No
#
# [6543 rows x 6 columns]

# %%
df2.to_csv('bioactivity_preprocessed_data_Mtb_H37Rv_MIC_nM.csv', index=False)

# %%
# find the duplicate and unique molecule_chembl_id
import pandas as pd

df_dup = pd.concat(g for _, 
                    g in df.groupby("molecule_chembl_id") 
                      if len(g) > 1)
df_non = df.loc[~df.index.isin(df_dup.index)]

print (str(len(df_non)), 
       str(len(df_dup)), 
       str(len(df_dup)+len(df_non)))
# Out:
# 3610 2933 6543

# %%
len(df_non), len(df_non['molecule_chembl_id'].unique())
# Out:
# (3610, 3610)

# %%
df_dup
# Out:
#       activity_comment  activity_id activity_properties assay_chembl_id  \
# 10774             None     15160967                  []   CHEMBL3398745
# 10804             None     15160997                  []   CHEMBL3398746
# 11669             None     15703592                  []   CHEMBL3615875
# 1086              None      3093309                  []   CHEMBL1065148
# 1087              None      3093310                  []   CHEMBL1065149
# ...                ...          ...                 ...             ...
# 10013             None     15045537                  []   CHEMBL3365855
# 10025             None     15045614                  []   CHEMBL3365856
# 3839              None      6390070                  []   CHEMBL1840267
# 7549              None     13486700                  []   CHEMBL2438666
# 8035              None     13869981                  []   CHEMBL3100314
#
#                                        assay_description assay_type  \
# 10774  Antimycobacterial activity against Mycobacteri...          F
# 10804  Antimycobacterial activity against Mycobacteri...          F
# 11669  Antimycobacterial activity against Mycobacteri...          F
# 1086   Antitubercular activity against Mycobacterium ...          F
# 1087   Antitubercular activity against Mycobacterium ...          F
# ...                                                  ...        ...
# 10013  Antimycobacterial activity against Mycobacteri...          F
# 10025  Antimycobacterial activity against Mycobacteri...          F
# 3839   Antimycobacterial activity against Mycobacteri...          F
# 7549   Antitubercular activity against Mycobacterium ...          F
# 8035   Antimicrobial activity against Mycobacterium t...          F
#
#       assay_variant_accession assay_variant_mutation bao_endpoint  \
# 10774                    None                   None  BAO_0002146
# 10804                    None                   None  BAO_0002146
# 11669                    None                   None  BAO_0002146
# 1086                     None                   None  BAO_0002146
# 1087                     None                   None  BAO_0002146
# ...                       ...                    ...          ...
# 10013                    None                   None  BAO_0002146
# 10025                    None                   None  BAO_0002146
# 3839                     None                   None  BAO_0002146
# 7549                     None                   None  BAO_0002146
# 8035                     None                   None  BAO_0002146
#
#         bao_format  ...                  target_pref_name target_tax_id  \
# 10774  BAO_0000218  ...  Mycobacterium tuberculosis H37Rv         83332
# 10804  BAO_0000218  ...  Mycobacterium tuberculosis H37Rv         83332
# 11669  BAO_0000218  ...  Mycobacterium tuberculosis H37Rv         83332
# 1086   BAO_0000218  ...  Mycobacterium tuberculosis H37Rv         83332
# 1087   BAO_0000218  ...  Mycobacterium tuberculosis H37Rv         83332
# ...            ...  ...                               ...           ...
# 10013  BAO_0000218  ...  Mycobacterium tuberculosis H37Rv         83332
# 10025  BAO_0000218  ...  Mycobacterium tuberculosis H37Rv         83332
# 3839   BAO_0000218  ...  Mycobacterium tuberculosis H37Rv         83332
# 7549   BAO_0000218  ...  Mycobacterium tuberculosis H37Rv         83332
# 8035   BAO_0000218  ...  Mycobacterium tuberculosis H37Rv         83332
#
#       text_value  toid type units    uo_units upper_value     value Activity
# 10774       None  None  MIC    uM  UO_0000065        None    4000.0       No
# 10804       None  None  MIC    uM  UO_0000065        None    8000.0       No
# 11669       None  None  MIC    uM  UO_0000065        None    1600.0       No
# 1086        None  None  MIC    uM  UO_0000065        None    7400.0       No
# 1087        None  None  MIC    uM  UO_0000065        None   12800.0       No
# ...          ...   ...  ...   ...         ...         ...       ...      ...
# 10013       None  None  MIC    uM  UO_0000065        None   32000.0       No
# 10025       None  None  MIC    uM  UO_0000065        None  125000.0       No
# 3839        None  None  MIC    uM  UO_0000065        None   34500.0       No
# 7549        None  None  MIC    uM  UO_0000065        None   34500.0       No
# 8035        None  None  MIC    uM  UO_0000065        None   34500.0       No
#
# [2933 rows x 46 columns]

# %%
# mean and std of all duplicate
import numpy as np
import pandas as pd
from time import time

from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
import seaborn as sns
# %matplotlib inline

mean_std = df_dup.groupby(['molecule_chembl_id'], as_index=False).agg({'value':['mean', 'std']})
mean_std.head()
# Out:
#   molecule_chembl_id         value
#                               mean           std
# 0       CHEMBL100633   4533.333333   3233.161507
# 1      CHEMBL1163032  10100.000000   3818.376618
# 2         CHEMBL1169  62500.000000      0.000000
# 3      CHEMBL1215999   4750.000000   2333.452378
# 4      CHEMBL1223644  76855.000000  12805.703807

# %%
len(mean_std)
# Out:
# 1080

# %%
df_dup = df_dup.merge(mean_std, on='molecule_chembl_id', how='inner')
len(df_dup)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:9190: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   return merge(
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py:4150: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# 2933

# %%
#keep only SD less thab 2SD for duplicate chemblID

df_dup = df_dup[(df_dup[('value', 'std')] < 2)]
len(df_dup), len(df_dup['molecule_chembl_id'].unique())
# Out:
# (430, 203)

# %%
df_dup['select'] = (df_dup['value']- df_dup[('value', 'mean')]).abs()
#value_median = keep.groupby('chemblId')['value'].transform('median')

df_dup = df_dup.groupby(["molecule_chembl_id"]).apply(lambda x: x.sort_values(["select"], ascending = True)).reset_index(drop=True)
df_dup
# Out:
#     activity_comment  activity_id activity_properties assay_chembl_id  \
# 0               None      5098792                  []   CHEMBL1638277
# 1               None      5098805                  []   CHEMBL1638278
# 2               None     13883413                  []   CHEMBL3105933
# 3               None     13883442                  []   CHEMBL3105934
# 4               None     15045565                  []   CHEMBL3365855
# ..               ...          ...                 ...             ...
# 425             None      3093286                  []   CHEMBL1065148
# 426             None      3093287                  []   CHEMBL1065149
# 427             None      6390070                  []   CHEMBL1840267
# 428             None     13486700                  []   CHEMBL2438666
# 429             None     13869981                  []   CHEMBL3100314
#
#                                      assay_description assay_type  \
# 0    Antimycobacterial activity against Mycobacteri...          F
# 1    Antimycobacterial activity against Mycobacteri...          F
# 2    Antimycobacterial activity against Mycobacteri...          F
# 3    Antimycobacterial activity against Mycobacteri...          F
# 4    Antimycobacterial activity against Mycobacteri...          F
# ..                                                 ...        ...
# 425  Antitubercular activity against Mycobacterium ...          F
# 426  Antitubercular activity against Mycobacterium ...          F
# 427  Antimycobacterial activity against Mycobacteri...          F
# 428  Antitubercular activity against Mycobacterium ...          F
# 429  Antimicrobial activity against Mycobacterium t...          F
#
#     assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                      None                   None  BAO_0002146  BAO_0000218
# 1                      None                   None  BAO_0002146  BAO_0000218
# 2                      None                   None  BAO_0002146  BAO_0000218
# 3                      None                   None  BAO_0002146  BAO_0000218
# 4                      None                   None  BAO_0002146  BAO_0000218
# ..                      ...                    ...          ...          ...
# 425                    None                   None  BAO_0002146  BAO_0000218
# 426                    None                   None  BAO_0002146  BAO_0000218
# 427                    None                   None  BAO_0002146  BAO_0000218
# 428                    None                   None  BAO_0002146  BAO_0000218
# 429                    None                   None  BAO_0002146  BAO_0000218
#
#      ...  toid type   units    uo_units upper_value     value  Activity  \
# 0    ...  None  MIC  umol/L  UO_0000065        None   62500.0        No
# 1    ...  None  MIC  umol/L  UO_0000065        None   62500.0        No
# 2    ...  None  MIC  umol/L  UO_0000065        None   62500.0        No
# 3    ...  None  MIC  umol/L  UO_0000065        None   62500.0        No
# 4    ...  None  MIC      uM  UO_0000065        None   62500.0        No
# ..   ...   ...  ...     ...         ...         ...       ...       ...
# 425  ...  None  MIC      uM  UO_0000065        None  128000.0        No
# 426  ...  None  MIC      uM  UO_0000065        None  128000.0        No
# 427  ...  None  MIC      uM  UO_0000065        None   34500.0        No
# 428  ...  None  MIC      uM  UO_0000065        None   34500.0        No
# 429  ...  None  MIC      uM  UO_0000065        None   34500.0        No
#
#     (value, mean) (value, std) select
# 0         62500.0          0.0    0.0
# 1         62500.0          0.0    0.0
# 2         62500.0          0.0    0.0
# 3         62500.0          0.0    0.0
# 4         62500.0          0.0    0.0
# ..            ...          ...    ...
# 425      128000.0          0.0    0.0
# 426      128000.0          0.0    0.0
# 427       34500.0          0.0    0.0
# 428       34500.0          0.0    0.0
# 429       34500.0          0.0    0.0
#
# [430 rows x 49 columns]

# %%
df_dup = df_dup.drop_duplicates(subset='molecule_chembl_id', keep='first')
df_dup
# Out:
#     activity_comment  activity_id activity_properties assay_chembl_id  \
# 0               None      5098792                  []   CHEMBL1638277
# 8               None     15125259                  []   CHEMBL3390432
# 11              None      5098782                  []   CHEMBL1638277
# 13              None      5098783                  []   CHEMBL1638277
# 15              None      5098784                  []   CHEMBL1638277
# ..               ...          ...                 ...             ...
# 419             None      3093280                  []   CHEMBL1065148
# 421             None      3093274                  []   CHEMBL1065148
# 423             None      3093277                  []   CHEMBL1065148
# 425             None      3093286                  []   CHEMBL1065148
# 427             None      6390070                  []   CHEMBL1840267
#
#                                      assay_description assay_type  \
# 0    Antimycobacterial activity against Mycobacteri...          F
# 8    Antimicrobial activity against Mycobacterium t...          F
# 11   Antimycobacterial activity against Mycobacteri...          F
# 13   Antimycobacterial activity against Mycobacteri...          F
# 15   Antimycobacterial activity against Mycobacteri...          F
# ..                                                 ...        ...
# 419  Antitubercular activity against Mycobacterium ...          F
# 421  Antitubercular activity against Mycobacterium ...          F
# 423  Antitubercular activity against Mycobacterium ...          F
# 425  Antitubercular activity against Mycobacterium ...          F
# 427  Antimycobacterial activity against Mycobacteri...          F
#
#     assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                      None                   None  BAO_0002146  BAO_0000218
# 8                      None                   None  BAO_0002146  BAO_0000218
# 11                     None                   None  BAO_0002146  BAO_0000218
# 13                     None                   None  BAO_0002146  BAO_0000218
# 15                     None                   None  BAO_0002146  BAO_0000218
# ..                      ...                    ...          ...          ...
# 419                    None                   None  BAO_0002146  BAO_0000218
# 421                    None                   None  BAO_0002146  BAO_0000218
# 423                    None                   None  BAO_0002146  BAO_0000218
# 425                    None                   None  BAO_0002146  BAO_0000218
# 427                    None                   None  BAO_0002146  BAO_0000218
#
#      ...  toid type   units    uo_units upper_value     value  Activity  \
# 0    ...  None  MIC  umol/L  UO_0000065        None   62500.0        No
# 8    ...  None  MIC      uM  UO_0000065        None   22950.0        No
# 11   ...  None  MIC  umol/L  UO_0000065        None    4000.0        No
# 13   ...  None  MIC  umol/L  UO_0000065        None    4000.0        No
# 15   ...  None  MIC  umol/L  UO_0000065        None    2000.0        No
# ..   ...   ...  ...     ...         ...         ...       ...       ...
# 419  ...  None  MIC      uM  UO_0000065        None  128000.0        No
# 421  ...  None  MIC      uM  UO_0000065        None  128000.0        No
# 423  ...  None  MIC      uM  UO_0000065        None  128000.0        No
# 425  ...  None  MIC      uM  UO_0000065        None  128000.0        No
# 427  ...  None  MIC      uM  UO_0000065        None   34500.0        No
#
#     (value, mean) (value, std) select
# 0         62500.0          0.0    0.0
# 8         22950.0          0.0    0.0
# 11         4000.0          0.0    0.0
# 13         4000.0          0.0    0.0
# 15         2000.0          0.0    0.0
# ..            ...          ...    ...
# 419      128000.0          0.0    0.0
# 421      128000.0          0.0    0.0
# 423      128000.0          0.0    0.0
# 425      128000.0          0.0    0.0
# 427       34500.0          0.0    0.0
#
# [203 rows x 49 columns]

# %%
len(df_dup), len(df_dup['molecule_chembl_id'].unique())
# Out:
# (203, 203)

# %%
df_dup = df_dup.drop('select', 1)
df_dup = df_dup.drop(('value', 'mean'), 1)
df_dup = df_dup.drop(('value', 'std'), 1)
# Out:
# <ipython-input-134-aca2d7831475>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df_dup = df_dup.drop('select', 1)
# <ipython-input-134-aca2d7831475>:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df_dup = df_dup.drop(('value', 'mean'), 1)
# <ipython-input-134-aca2d7831475>:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df_dup = df_dup.drop(('value', 'std'), 1)

# %%
df_final = pd.concat([df_non, df_dup])
len(df_dup), len(df_non), len(df_final)
# Out:
# (203, 3610, 3813)

# %%
df_final
# Out:
#     activity_comment  activity_id activity_properties assay_chembl_id  \
# 137             None      2923079                  []   CHEMBL1044039
# 138             None      2923080                  []   CHEMBL1044039
# 139             None      2923081                  []   CHEMBL1044039
# 140             None      2923082                  []   CHEMBL1044039
# 141             None      2923083                  []   CHEMBL1044039
# ..               ...          ...                 ...             ...
# 419             None      3093280                  []   CHEMBL1065148
# 421             None      3093274                  []   CHEMBL1065148
# 423             None      3093277                  []   CHEMBL1065148
# 425             None      3093286                  []   CHEMBL1065148
# 427             None      6390070                  []   CHEMBL1840267
#
#                                      assay_description assay_type  \
# 137  Antimycobacterial activity against Mycobacteri...          F
# 138  Antimycobacterial activity against Mycobacteri...          F
# 139  Antimycobacterial activity against Mycobacteri...          F
# 140  Antimycobacterial activity against Mycobacteri...          F
# 141  Antimycobacterial activity against Mycobacteri...          F
# ..                                                 ...        ...
# 419  Antitubercular activity against Mycobacterium ...          F
# 421  Antitubercular activity against Mycobacterium ...          F
# 423  Antitubercular activity against Mycobacterium ...          F
# 425  Antitubercular activity against Mycobacterium ...          F
# 427  Antimycobacterial activity against Mycobacteri...          F
#
#     assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 137                    None                   None  BAO_0002146  BAO_0000218
# 138                    None                   None  BAO_0002146  BAO_0000218
# 139                    None                   None  BAO_0002146  BAO_0000218
# 140                    None                   None  BAO_0002146  BAO_0000218
# 141                    None                   None  BAO_0002146  BAO_0000218
# ..                      ...                    ...          ...          ...
# 419                    None                   None  BAO_0002146  BAO_0000218
# 421                    None                   None  BAO_0002146  BAO_0000218
# 423                    None                   None  BAO_0002146  BAO_0000218
# 425                    None                   None  BAO_0002146  BAO_0000218
# 427                    None                   None  BAO_0002146  BAO_0000218
#
#      ...                  target_pref_name target_tax_id text_value  toid  \
# 137  ...  Mycobacterium tuberculosis H37Rv         83332       None  None
# 138  ...  Mycobacterium tuberculosis H37Rv         83332       None  None
# 139  ...  Mycobacterium tuberculosis H37Rv         83332       None  None
# 140  ...  Mycobacterium tuberculosis H37Rv         83332       None  None
# 141  ...  Mycobacterium tuberculosis H37Rv         83332       None  None
# ..   ...                               ...           ...        ...   ...
# 419  ...  Mycobacterium tuberculosis H37Rv         83332       None  None
# 421  ...  Mycobacterium tuberculosis H37Rv         83332       None  None
# 423  ...  Mycobacterium tuberculosis H37Rv         83332       None  None
# 425  ...  Mycobacterium tuberculosis H37Rv         83332       None  None
# 427  ...  Mycobacterium tuberculosis H37Rv         83332       None  None
#
#     type units    uo_units upper_value     value Activity
# 137  MIC    uM  UO_0000065        None   84000.0       No
# 138  MIC    uM  UO_0000065        None   24000.0       No
# 139  MIC    uM  UO_0000065        None    3600.0       No
# 140  MIC    uM  UO_0000065        None   16600.0       No
# 141  MIC    uM  UO_0000065        None    3100.0       No
# ..   ...   ...         ...         ...       ...      ...
# 419  MIC    uM  UO_0000065        None  128000.0       No
# 421  MIC    uM  UO_0000065        None  128000.0       No
# 423  MIC    uM  UO_0000065        None  128000.0       No
# 425  MIC    uM  UO_0000065        None  128000.0       No
# 427  MIC    uM  UO_0000065        None   34500.0       No
#
# [3813 rows x 46 columns]

# %%
df_final.to_csv('bioactivity_preprocessed_data_Mtb_H37Rv_nodup_MIC_nM.csv', index=False)

# %%
selection = ['molecule_chembl_id', 'canonical_smiles', 'value', 'Activity']
df3 = df_final[selection]
df3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 137       CHEMBL312865                 CCCCCCCCCCCCCCC(CO)NC(=O)OC(C)(C)C
# 138        CHEMBL85287                               CCCCCCCCCCCCCCC(N)CO
# 139        CHEMBL86788                      CCCCCCCCCCCCCCC(N)COCc1ccccc1
# 140        CHEMBL92431                    CCCCCCCCCCCCCCC(COCc1ccccc1)NCC
# 141        CHEMBL87006                CCCCCCCCCCCCCCC(COCc1ccccc1)N(CC)CC
# ..                 ...                                                ...
# 419       CHEMBL591045  O=C(c1cc(COc2cc(C(F)(F)F)nc3c(C(F)(F)F)cccc23)...
# 421       CHEMBL600051  NC(=O)c1cc(COc2cc(C(F)(F)F)nc3c(C(F)(F)F)cccc2...
# 423       CHEMBL600062  CCN(CC)C(=O)c1cc(COc2cc(C(F)(F)F)nc3c(C(F)(F)F...
# 425       CHEMBL607978    OCc1cc(COc2cc(C(F)(F)F)nc3c(C(F)(F)F)cccc23)on1
# 427          CHEMBL849                       Oc1cc(Cl)ccc1Oc1ccc(Cl)cc1Cl
#
#         value Activity
# 137   84000.0       No
# 138   24000.0       No
# 139    3600.0       No
# 140   16600.0       No
# 141    3100.0       No
# ..        ...      ...
# 419  128000.0       No
# 421  128000.0       No
# 423  128000.0       No
# 425  128000.0       No
# 427   34500.0       No
#
# [3813 rows x 4 columns]

# %%
! wget https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
! chmod +x Miniconda3-py37_4.8.2-Linux-x86_64.sh
! bash ./Miniconda3-py37_4.8.2-Linux-x86_64.sh -b -f -p /usr/local
! conda install -c rdkit rdkit -y
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')
# Out:
# --2023-02-01 17:28:57--  https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.131.3, 104.16.130.3, 2606:4700::6810:8303, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.131.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85055499 (81M) [application/x-sh]
# Saving to: ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh’
#
# Miniconda3-py37_4.8 100%[===================>]  81.12M   167MB/s    in 0.5s
#
# 2023-02-01 17:28:57 (167 MB/s) - ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh’ saved [85055499/85055499]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - asn1crypto==1.3.0=py37_0
#     - ca-certificates==2020.1.1=0
#     - certifi==2019.11.28=py37_0
#     - cffi==1.14.0=py37h2e261b9_0
#     - chardet==3.0.4=py37_1003
#     - conda-package-handling==1.6.0=py37h7b6447c_0
#     - conda==4.8.2=py37_0
#     - cryptography==2.8=py37h1ba5d50_0
#     - idna==2.8=py37_0
#     - ld_impl_linux-64==2.33.1=h53a641e_7
#     - libedit==3.1.20181209=hc058e9b_0
#     - libffi==3.2.1=hd88cf55_4
#     - libgcc-ng==9.1.0=hdf63c60_0
#     - libstdcxx-ng==9.1.0=hdf63c60_0
#     - ncurses==6.2=he6710b0_0
#     - openssl==1.1.1d=h7b6447c_4
#     - pip==20.0.2=py37_1
#     - pycosat==0.6.3=py37h7b6447c_0
#     - pycparser==2.19=py37_0
#     - pyopenssl==19.1.0=py37_0
#     - pysocks==1.7.1=py37_0
#     - python==3.7.6=h0371630_2
#     - readline==7.0=h7b6447c_5
#     - requests==2.22.0=py37_1
#     - ruamel_yaml==0.15.87=py37h7b6447c_0
#     - setuptools==45.2.0=py37_0
#     - six==1.14.0=py37_0
#     - sqlite==3.31.1=h7b6447c_0
#     - tk==8.6.8=hbc83047_0
#     - tqdm==4.42.1=py_0
#     - urllib3==1.25.8=py37_0
#     - wheel==0.34.2=py37_0
#     - xz==5.2.4=h14c3975_4
#     - yaml==0.1.7=had09818_2
#     - zlib==1.2.11=h7b6447c_3
#
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
#   asn1crypto         pkgs/main/linux-64::asn1crypto-1.3.0-py37_0
#   ca-certificates    pkgs/main/linux-64::ca-certificates-2020.1.1-0
#   certifi            pkgs/main/linux-64::certifi-2019.11.28-py37_0
#   cffi               pkgs/main/linux-64::cffi-1.14.0-py37h2e261b9_0
#   chardet            pkgs/main/linux-64::chardet-3.0.4-py37_1003
#   conda              pkgs/main/linux-64::conda-4.8.2-py37_0
#   conda-package-han~ pkgs/main/linux-64::conda-package-handling-1.6.0-py37h7b6447c_0
#   cryptography       pkgs/main/linux-64::cryptography-2.8-py37h1ba5d50_0
#   idna               pkgs/main/linux-64::idna-2.8-py37_0
#   ld_impl_linux-64   pkgs/main/linux-64::ld_impl_linux-64-2.33.1-h53a641e_7
#   libedit            pkgs/main/linux-64::libedit-3.1.20181209-hc058e9b_0
#   libffi             pkgs/main/linux-64::libffi-3.2.1-hd88cf55_4
#   libgcc-ng          pkgs/main/linux-64::libgcc-ng-9.1.0-hdf63c60_0
#   libstdcxx-ng       pkgs/main/linux-64::libstdcxx-ng-9.1.0-hdf63c60_0
#   ncurses            pkgs/main/linux-64::ncurses-6.2-he6710b0_0
#   openssl            pkgs/main/linux-64::openssl-1.1.1d-h7b6447c_4
#   pip                pkgs/main/linux-64::pip-20.0.2-py37_1
#   pycosat            pkgs/main/linux-64::pycosat-0.6.3-py37h7b6447c_0
#   pycparser          pkgs/main/linux-64::pycparser-2.19-py37_0
#   pyopenssl          pkgs/main/linux-64::pyopenssl-19.1.0-py37_0
#   pysocks            pkgs/main/linux-64::pysocks-1.7.1-py37_0
#   python             pkgs/main/linux-64::python-3.7.6-h0371630_2
#   readline           pkgs/main/linux-64::readline-7.0-h7b6447c_5
#   requests           pkgs/main/linux-64::requests-2.22.0-py37_1
#   ruamel_yaml        pkgs/main/linux-64::ruamel_yaml-0.15.87-py37h7b6447c_0
#   setuptools         pkgs/main/linux-64::setuptools-45.2.0-py37_0
#   six                pkgs/main/linux-64::six-1.14.0-py37_0
#   sqlite             pkgs/main/linux-64::sqlite-3.31.1-h7b6447c_0
#   tk                 pkgs/main/linux-64::tk-8.6.8-hbc83047_0
#   tqdm               pkgs/main/noarch::tqdm-4.42.1-py_0
#   urllib3            pkgs/main/linux-64::urllib3-1.25.8-py37_0
#   wheel              pkgs/main/linux-64::wheel-0.34.2-py37_0
#   xz                 pkgs/main/linux-64::xz-5.2.4-h14c3975_4
#   yaml               pkgs/main/linux-64::yaml-0.1.7-had09818_2
#   zlib               pkgs/main/linux-64::zlib-1.2.11-h7b6447c_3
#
#
# done
# done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - rdkit
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-5.1          |            1_gnu          21 KB
#     blas-1.0                   |              mkl           6 KB
#     bottleneck-1.3.5           |   py37h7deecbd_0         115 KB
#     bzip2-1.0.8                |       h7b6447c_0          78 KB
#     ca-certificates-2023.01.10 |       h06a4308_0         120 KB
#     cairo-1.16.0               |       hb05425b_3         1.2 MB
#     certifi-2022.12.7          |   py37h06a4308_0         150 KB
#     conda-23.1.0               |   py37h06a4308_0         937 KB
#     expat-2.4.9                |       h6a678d5_0         156 KB
#     flit-core-3.6.0            |     pyhd3eb1b0_0          42 KB
#     fontconfig-2.14.1          |       h52c9d5c_1         281 KB
#     freetype-2.12.1            |       h4a9f257_0         626 KB
#     giflib-5.2.1               |       h5eee18b_1          75 KB
#     glib-2.69.1                |       he621ea3_2         1.9 MB
#     icu-58.2                   |       he6710b0_3        10.5 MB
#     importlib-metadata-4.11.3  |   py37h06a4308_0          40 KB
#     importlib_metadata-4.11.3  |       hd3eb1b0_0          12 KB
#     intel-openmp-2021.4.0      |    h06a4308_3561         4.2 MB
#     jpeg-9e                    |       h7f8727e_0         240 KB
#     lcms2-2.12                 |       h3be6417_0         312 KB
#     lerc-3.0                   |       h295c915_0         196 KB
#     libboost-1.73.0            |      h28710b8_12        13.8 MB
#     libdeflate-1.8             |       h7f8727e_5          51 KB
#     libffi-3.4.2               |       h6a678d5_6         136 KB
#     libgcc-ng-11.2.0           |       h1234567_1         5.3 MB
#     libgomp-11.2.0             |       h1234567_1         474 KB
#     libpng-1.6.37              |       hbc83047_0         278 KB
#     libstdcxx-ng-11.2.0        |       h1234567_1         4.7 MB
#     libtiff-4.5.0              |       hecacb30_0         528 KB
#     libuuid-1.41.5             |       h5eee18b_0          27 KB
#     libwebp-1.2.4              |       h11a3e52_0          79 KB
#     libwebp-base-1.2.4         |       h5eee18b_0         347 KB
#     libxcb-1.15                |       h7f8727e_0         505 KB
#     libxml2-2.9.14             |       h74e7548_0         718 KB
#     lz4-c-1.9.4                |       h6a678d5_0         154 KB
#     mkl-2021.4.0               |     h06a4308_640       142.6 MB
#     mkl-service-2.4.0          |   py37h7f8727e_0          56 KB
#     mkl_fft-1.3.1              |   py37hd3c417c_0         172 KB
#     mkl_random-1.2.2           |   py37h51133e4_0         287 KB
#     numexpr-2.8.4              |   py37he184ba9_0         133 KB
#     numpy-1.21.5               |   py37h6c91a56_3          10 KB
#     numpy-base-1.21.5          |   py37ha15fc14_3         4.8 MB
#     openssl-1.1.1s             |       h7f8727e_0         3.6 MB
#     packaging-22.0             |   py37h06a4308_0          68 KB
#     pandas-1.3.5               |   py37h8c16a72_0         9.3 MB
#     pcre-8.45                  |       h295c915_0         207 KB
#     pillow-9.3.0               |   py37hace64e9_1         719 KB
#     pixman-0.40.0              |       h7f8727e_1         373 KB
#     pluggy-1.0.0               |   py37h06a4308_1          29 KB
#     py-boost-1.73.0            |  py37h51133e4_12         195 KB
#     python-dateutil-2.8.2      |     pyhd3eb1b0_0         233 KB
#     pytz-2022.7                |   py37h06a4308_0         207 KB
#     rdkit-2020.09.1.0          |   py37hd50e099_1        25.8 MB  rdkit
#     ruamel.yaml-0.17.21        |   py37h5eee18b_0         177 KB
#     ruamel.yaml.clib-0.2.6     |   py37h5eee18b_1         140 KB
#     toolz-0.12.0               |   py37h06a4308_0         104 KB
#     typing_extensions-4.4.0    |   py37h06a4308_0          45 KB
#     xz-5.2.10                  |       h5eee18b_1         429 KB
#     zipp-3.11.0                |   py37h06a4308_0          19 KB
#     zlib-1.2.13                |       h5eee18b_0         103 KB
#     zstd-1.5.2                 |       ha4553b6_0         488 KB
#     ------------------------------------------------------------
#                                            Total:       238.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   _openmp_mutex      pkgs/main/linux-64::_openmp_mutex-5.1-1_gnu
#   blas               pkgs/main/linux-64::blas-1.0-mkl
#   bottleneck         pkgs/main/linux-64::bottleneck-1.3.5-py37h7deecbd_0
#   bzip2              pkgs/main/linux-64::bzip2-1.0.8-h7b6447c_0
#   cairo              pkgs/main/linux-64::cairo-1.16.0-hb05425b_3
#   expat              pkgs/main/linux-64::expat-2.4.9-h6a678d5_0
#   flit-core          pkgs/main/noarch::flit-core-3.6.0-pyhd3eb1b0_0
#   fontconfig         pkgs/main/linux-64::fontconfig-2.14.1-h52c9d5c_1
#   freetype           pkgs/main/linux-64::freetype-2.12.1-h4a9f257_0
#   giflib             pkgs/main/linux-64::giflib-5.2.1-h5eee18b_1
#   glib               pkgs/main/linux-64::glib-2.69.1-he621ea3_2
#   icu                pkgs/main/linux-64::icu-58.2-he6710b0_3
#   importlib-metadata pkgs/main/linux-64::importlib-metadata-4.11.3-py37h06a4308_0
#   importlib_metadata pkgs/main/noarch::importlib_metadata-4.11.3-hd3eb1b0_0
#   intel-openmp       pkgs/main/linux-64::intel-openmp-2021.4.0-h06a4308_3561
#   jpeg               pkgs/main/linux-64::jpeg-9e-h7f8727e_0
#   lcms2              pkgs/main/linux-64::lcms2-2.12-h3be6417_0
#   lerc               pkgs/main/linux-64::lerc-3.0-h295c915_0
#   libboost           pkgs/main/linux-64::libboost-1.73.0-h28710b8_12
#   libdeflate         pkgs/main/linux-64::libdeflate-1.8-h7f8727e_5
#   libgomp            pkgs/main/linux-64::libgomp-11.2.0-h1234567_1
#   libpng             pkgs/main/linux-64::libpng-1.6.37-hbc83047_0
#   libtiff            pkgs/main/linux-64::libtiff-4.5.0-hecacb30_0
#   libuuid            pkgs/main/linux-64::libuuid-1.41.5-h5eee18b_0
#   libwebp            pkgs/main/linux-64::libwebp-1.2.4-h11a3e52_0
#   libwebp-base       pkgs/main/linux-64::libwebp-base-1.2.4-h5eee18b_0
#   libxcb             pkgs/main/linux-64::libxcb-1.15-h7f8727e_0
#   libxml2            pkgs/main/linux-64::libxml2-2.9.14-h74e7548_0
#   lz4-c              pkgs/main/linux-64::lz4-c-1.9.4-h6a678d5_0
#   mkl                pkgs/main/linux-64::mkl-2021.4.0-h06a4308_640
#   mkl-service        pkgs/main/linux-64::mkl-service-2.4.0-py37h7f8727e_0
#   mkl_fft            pkgs/main/linux-64::mkl_fft-1.3.1-py37hd3c417c_0
#   mkl_random         pkgs/main/linux-64::mkl_random-1.2.2-py37h51133e4_0
#   numexpr            pkgs/main/linux-64::numexpr-2.8.4-py37he184ba9_0
#   numpy              pkgs/main/linux-64::numpy-1.21.5-py37h6c91a56_3
#   numpy-base         pkgs/main/linux-64::numpy-base-1.21.5-py37ha15fc14_3
#   packaging          pkgs/main/linux-64::packaging-22.0-py37h06a4308_0
#   pandas             pkgs/main/linux-64::pandas-1.3.5-py37h8c16a72_0
#   pcre               pkgs/main/linux-64::pcre-8.45-h295c915_0
#   pillow             pkgs/main/linux-64::pillow-9.3.0-py37hace64e9_1
#   pixman             pkgs/main/linux-64::pixman-0.40.0-h7f8727e_1
#   pluggy             pkgs/main/linux-64::pluggy-1.0.0-py37h06a4308_1
#   py-boost           pkgs/main/linux-64::py-boost-1.73.0-py37h51133e4_12
#   python-dateutil    pkgs/main/noarch::python-dateutil-2.8.2-pyhd3eb1b0_0
#   pytz               pkgs/main/linux-64::pytz-2022.7-py37h06a4308_0
#   rdkit              rdkit/linux-64::rdkit-2020.09.1.0-py37hd50e099_1
#   ruamel.yaml        pkgs/main/linux-64::ruamel.yaml-0.17.21-py37h5eee18b_0
#   ruamel.yaml.clib   pkgs/main/linux-64::ruamel.yaml.clib-0.2.6-py37h5eee18b_1
#   toolz              pkgs/main/linux-64::toolz-0.12.0-py37h06a4308_0
#   typing_extensions  pkgs/main/linux-64::typing_extensions-4.4.0-py37h06a4308_0
#   zipp               pkgs/main/linux-64::zipp-3.11.0-py37h06a4308_0
#   zstd               pkgs/main/linux-64::zstd-1.5.2-ha4553b6_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                                2020.1.1-0 --> 2023.01.10-h06a4308_0
#   certifi                                 2019.11.28-py37_0 --> 2022.12.7-py37h06a4308_0
#   conda                                        4.8.2-py37_0 --> 23.1.0-py37h06a4308_0
#   libffi                                   3.2.1-hd88cf55_4 --> 3.4.2-h6a678d5_6
#   libgcc-ng                                9.1.0-hdf63c60_0 --> 11.2.0-h1234567_1
#   libstdcxx-ng                             9.1.0-hdf63c60_0 --> 11.2.0-h1234567_1
#   openssl                                 1.1.1d-h7b6447c_4 --> 1.1.1s-h7f8727e_0
#   xz                                       5.2.4-h14c3975_4 --> 5.2.10-h5eee18b_1
#   zlib                                    1.2.11-h7b6447c_3 --> 1.2.13-h5eee18b_0
#
#
#
# Downloading and Extracting Packages
# pcre-8.45            | 207 KB    | : 100% 1.0/1 [00:00<00:00,  7.40it/s]
# pixman-0.40.0        | 373 KB    | : 100% 1.0/1 [00:00<00:00, 11.50it/s]
# _openmp_mutex-5.1    | 21 KB     | : 100% 1.0/1 [00:00<00:00, 13.86it/s]
# libuuid-1.41.5       | 27 KB     | : 100% 1.0/1 [00:00<00:00, 11.84it/s]
# certifi-2022.12.7    | 150 KB    | : 100% 1.0/1 [00:00<00:00, 10.56it/s]
# libpng-1.6.37        | 278 KB    | : 100% 1.0/1 [00:00<00:00,  9.69it/s]
# zstd-1.5.2           | 488 KB    | : 100% 1.0/1 [00:00<00:00, 12.33it/s]
# lcms2-2.12           | 312 KB    | : 100% 1.0/1 [00:00<00:00, 12.30it/s]
# pillow-9.3.0         | 719 KB    | : 100% 1.0/1 [00:00<00:00, 10.21it/s]
# bottleneck-1.3.5     | 115 KB    | : 100% 1.0/1 [00:00<00:00, 12.94it/s]
# icu-58.2             | 10.5 MB   | : 100% 1.0/1 [00:00<00:00,  2.18it/s]
# jpeg-9e              | 240 KB    | : 100% 1.0/1 [00:00<00:00, 12.33it/s]
# fontconfig-2.14.1    | 281 KB    | : 100% 1.0/1 [00:00<00:00, 11.64it/s]
# toolz-0.12.0         | 104 KB    | : 100% 1.0/1 [00:00<00:00,  9.94it/s]
# mkl-2021.4.0         | 142.6 MB  | : 100% 1.0/1 [00:05<00:00,  5.51s/it]
# ruamel.yaml-0.17.21  | 177 KB    | : 100% 1.0/1 [00:00<00:00, 10.38it/s]
# python-dateutil-2.8. | 233 KB    | : 100% 1.0/1 [00:00<00:00, 13.95it/s]
# openssl-1.1.1s       | 3.6 MB    | : 100% 1.0/1 [00:00<00:00,  5.08it/s]
# mkl_random-1.2.2     | 287 KB    | : 100% 1.0/1 [00:00<00:00, 11.61it/s]
# conda-23.1.0         | 937 KB    | : 100% 1.0/1 [00:00<00:00,  7.75it/s]
# xz-5.2.10            | 429 KB    | : 100% 1.0/1 [00:00<00:00,  9.52it/s]
# libgcc-ng-11.2.0     | 5.3 MB    | : 100% 1.0/1 [00:00<00:00,  4.49it/s]
# mkl-service-2.4.0    | 56 KB     | : 100% 1.0/1 [00:00<00:00, 13.87it/s]
# bzip2-1.0.8          | 78 KB     | : 100% 1.0/1 [00:00<00:00, 13.38it/s]
# numexpr-2.8.4        | 133 KB    | : 100% 1.0/1 [00:00<00:00, 13.91it/s]
# libxcb-1.15          | 505 KB    | : 100% 1.0/1 [00:00<00:00, 10.31it/s]
# zipp-3.11.0          | 19 KB     | : 100% 1.0/1 [00:00<00:00, 15.71it/s]
# libstdcxx-ng-11.2.0  | 4.7 MB    | : 100% 1.0/1 [00:00<00:00,  4.67it/s]
# cairo-1.16.0         | 1.2 MB    | : 100% 1.0/1 [00:00<00:00,  9.25it/s]
# pytz-2022.7          | 207 KB    | : 100% 1.0/1 [00:00<00:00,  8.76it/s]
# libtiff-4.5.0        | 528 KB    | : 100% 1.0/1 [00:00<00:00,  7.15it/s]
# libffi-3.4.2         | 136 KB    | : 100% 1.0/1 [00:00<00:00, 11.56it/s]
# libxml2-2.9.14       | 718 KB    | : 100% 1.0/1 [00:00<00:00, 10.34it/s]
# ruamel.yaml.clib-0.2 | 140 KB    | : 100% 1.0/1 [00:00<00:00, 14.33it/s]
# libwebp-1.2.4        | 79 KB     | : 100% 1.0/1 [00:00<00:00, 13.67it/s]
# blas-1.0             | 6 KB      | : 100% 1.0/1 [00:00<00:00, 14.91it/s]
# pluggy-1.0.0         | 29 KB     | : 100% 1.0/1 [00:00<00:00, 13.94it/s]
# importlib-metadata-4 | 40 KB     | : 100% 1.0/1 [00:00<00:00, 14.37it/s]
# libgomp-11.2.0       | 474 KB    | : 100% 1.0/1 [00:00<00:00, 11.21it/s]
# packaging-22.0       | 68 KB     | : 100% 1.0/1 [00:00<00:00, 14.94it/s]
# pandas-1.3.5         | 9.3 MB    | : 100% 1.0/1 [00:00<00:00,  1.42it/s]
# intel-openmp-2021.4. | 4.2 MB    | : 100% 1.0/1 [00:00<00:00,  4.19it/s]
# glib-2.69.1          | 1.9 MB    | : 100% 1.0/1 [00:00<00:00,  6.86it/s]
# libboost-1.73.0      | 13.8 MB   | : 100% 1.0/1 [00:03<00:00,  2.32s/it]
# lz4-c-1.9.4          | 154 KB    | : 100% 1.0/1 [00:00<00:00,  9.12it/s]
# expat-2.4.9          | 156 KB    | : 100% 1.0/1 [00:00<00:00,  8.42it/s]
# freetype-2.12.1      | 626 KB    | : 100% 1.0/1 [00:00<00:00,  4.44it/s]
# numpy-base-1.21.5    | 4.8 MB    | : 100% 1.0/1 [00:00<00:00,  1.80it/s]
# libdeflate-1.8       | 51 KB     | : 100% 1.0/1 [00:00<00:00,  7.04it/s]
# py-boost-1.73.0      | 195 KB    | : 100% 1.0/1 [00:00<00:00,  6.35it/s]
# zlib-1.2.13          | 103 KB    | : 100% 1.0/1 [00:00<00:00,  7.16it/s]
# flit-core-3.6.0      | 42 KB     | : 100% 1.0/1 [00:00<00:00,  7.22it/s]
# libwebp-base-1.2.4   | 347 KB    | : 100% 1.0/1 [00:00<00:00,  5.69it/s]
# rdkit-2020.09.1.0    | 25.8 MB   | : 100% 1.0/1 [00:06<00:00,  6.78s/it]
# mkl_fft-1.3.1        | 172 KB    | : 100% 1.0/1 [00:00<00:00, 11.78it/s]
# typing_extensions-4. | 45 KB     | : 100% 1.0/1 [00:00<00:00, 13.99it/s]
# giflib-5.2.1         | 75 KB     | : 100% 1.0/1 [00:00<00:00, 13.09it/s]
# importlib_metadata-4 | 12 KB     | : 100% 1.0/1 [00:00<00:00,  7.87it/s]
# lerc-3.0             | 196 KB    | : 100% 1.0/1 [00:00<00:00,  8.56it/s]
# ca-certificates-2023 | 120 KB    | : 100% 1.0/1 [00:00<00:00, 14.34it/s]
# numpy-1.21.5         | 10 KB     | : 100% 1.0/1 [00:00<00:00, 12.03it/s]
# done
# done
# done

# %% [markdown]
# # Lipniski's Rule of 5

# %%
import numpy as np
from rdkit import Chem
from rdkit.Chem import Descriptors, Lipinski
import pandas as pd

# %% [markdown]
# Molecular Descriptors calculation

# %%
def lipinski(smiles, verbose=False):

    moldata= []
    for elem in smiles:
        mol=Chem.MolFromSmiles(elem) 
        moldata.append(mol)
       
    baseData= np.arange(1,1)
    i=0  
    for mol in moldata:        
       
        desc_MolWt = Descriptors.MolWt(mol)
        desc_MolLogP = Descriptors.MolLogP(mol)
        desc_NumHDonors = Lipinski.NumHDonors(mol)
        desc_NumHAcceptors = Lipinski.NumHAcceptors(mol)
           
        row = np.array([desc_MolWt,
                        desc_MolLogP,
                        desc_NumHDonors,
                        desc_NumHAcceptors])   
    
        if(i==0):
            baseData=row
        else:
            baseData=np.vstack([baseData, row])
        i=i+1      
    
    columnNames=["MW","LogP","NumHDonors","NumHAcceptors"]   
    descriptors = pd.DataFrame(data=baseData,columns=columnNames)
    
    return descriptors

# %%
df_lipinski = lipinski(df3.canonical_smiles)

# %%
df_final2 = df_final.reset_index()
df_final2
# Out:
#       index activity_comment  activity_id activity_properties assay_chembl_id  \
# 0       137             None      2923079                  []   CHEMBL1044039
# 1       138             None      2923080                  []   CHEMBL1044039
# 2       139             None      2923081                  []   CHEMBL1044039
# 3       140             None      2923082                  []   CHEMBL1044039
# 4       141             None      2923083                  []   CHEMBL1044039
# ...     ...              ...          ...                 ...             ...
# 3808    419             None      3093280                  []   CHEMBL1065148
# 3809    421             None      3093274                  []   CHEMBL1065148
# 3810    423             None      3093277                  []   CHEMBL1065148
# 3811    425             None      3093286                  []   CHEMBL1065148
# 3812    427             None      6390070                  []   CHEMBL1840267
#
#                                       assay_description assay_type  \
# 0     Antimycobacterial activity against Mycobacteri...          F
# 1     Antimycobacterial activity against Mycobacteri...          F
# 2     Antimycobacterial activity against Mycobacteri...          F
# 3     Antimycobacterial activity against Mycobacteri...          F
# 4     Antimycobacterial activity against Mycobacteri...          F
# ...                                                 ...        ...
# 3808  Antitubercular activity against Mycobacterium ...          F
# 3809  Antitubercular activity against Mycobacterium ...          F
# 3810  Antitubercular activity against Mycobacterium ...          F
# 3811  Antitubercular activity against Mycobacterium ...          F
# 3812  Antimycobacterial activity against Mycobacteri...          F
#
#      assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0                       None                   None  BAO_0002146  ...
# 1                       None                   None  BAO_0002146  ...
# 2                       None                   None  BAO_0002146  ...
# 3                       None                   None  BAO_0002146  ...
# 4                       None                   None  BAO_0002146  ...
# ...                      ...                    ...          ...  ...
# 3808                    None                   None  BAO_0002146  ...
# 3809                    None                   None  BAO_0002146  ...
# 3810                    None                   None  BAO_0002146  ...
# 3811                    None                   None  BAO_0002146  ...
# 3812                    None                   None  BAO_0002146  ...
#
#                       target_pref_name target_tax_id text_value  toid type  \
# 0     Mycobacterium tuberculosis H37Rv         83332       None  None  MIC
# 1     Mycobacterium tuberculosis H37Rv         83332       None  None  MIC
# 2     Mycobacterium tuberculosis H37Rv         83332       None  None  MIC
# 3     Mycobacterium tuberculosis H37Rv         83332       None  None  MIC
# 4     Mycobacterium tuberculosis H37Rv         83332       None  None  MIC
# ...                                ...           ...        ...   ...  ...
# 3808  Mycobacterium tuberculosis H37Rv         83332       None  None  MIC
# 3809  Mycobacterium tuberculosis H37Rv         83332       None  None  MIC
# 3810  Mycobacterium tuberculosis H37Rv         83332       None  None  MIC
# 3811  Mycobacterium tuberculosis H37Rv         83332       None  None  MIC
# 3812  Mycobacterium tuberculosis H37Rv         83332       None  None  MIC
#
#      units    uo_units  upper_value     value Activity
# 0       uM  UO_0000065         None   84000.0       No
# 1       uM  UO_0000065         None   24000.0       No
# 2       uM  UO_0000065         None    3600.0       No
# 3       uM  UO_0000065         None   16600.0       No
# 4       uM  UO_0000065         None    3100.0       No
# ...    ...         ...          ...       ...      ...
# 3808    uM  UO_0000065         None  128000.0       No
# 3809    uM  UO_0000065         None  128000.0       No
# 3810    uM  UO_0000065         None  128000.0       No
# 3811    uM  UO_0000065         None  128000.0       No
# 3812    uM  UO_0000065         None   34500.0       No
#
# [3813 rows x 47 columns]

# %%
df_lipinski
# Out:
#            MW    LogP  NumHDonors  NumHAcceptors
# 0     357.579  5.9632         2.0            3.0
# 1     257.462  4.3972         2.0            2.0
# 2     347.587  6.6217         1.0            2.0
# 3     375.641  7.2725         1.0            2.0
# 4     403.695  8.0048         0.0            2.0
# ...       ...     ...         ...            ...
# 3808  475.345  5.0070         0.0            6.0
# 3809  405.254  3.9383         1.0            5.0
# 3810  461.362  5.3214         0.0            5.0
# 3811  392.255  4.3317         1.0            5.0
# 3812  289.545  5.1447         1.0            2.0
#
# [3813 rows x 4 columns]

# %%
df_combined = pd.concat([df_final2,df_lipinski], axis=1)

# %%
df_combined
# Out:
#       index activity_comment  activity_id activity_properties assay_chembl_id  \
# 0       137             None      2923079                  []   CHEMBL1044039
# 1       138             None      2923080                  []   CHEMBL1044039
# 2       139             None      2923081                  []   CHEMBL1044039
# 3       140             None      2923082                  []   CHEMBL1044039
# 4       141             None      2923083                  []   CHEMBL1044039
# ...     ...              ...          ...                 ...             ...
# 3808    419             None      3093280                  []   CHEMBL1065148
# 3809    421             None      3093274                  []   CHEMBL1065148
# 3810    423             None      3093277                  []   CHEMBL1065148
# 3811    425             None      3093286                  []   CHEMBL1065148
# 3812    427             None      6390070                  []   CHEMBL1840267
#
#                                       assay_description assay_type  \
# 0     Antimycobacterial activity against Mycobacteri...          F
# 1     Antimycobacterial activity against Mycobacteri...          F
# 2     Antimycobacterial activity against Mycobacteri...          F
# 3     Antimycobacterial activity against Mycobacteri...          F
# 4     Antimycobacterial activity against Mycobacteri...          F
# ...                                                 ...        ...
# 3808  Antitubercular activity against Mycobacterium ...          F
# 3809  Antitubercular activity against Mycobacterium ...          F
# 3810  Antitubercular activity against Mycobacterium ...          F
# 3811  Antitubercular activity against Mycobacterium ...          F
# 3812  Antimycobacterial activity against Mycobacteri...          F
#
#      assay_variant_accession assay_variant_mutation bao_endpoint  ... type  \
# 0                       None                   None  BAO_0002146  ...  MIC
# 1                       None                   None  BAO_0002146  ...  MIC
# 2                       None                   None  BAO_0002146  ...  MIC
# 3                       None                   None  BAO_0002146  ...  MIC
# 4                       None                   None  BAO_0002146  ...  MIC
# ...                      ...                    ...          ...  ...  ...
# 3808                    None                   None  BAO_0002146  ...  MIC
# 3809                    None                   None  BAO_0002146  ...  MIC
# 3810                    None                   None  BAO_0002146  ...  MIC
# 3811                    None                   None  BAO_0002146  ...  MIC
# 3812                    None                   None  BAO_0002146  ...  MIC
#
#      units    uo_units upper_value     value Activity       MW    LogP  \
# 0       uM  UO_0000065        None   84000.0       No  357.579  5.9632
# 1       uM  UO_0000065        None   24000.0       No  257.462  4.3972
# 2       uM  UO_0000065        None    3600.0       No  347.587  6.6217
# 3       uM  UO_0000065        None   16600.0       No  375.641  7.2725
# 4       uM  UO_0000065        None    3100.0       No  403.695  8.0048
# ...    ...         ...         ...       ...      ...      ...     ...
# 3808    uM  UO_0000065        None  128000.0       No  475.345  5.0070
# 3809    uM  UO_0000065        None  128000.0       No  405.254  3.9383
# 3810    uM  UO_0000065        None  128000.0       No  461.362  5.3214
# 3811    uM  UO_0000065        None  128000.0       No  392.255  4.3317
# 3812    uM  UO_0000065        None   34500.0       No  289.545  5.1447
#
#      NumHDonors NumHAcceptors
# 0           2.0           3.0
# 1           2.0           2.0
# 2           1.0           2.0
# 3           1.0           2.0
# 4           0.0           2.0
# ...         ...           ...
# 3808        0.0           6.0
# 3809        1.0           5.0
# 3810        0.0           5.0
# 3811        1.0           5.0
# 3812        1.0           2.0
#
# [3813 rows x 51 columns]

# %%
df_combined.to_csv('Mtb_H37Rv_MIC_nm_MolDes.csv', sep=',' ,index=False)
