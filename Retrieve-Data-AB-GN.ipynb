# %% [markdown]
# <a href="https://colab.research.google.com/github/Jahan08/Amber-tutorial/blob/main/Retrieve-Data-AB-GN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install chembl_webresource_client
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.8-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 KB 1.7 MB/s eta 0:00:00
# Collecting requests-cache~=0.7.0
#   Downloading requests_cache-0.7.5-py3-none-any.whl (39 kB)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.9/dist-packages (from chembl_webresource_client) (1.26.15)
# Requirement already satisfied: easydict in /usr/local/lib/python3.9/dist-packages (from chembl_webresource_client) (1.10)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.9/dist-packages (from chembl_webresource_client) (2.27.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2022.12.7)
# Requirement already satisfied: itsdangerous>=2.0.1 in /usr/local/lib/python3.9/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (2.1.2)
# Collecting url-normalize<2.0,>=1.4
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Collecting attrs<22.0,>=21.2
#   Downloading attrs-21.4.0-py2.py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 KB 4.3 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.4 in /usr/local/lib/python3.9/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (6.0)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from url-normalize<2.0,>=1.4->requests-cache~=0.7.0->chembl_webresource_client) (1.16.0)
# Installing collected packages: url-normalize, attrs, requests-cache, chembl_webresource_client
#   Attempting uninstall: attrs
#     Found existing installation: attrs 22.2.0
#     Uninstalling attrs-22.2.0:
#       Successfully uninstalled attrs-22.2.0
# Successfully installed attrs-21.4.0 chembl_webresource_client-0.10.8 requests-cache-0.7.5 url-normalize-1.4.3

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %%
target = new_client.target
target_query = target.search('Escherichia coli')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#    cross_references                     organism  \
# 0                []             Escherichia coli
# 1                []        Escherichia coli K-12
# 2                []           Escherichia coli B
# 3                []     Escherichia coli O157:H7
# 4                []  Escherichia coli DH5[alpha]
# ..              ...                          ...
# 72               []             Escherichia coli
# 73               []             Escherichia coli
# 74               []             Escherichia coli
# 75               []             Escherichia coli
# 76               []             Escherichia coli
#
#                                             pref_name  score  \
# 0                                    Escherichia coli   29.0
# 1                                Escherichia coli K12   25.0
# 2                                  Escherichia coli B   25.0
# 3                            Escherichia coli O157:H7   23.0
# 4                         Escherichia coli DH5[alpha]   23.0
# ..                                                ...    ...
# 72                              Beta-lactamase SHV-12    8.0
# 73                        DNA-directed RNA polymerase    8.0
# 74                            DNA repair protein RecN    8.0
# 75                                     LexA repressor    8.0
# 76  Acyl-[acyl-carrier-protein]--UDP-N-acetylgluco...    8.0
#
#     species_group_flag target_chembl_id  \
# 0                False        CHEMBL354
# 1                False     CHEMBL612336
# 2                False     CHEMBL612393
# 3                False    CHEMBL2366669
# 4                False    CHEMBL2366740
# ..                 ...              ...
# 72               False    CHEMBL4296041
# 73               False    CHEMBL4296169
# 74               False    CHEMBL4630870
# 75               False    CHEMBL4630871
# 76               False    CHEMBL4879550
#
#                                     target_components      target_type  tax_id
# 0                                                  []         ORGANISM     562
# 1                                                  []         ORGANISM   83333
# 2                                                  []         ORGANISM   37762
# 3                                                  []         ORGANISM   83334
# 4                                                  []         ORGANISM  668369
# ..                                                ...              ...     ...
# 72  [{'accession': 'A0A2P9E6B0', 'component_descri...   SINGLE PROTEIN     562
# 73  [{'accession': 'P0A8V2', 'component_descriptio...  PROTEIN COMPLEX     562
# 74  [{'accession': 'P05824', 'component_descriptio...   SINGLE PROTEIN     562
# 75  [{'accession': 'P0A7C2', 'component_descriptio...   SINGLE PROTEIN     562
# 76  [{'accession': 'P0A722', 'component_descriptio...   SINGLE PROTEIN     562
#
# [77 rows x 9 columns]

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL354'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="MIC")

# %%
df = pd.DataFrame.from_dict(res)
df
# Out:
#       activity_comment  activity_id  \
# 0                 None        31976
# 1                 None        32280
# 2                 None        32286
# 3                 None        32426
# 4                 None        32427
# ...                ...          ...
# 70470             None     24518128
# 70471             None     24518129
# 70472             None     24518130
# 70473             None     24518246
# 70474             None     24518247
#
#                                      activity_properties assay_chembl_id  \
# 0                                                     []    CHEMBL676856
# 1                                                     []    CHEMBL682927
# 2                                                     []    CHEMBL682927
# 3                                                     []    CHEMBL676848
# 4                                                     []    CHEMBL675580
# ...                                                  ...             ...
# 70470  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5057930
# 70471  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5057930
# 70472  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5057930
# 70473  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5057959
# 70474  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5057959
#
#                                        assay_description assay_type  \
# 0      Compound was tested in vitro for antibacterial...          F
# 1      Minimum inhibitory concentration against Esche...          F
# 2      Minimum inhibitory concentration against Esche...          F
# 3      Compound was tested for its minimal inhibitory...          F
# 4      Compound was tested for its minimal inhibitory...          F
# ...                                                  ...        ...
# 70470  Antimicrobial activity against Escherichia col...          F
# 70471  Antimicrobial activity against Escherichia col...          F
# 70472  Antimicrobial activity against Escherichia col...          F
# 70473  Antibacterial activity against Escherichia col...          F
# 70474  Antibacterial activity against Escherichia col...          F
#
#       assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0                        None                   None  BAO_0002146
# 1                        None                   None  BAO_0002146
# 2                        None                   None  BAO_0002146
# 3                        None                   None  BAO_0002146
# 4                        None                   None  BAO_0002146
# ...                       ...                    ...          ...
# 70470                    None                   None  BAO_0002146
# 70471                    None                   None  BAO_0002146
# 70472                    None                   None  BAO_0002146
# 70473                    None                   None  BAO_0002146
# 70474                    None                   None  BAO_0002146
#
#         bao_format  ...   target_organism  target_pref_name target_tax_id  \
# 0      BAO_0000218  ...  Escherichia coli  Escherichia coli           562
# 1      BAO_0000218  ...  Escherichia coli  Escherichia coli           562
# 2      BAO_0000218  ...  Escherichia coli  Escherichia coli           562
# 3      BAO_0000218  ...  Escherichia coli  Escherichia coli           562
# 4      BAO_0000218  ...  Escherichia coli  Escherichia coli           562
# ...            ...  ...               ...               ...           ...
# 70470  BAO_0000218  ...  Escherichia coli  Escherichia coli           562
# 70471  BAO_0000218  ...  Escherichia coli  Escherichia coli           562
# 70472  BAO_0000218  ...  Escherichia coli  Escherichia coli           562
# 70473  BAO_0000218  ...  Escherichia coli  Escherichia coli           562
# 70474  BAO_0000218  ...  Escherichia coli  Escherichia coli           562
#
#       text_value  toid type    units    uo_units upper_value  value
# 0           None  None  MIC  ug ml-1  UO_0000274        None    3.9
# 1           None  None  MIC  ug ml-1  UO_0000274        None   1.56
# 2           None  None  MIC  ug ml-1  UO_0000274        None   6.25
# 3           None  None  MIC  ug ml-1  UO_0000274        None    0.1
# 4           None  None  MIC  ug ml-1  UO_0000274        None    0.1
# ...          ...   ...  ...      ...         ...         ...    ...
# 70470       None  None  MIC  ug ml-1  UO_0000274        None  250.0
# 70471       None  None  MIC  ug ml-1  UO_0000274        None  250.0
# 70472       None  None  MIC  ug ml-1  UO_0000274        None  250.0
# 70473       None  None  MIC       uM  UO_0000065        None   88.0
# 70474       None  None  MIC       uM  UO_0000065        None  132.0
#
# [70475 rows x 45 columns]

# %%
# considering nM unit for MIC
#df = df[(df['standard_type'] == 'GI50')]
#df = df[(df['standard_type'] == 'IC50')]
#df = df[(df['standard_type'] == 'EC50')]
df = df[(df['standard_units'] == 'nM')]
df = df[(df['relation'] == '=')]
df = df[df.canonical_smiles.notna()]
df = df[df.standard_value.notna()]
df
# Out:
#       activity_comment  activity_id  \
# 566               None        72466
# 645               None        84473
# 656               None        85545
# 674               None        91485
# 680               None        92514
# ...                ...          ...
# 70331             None     24425371
# 70332             None     24425372
# 70333             None     24425373
# 70473             None     24518246
# 70474             None     24518247
#
#                                      activity_properties assay_chembl_id  \
# 566                                                   []    CHEMBL682833
# 645                                                   []    CHEMBL682833
# 656                                                   []    CHEMBL682833
# 674                                                   []    CHEMBL682833
# 680                                                   []    CHEMBL682833
# ...                                                  ...             ...
# 70331  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5049908
# 70332  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5049908
# 70333  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5049908
# 70473  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5057959
# 70474  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5057959
#
#                                        assay_description assay_type  \
# 566    In vitro antibacterial activity of the peptide...          F
# 645    In vitro antibacterial activity of the peptide...          F
# 656    In vitro antibacterial activity of the peptide...          F
# 674    In vitro antibacterial activity of the peptide...          F
# 680    In vitro antibacterial activity of the peptide...          F
# ...                                                  ...        ...
# 70331  Antibacterial activity against Escherichia col...          F
# 70332  Antibacterial activity against Escherichia col...          F
# 70333  Antibacterial activity against Escherichia col...          F
# 70473  Antibacterial activity against Escherichia col...          F
# 70474  Antibacterial activity against Escherichia col...          F
#
#       assay_variant_accession assay_variant_mutation bao_endpoint  \
# 566                      None                   None  BAO_0002146
# 645                      None                   None  BAO_0002146
# 656                      None                   None  BAO_0002146
# 674                      None                   None  BAO_0002146
# 680                      None                   None  BAO_0002146
# ...                       ...                    ...          ...
# 70331                    None                   None  BAO_0002146
# 70332                    None                   None  BAO_0002146
# 70333                    None                   None  BAO_0002146
# 70473                    None                   None  BAO_0002146
# 70474                    None                   None  BAO_0002146
#
#         bao_format  ...   target_organism  target_pref_name target_tax_id  \
# 566    BAO_0000218  ...  Escherichia coli  Escherichia coli           562
# 645    BAO_0000218  ...  Escherichia coli  Escherichia coli           562
# 656    BAO_0000218  ...  Escherichia coli  Escherichia coli           562
# 674    BAO_0000218  ...  Escherichia coli  Escherichia coli           562
# 680    BAO_0000218  ...  Escherichia coli  Escherichia coli           562
# ...            ...  ...               ...               ...           ...
# 70331  BAO_0000218  ...  Escherichia coli  Escherichia coli           562
# 70332  BAO_0000218  ...  Escherichia coli  Escherichia coli           562
# 70333  BAO_0000218  ...  Escherichia coli  Escherichia coli           562
# 70473  BAO_0000218  ...  Escherichia coli  Escherichia coli           562
# 70474  BAO_0000218  ...  Escherichia coli  Escherichia coli           562
#
#       text_value  toid type  units    uo_units upper_value  value
# 566         None  None  MIC     uM  UO_0000065        None   55.0
# 645         None  None  MIC     uM  UO_0000065        None    5.7
# 656         None  None  MIC     uM  UO_0000065        None    6.6
# 674         None  None  MIC     uM  UO_0000065        None    4.5
# 680         None  None  MIC     uM  UO_0000065        None    7.7
# ...          ...   ...  ...    ...         ...         ...    ...
# 70331       None  None  MIC     uM  UO_0000065        None   32.0
# 70332       None  None  MIC     uM  UO_0000065        None   32.0
# 70333       None  None  MIC     uM  UO_0000065        None    1.0
# 70473       None  None  MIC     uM  UO_0000065        None   88.0
# 70474       None  None  MIC     uM  UO_0000065        None  132.0
#
# [5378 rows x 45 columns]

# %%
fix = []

for i in df.standard_value:
    fix.append(float(i))

STATUS = []

for i in fix:
    if i <20000:
        STATUS.append("Yes") #active
        
    elif 50000 <= i <= 100000:
        STATUS.append("No") #inactive
        
    else:
        STATUS.append("IN") #intermediate     

df = df.drop('value', 1)
df['value'] = fix
df['Activity'] = STATUS
df
# Out:
# <ipython-input-34-b12e53e9fad3>:18: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df = df.drop('value', 1)
#       activity_comment  activity_id  \
# 566               None        72466
# 645               None        84473
# 656               None        85545
# 674               None        91485
# 680               None        92514
# ...                ...          ...
# 70331             None     24425371
# 70332             None     24425372
# 70333             None     24425373
# 70473             None     24518246
# 70474             None     24518247
#
#                                      activity_properties assay_chembl_id  \
# 566                                                   []    CHEMBL682833
# 645                                                   []    CHEMBL682833
# 656                                                   []    CHEMBL682833
# 674                                                   []    CHEMBL682833
# 680                                                   []    CHEMBL682833
# ...                                                  ...             ...
# 70331  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5049908
# 70332  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5049908
# 70333  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5049908
# 70473  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5057959
# 70474  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5057959
#
#                                        assay_description assay_type  \
# 566    In vitro antibacterial activity of the peptide...          F
# 645    In vitro antibacterial activity of the peptide...          F
# 656    In vitro antibacterial activity of the peptide...          F
# 674    In vitro antibacterial activity of the peptide...          F
# 680    In vitro antibacterial activity of the peptide...          F
# ...                                                  ...        ...
# 70331  Antibacterial activity against Escherichia col...          F
# 70332  Antibacterial activity against Escherichia col...          F
# 70333  Antibacterial activity against Escherichia col...          F
# 70473  Antibacterial activity against Escherichia col...          F
# 70474  Antibacterial activity against Escherichia col...          F
#
#       assay_variant_accession assay_variant_mutation bao_endpoint  \
# 566                      None                   None  BAO_0002146
# 645                      None                   None  BAO_0002146
# 656                      None                   None  BAO_0002146
# 674                      None                   None  BAO_0002146
# 680                      None                   None  BAO_0002146
# ...                       ...                    ...          ...
# 70331                    None                   None  BAO_0002146
# 70332                    None                   None  BAO_0002146
# 70333                    None                   None  BAO_0002146
# 70473                    None                   None  BAO_0002146
# 70474                    None                   None  BAO_0002146
#
#         bao_format  ...  target_pref_name target_tax_id text_value  toid type  \
# 566    BAO_0000218  ...  Escherichia coli           562       None  None  MIC
# 645    BAO_0000218  ...  Escherichia coli           562       None  None  MIC
# 656    BAO_0000218  ...  Escherichia coli           562       None  None  MIC
# 674    BAO_0000218  ...  Escherichia coli           562       None  None  MIC
# 680    BAO_0000218  ...  Escherichia coli           562       None  None  MIC
# ...            ...  ...               ...           ...        ...   ...  ...
# 70331  BAO_0000218  ...  Escherichia coli           562       None  None  MIC
# 70332  BAO_0000218  ...  Escherichia coli           562       None  None  MIC
# 70333  BAO_0000218  ...  Escherichia coli           562       None  None  MIC
# 70473  BAO_0000218  ...  Escherichia coli           562       None  None  MIC
# 70474  BAO_0000218  ...  Escherichia coli           562       None  None  MIC
#
#       units    uo_units upper_value     value Activity
# 566      uM  UO_0000065        None   55000.0       No
# 645      uM  UO_0000065        None    5700.0      Yes
# 656      uM  UO_0000065        None    6600.0      Yes
# 674      uM  UO_0000065        None    4500.0      Yes
# 680      uM  UO_0000065        None    7700.0      Yes
# ...     ...         ...         ...       ...      ...
# 70331    uM  UO_0000065        None   32000.0       IN
# 70332    uM  UO_0000065        None   32000.0       IN
# 70333    uM  UO_0000065        None    1000.0      Yes
# 70473    uM  UO_0000065        None   88000.0       No
# 70474    uM  UO_0000065        None  132000.0       IN
#
# [5378 rows x 46 columns]

# %%
# considering nM unit for MIC
df = df[(df['Activity'] != 'IN')]
len(df)
# Out:
# 3343

# %%
df.to_csv('/content/bioactivity_data_MIC_EC.csv', index=False)
