# %% [markdown]
# <a href="https://colab.research.google.com/github/Jahan08/Amber-tutorial/blob/main/Retrieve-Data-AB-GN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install chembl_webresource_client
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.8-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 KB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.9/dist-packages (from chembl_webresource_client) (1.26.15)
# Requirement already satisfied: easydict in /usr/local/lib/python3.9/dist-packages (from chembl_webresource_client) (1.10)
# Collecting requests-cache~=0.7.0
#   Downloading requests_cache-0.7.5-py3-none-any.whl (39 kB)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.9/dist-packages (from chembl_webresource_client) (2.27.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2.0.12)
# Collecting attrs<22.0,>=21.2
#   Downloading attrs-21.4.0-py2.py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 KB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: itsdangerous>=2.0.1 in /usr/local/lib/python3.9/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (2.1.2)
# Requirement already satisfied: pyyaml>=5.4 in /usr/local/lib/python3.9/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (6.0)
# Collecting url-normalize<2.0,>=1.4
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from url-normalize<2.0,>=1.4->requests-cache~=0.7.0->chembl_webresource_client) (1.16.0)
# Installing collected packages: url-normalize, attrs, requests-cache, chembl_webresource_client
#   Attempting uninstall: attrs
#     Found existing installation: attrs 22.2.0
#     Uninstalling attrs-22.2.0:
#       Successfully uninstalled attrs-22.2.0
# Successfully installed attrs-21.4.0 chembl_webresource_client-0.10.8 requests-cache-0.7.5 url-normalize-1.4.3

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %%
target = new_client.target
target_query = target.search('Klebsiella aerogenes')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                      cross_references  \
# 0                                                  []
# 1                                                  []
# 2                                                  []
# 3                                                  []
# 4                                                  []
# 5                                                  []
# 6   [{'xref_id': 'P31074', 'xref_name': None, 'xre...
# 7                                                  []
# 8                                                  []
# 9                                                  []
# 10                                                 []
#
#                                    organism  \
# 0                      Klebsiella aerogenes
# 1                                Klebsiella
# 2                     Klebsiella pneumoniae
# 3                        Klebsiella oxytoca
# 4                            Klebsiella sp.
# 5                      Klebsiella variicola
# 6                      Klebsiella aerogenes
# 7                      Klebsiella aerogenes
# 8                      Klebsiella aerogenes
# 9      Klebsiella pneumoniae subsp. ozaenae
# 10  Klebsiella pneumoniae subsp. pneumoniae
#
#                                   pref_name  score  species_group_flag  \
# 0                      Klebsiella aerogenes   32.0               False
# 1                                Klebsiella   17.0                True
# 2                     Klebsiella pneumoniae   14.0               False
# 3                        Klebsiella oxytoca   14.0               False
# 4                            Klebsiella sp.   14.0               False
# 5                      Klebsiella variicola   14.0               False
# 6                   Dihydrofolate reductase   12.0               False
# 7                      Beta-lactamase OXA-9   12.0               False
# 8                              AcrB protein   12.0               False
# 9      Klebsiella pneumoniae subsp. ozaenae   11.0               False
# 10  Klebsiella pneumoniae subsp. pneumoniae   11.0               False
#
#    target_chembl_id                                  target_components  \
# 0      CHEMBL612508                                                 []
# 1      CHEMBL612535                                                 []
# 2         CHEMBL350                                                 []
# 3      CHEMBL614441                                                 []
# 4      CHEMBL612616                                                 []
# 5     CHEMBL4513195                                                 []
# 6        CHEMBL3853  [{'accession': 'P31074', 'component_descriptio...
# 7     CHEMBL1744486  [{'accession': 'P0A3M4', 'component_descriptio...
# 8     CHEMBL2321620  [{'accession': 'Q9AEG1', 'component_descriptio...
# 9      CHEMBL612612                                                 []
# 10     CHEMBL613207                                                 []
#
#        target_type  tax_id
# 0         ORGANISM     548
# 1         ORGANISM     570
# 2         ORGANISM     573
# 3         ORGANISM     571
# 4         ORGANISM     576
# 5         ORGANISM  244366
# 6   SINGLE PROTEIN     548
# 7   SINGLE PROTEIN     548
# 8   SINGLE PROTEIN     548
# 9         ORGANISM     574
# 10        ORGANISM   72407

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL612508'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="MIC")

# %%
df = pd.DataFrame.from_dict(res)
df
# Out:
#      activity_comment  activity_id  \
# 0                None        40605
# 1                None        46709
# 2                None        53174
# 3                None        54361
# 4                None        60711
# ...               ...          ...
# 3275             None     23181005
# 3276             None     23181006
# 3277             None     24425142
# 3278             None     24425143
# 3279             None     24425144
#
#                                     activity_properties assay_chembl_id  \
# 0                                                    []    CHEMBL676752
# 1                                                    []    CHEMBL673912
# 2                                                    []    CHEMBL676752
# 3                                                    []    CHEMBL676752
# 4                                                    []    CHEMBL673912
# ...                                                 ...             ...
# 3275                                                 []   CHEMBL4816531
# 3276                                                 []   CHEMBL4816531
# 3277  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5049862
# 3278  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5049862
# 3279  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5049862
#
#                                       assay_description assay_type  \
# 0     In vitro synergistic activity against Enteroba...          F
# 1     Inhibitory activity against Enterobacter aerog...          F
# 2     In vitro synergistic activity against Enteroba...          F
# 3     In vitro synergistic activity against Enteroba...          F
# 4     Inhibitory activity against Enterobacter aerog...          F
# ...                                                 ...        ...
# 3275  Antibacterial activity against Enterobacter ae...          F
# 3276  Antibacterial activity against Enterobacter ae...          F
# 3277  Antibacterial activity against Klebsiella aero...          F
# 3278  Antibacterial activity against Klebsiella aero...          F
# 3279  Antibacterial activity against Klebsiella aero...          F
#
#      assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                       None                   None  BAO_0002146  BAO_0000218
# 1                       None                   None  BAO_0002146  BAO_0000218
# 2                       None                   None  BAO_0002146  BAO_0000218
# 3                       None                   None  BAO_0002146  BAO_0000218
# 4                       None                   None  BAO_0002146  BAO_0000218
# ...                      ...                    ...          ...          ...
# 3275                    None                   None  BAO_0002146  BAO_0000218
# 3276                    None                   None  BAO_0002146  BAO_0000218
# 3277                    None                   None  BAO_0002146  BAO_0000218
# 3278                    None                   None  BAO_0002146  BAO_0000218
# 3279                    None                   None  BAO_0002146  BAO_0000218
#
#       ...       target_organism      target_pref_name target_tax_id  \
# 0     ...  Klebsiella aerogenes  Klebsiella aerogenes           548
# 1     ...  Klebsiella aerogenes  Klebsiella aerogenes           548
# 2     ...  Klebsiella aerogenes  Klebsiella aerogenes           548
# 3     ...  Klebsiella aerogenes  Klebsiella aerogenes           548
# 4     ...  Klebsiella aerogenes  Klebsiella aerogenes           548
# ...   ...                   ...                   ...           ...
# 3275  ...  Klebsiella aerogenes  Klebsiella aerogenes           548
# 3276  ...  Klebsiella aerogenes  Klebsiella aerogenes           548
# 3277  ...  Klebsiella aerogenes  Klebsiella aerogenes           548
# 3278  ...  Klebsiella aerogenes  Klebsiella aerogenes           548
# 3279  ...  Klebsiella aerogenes  Klebsiella aerogenes           548
#
#      text_value  toid type    units    uo_units upper_value   value
# 0          None  None  MIC  ug ml-1  UO_0000274        None    64.0
# 1          None  None  MIC  ug ml-1  UO_0000274        None   800.0
# 2          None  None  MIC  ug ml-1  UO_0000274        None    64.0
# 3          None  None  MIC  ug ml-1  UO_0000274        None    32.0
# 4          None  None  MIC  ug ml-1  UO_0000274        None  3200.0
# ...         ...   ...  ...      ...         ...         ...     ...
# 3275       None  None  MIC     mg/L  UO_0000274        None     2.0
# 3276       None  None  MIC     mg/L  UO_0000274        None     1.0
# 3277       None  None  MIC       uM  UO_0000065        None   128.0
# 3278       None  None  MIC       uM  UO_0000065        None     8.0
# 3279       None  None  MIC       uM  UO_0000065        None    0.25
#
# [3280 rows x 45 columns]

# %%
# considering nM unit for MIC
#df = df[(df['standard_type'] == 'GI50')]
#df = df[(df['standard_type'] == 'IC50')]
#df = df[(df['standard_type'] == 'EC50')]
df = df[(df['standard_units'] == 'nM')]
df = df[(df['relation'] == '=')]
df = df[df.canonical_smiles.notna()]
df = df[df.standard_value.notna()]
df
# Out:
#      activity_comment  activity_id  \
# 158              None       223405
# 162              None       224766
# 163              None       224777
# 168              None       227400
# 169              None       227411
# ...               ...          ...
# 3195             None     20697470
# 3200             None     22387449
# 3277             None     24425142
# 3278             None     24425143
# 3279             None     24425144
#
#                                     activity_properties assay_chembl_id  \
# 158                                                  []    CHEMBL703222
# 162                                                  []    CHEMBL703222
# 163                                                  []    CHEMBL703222
# 168                                                  []    CHEMBL703222
# 169                                                  []    CHEMBL703222
# ...                                                 ...             ...
# 3195                                                 []   CHEMBL4627144
# 3200                                                 []   CHEMBL4666296
# 3277  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5049862
# 3278  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5049862
# 3279  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5049862
#
#                                       assay_description assay_type  \
# 158   Antibacterial activity against Klebsiella aero...          F
# 162   Antibacterial activity against Klebsiella aero...          F
# 163   Antibacterial activity against Klebsiella aero...          F
# 168   Antibacterial activity against Klebsiella aero...          F
# 169   Antibacterial activity against Klebsiella aero...          F
# ...                                                 ...        ...
# 3195  Antibacterial activity against Enterobacter ae...          A
# 3200  Antibacterial activity against Enterobacter ae...          F
# 3277  Antibacterial activity against Klebsiella aero...          F
# 3278  Antibacterial activity against Klebsiella aero...          F
# 3279  Antibacterial activity against Klebsiella aero...          F
#
#      assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 158                     None                   None  BAO_0002146  BAO_0000218
# 162                     None                   None  BAO_0002146  BAO_0000218
# 163                     None                   None  BAO_0002146  BAO_0000218
# 168                     None                   None  BAO_0002146  BAO_0000218
# 169                     None                   None  BAO_0002146  BAO_0000218
# ...                      ...                    ...          ...          ...
# 3195                    None                   None  BAO_0002146  BAO_0000218
# 3200                    None                   None  BAO_0002146  BAO_0000218
# 3277                    None                   None  BAO_0002146  BAO_0000218
# 3278                    None                   None  BAO_0002146  BAO_0000218
# 3279                    None                   None  BAO_0002146  BAO_0000218
#
#       ...       target_organism      target_pref_name target_tax_id  \
# 158   ...  Klebsiella aerogenes  Klebsiella aerogenes           548
# 162   ...  Klebsiella aerogenes  Klebsiella aerogenes           548
# 163   ...  Klebsiella aerogenes  Klebsiella aerogenes           548
# 168   ...  Klebsiella aerogenes  Klebsiella aerogenes           548
# 169   ...  Klebsiella aerogenes  Klebsiella aerogenes           548
# ...   ...                   ...                   ...           ...
# 3195  ...  Klebsiella aerogenes  Klebsiella aerogenes           548
# 3200  ...  Klebsiella aerogenes  Klebsiella aerogenes           548
# 3277  ...  Klebsiella aerogenes  Klebsiella aerogenes           548
# 3278  ...  Klebsiella aerogenes  Klebsiella aerogenes           548
# 3279  ...  Klebsiella aerogenes  Klebsiella aerogenes           548
#
#      text_value  toid type  units    uo_units upper_value  value
# 158        None  None  MIC     uM  UO_0000065        None  121.0
# 162        None  None  MIC     uM  UO_0000065        None   15.9
# 163        None  None  MIC     uM  UO_0000065        None   70.2
# 168        None  None  MIC     uM  UO_0000065        None  147.0
# 169        None  None  MIC     uM  UO_0000065        None   37.6
# ...         ...   ...  ...    ...         ...         ...    ...
# 3195       None  None  MIC     uM  UO_0000065        None    7.8
# 3200       None  None  MIC     uM  UO_0000065        None  0.113
# 3277       None  None  MIC     uM  UO_0000065        None  128.0
# 3278       None  None  MIC     uM  UO_0000065        None    8.0
# 3279       None  None  MIC     uM  UO_0000065        None   0.25
#
# [272 rows x 45 columns]

# %%
fix = []

for i in df.standard_value:
    fix.append(float(i))

STATUS = []

for i in fix:
    if i <20000:
        STATUS.append("Yes") #active
        
    elif 50000 <= i <= 100000:
        STATUS.append("No") #inactive
        
    else:
        STATUS.append("IN") #intermediate     

df = df.drop('value', 1)
df['value'] = fix
df['Activity'] = STATUS
df
# Out:
# <ipython-input-56-b12e53e9fad3>:18: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df = df.drop('value', 1)
#      activity_comment  activity_id  \
# 158              None       223405
# 162              None       224766
# 163              None       224777
# 168              None       227400
# 169              None       227411
# ...               ...          ...
# 3195             None     20697470
# 3200             None     22387449
# 3277             None     24425142
# 3278             None     24425143
# 3279             None     24425144
#
#                                     activity_properties assay_chembl_id  \
# 158                                                  []    CHEMBL703222
# 162                                                  []    CHEMBL703222
# 163                                                  []    CHEMBL703222
# 168                                                  []    CHEMBL703222
# 169                                                  []    CHEMBL703222
# ...                                                 ...             ...
# 3195                                                 []   CHEMBL4627144
# 3200                                                 []   CHEMBL4666296
# 3277  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5049862
# 3278  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5049862
# 3279  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5049862
#
#                                       assay_description assay_type  \
# 158   Antibacterial activity against Klebsiella aero...          F
# 162   Antibacterial activity against Klebsiella aero...          F
# 163   Antibacterial activity against Klebsiella aero...          F
# 168   Antibacterial activity against Klebsiella aero...          F
# 169   Antibacterial activity against Klebsiella aero...          F
# ...                                                 ...        ...
# 3195  Antibacterial activity against Enterobacter ae...          A
# 3200  Antibacterial activity against Enterobacter ae...          F
# 3277  Antibacterial activity against Klebsiella aero...          F
# 3278  Antibacterial activity against Klebsiella aero...          F
# 3279  Antibacterial activity against Klebsiella aero...          F
#
#      assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 158                     None                   None  BAO_0002146  BAO_0000218
# 162                     None                   None  BAO_0002146  BAO_0000218
# 163                     None                   None  BAO_0002146  BAO_0000218
# 168                     None                   None  BAO_0002146  BAO_0000218
# 169                     None                   None  BAO_0002146  BAO_0000218
# ...                      ...                    ...          ...          ...
# 3195                    None                   None  BAO_0002146  BAO_0000218
# 3200                    None                   None  BAO_0002146  BAO_0000218
# 3277                    None                   None  BAO_0002146  BAO_0000218
# 3278                    None                   None  BAO_0002146  BAO_0000218
# 3279                    None                   None  BAO_0002146  BAO_0000218
#
#       ...      target_pref_name target_tax_id text_value  toid type units  \
# 158   ...  Klebsiella aerogenes           548       None  None  MIC    uM
# 162   ...  Klebsiella aerogenes           548       None  None  MIC    uM
# 163   ...  Klebsiella aerogenes           548       None  None  MIC    uM
# 168   ...  Klebsiella aerogenes           548       None  None  MIC    uM
# 169   ...  Klebsiella aerogenes           548       None  None  MIC    uM
# ...   ...                   ...           ...        ...   ...  ...   ...
# 3195  ...  Klebsiella aerogenes           548       None  None  MIC    uM
# 3200  ...  Klebsiella aerogenes           548       None  None  MIC    uM
# 3277  ...  Klebsiella aerogenes           548       None  None  MIC    uM
# 3278  ...  Klebsiella aerogenes           548       None  None  MIC    uM
# 3279  ...  Klebsiella aerogenes           548       None  None  MIC    uM
#
#         uo_units upper_value     value Activity
# 158   UO_0000065        None  121000.0       IN
# 162   UO_0000065        None   15900.0      Yes
# 163   UO_0000065        None   70200.0       No
# 168   UO_0000065        None  147000.0       IN
# 169   UO_0000065        None   37600.0       IN
# ...          ...         ...       ...      ...
# 3195  UO_0000065        None    7800.0      Yes
# 3200  UO_0000065        None     113.0      Yes
# 3277  UO_0000065        None  128000.0       IN
# 3278  UO_0000065        None    8000.0      Yes
# 3279  UO_0000065        None     250.0      Yes
#
# [272 rows x 46 columns]

# %%
# considering nM unit for MIC
df = df[(df['Activity'] != 'IN')]
len(df)
# Out:
# 131

# %%
df.to_csv('/content/bioactivity_data_MIC_KA.csv', index=False)
