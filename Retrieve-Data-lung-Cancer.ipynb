# %% [markdown]
# <a href="https://colab.research.google.com/github/Jahan08/Amber-tutorial/blob/main/Retrieve-Data-lung-Cancer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install chembl_webresource_client
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 KB 1.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 KB 3.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: attrs
#     Found existing installation: attrs 22.2.0
#     Uninstalling attrs-22.2.0:
#       Successfully uninstalled attrs-22.2.0
# ...

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %%
target = new_client.target
target_query = target.search('HOP-62')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#    cross_references      organism                               pref_name  \
# 0                []  Homo sapiens                                  HOP-62
# 1                []  Homo sapiens                                  HOP-18
# 2                []  Homo sapiens                                  HOP-19
# 3                []  Homo sapiens                                  HOP-92
# 4                []  Homo sapiens           G-protein coupled receptor 62
# 5                []  Homo sapiens                                 UACC-62
# 6                []          None                                Clone 62
# 7                []  Homo sapiens                                  CAL-62
# 8                []  Homo sapiens                                  KNS-62
# 9                []  Homo sapiens         Stress-induced-phosphoprotein 1
# 10               []  Homo sapiens  Panel NCI-62 (62 carcinoma cell lines)
# 11               []  Homo sapiens              Kinesin-like protein KIF15
# ...

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL614643'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="GI50")

# %%
df = pd.DataFrame.from_dict(res)
df

# %%
# considering nM unit for MIC
#df = df[(df['standard_type'] == 'GI50')]
#df = df[(df['standard_type'] == 'IC50')]
#df = df[(df['standard_type'] == 'EC50')]
df = df[(df['standard_units'] == 'nM')]
df = df[(df['relation'] == '=')]
df = df[df.canonical_smiles.notna()]
df = df[df.standard_value.notna()]
df
# Out:
#     activity_comment  activity_id  \
# 0               None       401231
# 1               None       403900
# 2               None       412691
# 3               None       425303
# 4               None       427826
# ..               ...          ...
# 311             None     19126466
# 312             None     19126467
# 313             None     22483600
# 314             None     22850570
# 315             None     22850571
#
#                                    activity_properties assay_chembl_id  \
# 0                                                   []    CHEMBL695473
# 1                                                   []    CHEMBL695473
# 2                                                   []    CHEMBL695473
# 3                                                   []    CHEMBL695473
# 4                                                   []    CHEMBL695473
# ..                                                 ...             ...
# ...

# %%
fix = []

for i in df.standard_value:
    fix.append(float(i))

STATUS = []

for i in fix:
    if i < 1000:
        STATUS.append("Yes") #active
        
    elif 20000 <= i <= 100000:
        STATUS.append("No") #inactive
        
    else:
        STATUS.append("IN") #intermediate     

df = df.drop('value', 1)
df['value'] = fix
df['Activity'] = STATUS
df
# Out:
# <ipython-input-138-d453deb383ef>:18: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df = df.drop('value', 1)
#     activity_comment  activity_id  \
# 0               None       401231
# 1               None       403900
# 2               None       412691
# 3               None       425303
# 4               None       427826
# ..               ...          ...
# 311             None     19126466
# 312             None     19126467
# 313             None     22483600
# 314             None     22850570
# 315             None     22850571
#
#                                    activity_properties assay_chembl_id  \
# 0                                                   []    CHEMBL695473
# 1                                                   []    CHEMBL695473
# 2                                                   []    CHEMBL695473
# ...

# %%
# considering nM unit for MIC
df = df[(df['Activity'] != 'IN')]
len(df)
# Out:
# 118

# %%
df.to_csv('/content/bioactivity_data_HOP-62_IC50.csv', index=False)
