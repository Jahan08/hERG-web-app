# %% [markdown]
# <a href="https://colab.research.google.com/github/Jahan08/Amber-tutorial/blob/main/Gram_negative.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install chembl_webresource_client
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 KB 1.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 KB 3.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: attrs
#     Found existing installation: attrs 22.2.0
#     Uninstalling attrs-22.2.0:
#       Successfully uninstalled attrs-22.2.0
# ...

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %%
target = new_client.target
target_query = target.search('Neisseria gonorrhoeae')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references                organism  \
# 0                                                 []   Neisseria gonorrhoeae
# 1                                                 []               Neisseria
# 2                                                 []  Neisseria meningitidis
# 3                                                 []         Neisseria sicca
# 4                                                 []      Neisseria perflava
# 5                                                 []   Neisseria gonorrhoeae
# 6                                                 []   Neisseria gonorrhoeae
# 7  [{'xref_id': 'P04174', 'xref_name': None, 'xre...   Neisseria gonorrhoeae
# 8  [{'xref_id': 'P09790', 'xref_name': None, 'xre...   Neisseria gonorrhoeae
#
#                  pref_name  score  species_group_flag target_chembl_id  \
# 0    Neisseria gonorrhoeae   33.0               False     CHEMBL614430
# ...

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL614430'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="MIC")

# %%
df = pd.DataFrame.from_dict(res)
df
# Out:
#     activity_comment  activity_id  \
# 0               None        34019
# 1               None        34113
# 2               None        36500
# 3               None        37388
# 4               None        39745
# ..               ...          ...
# 894             None     22987502
# 895             None     22987503
# 896             None     22987504
# 897             None     22987505
# 898             None     24513259
#
#                                    activity_properties assay_chembl_id  \
# 0                                                   []    CHEMBL750222
# 1                                                   []    CHEMBL750222
# 2                                                   []    CHEMBL750222
# 3                                                   []    CHEMBL750220
# 4                                                   []    CHEMBL750220
# ..                                                 ...             ...
# ...

# %%
df = pd.read_csv('/content/bioactivity_data_UO-31.csv', header = 0)
# Out:
# <ipython-input-176-0c86e62881e9>:1: DtypeWarning: Columns (15,25,28,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/bioactivity_data_UO-31.csv', header = 0)

# %%
# considering nM unit for MIC
#df = df[(df['standard_type'] == 'GI50')]
#df = df[(df['standard_type'] == 'IC50')]
#df = df[(df['standard_type'] == 'EC50')]
df = df[(df['standard_units'] == 'nM')]
#df = df[(df['relation'] == '=')]
df = df[df.canonical_smiles.notna()]
df = df[df.standard_value.notna()]
df
# Out:
#     activity_comment  activity_id activity_properties assay_chembl_id  \
# 27              None        73099                  []    CHEMBL753614
# 28              None        73112                  []    CHEMBL753614
# 29              None        75211                  []    CHEMBL753614
# 30              None        79721                  []    CHEMBL753614
# 31              None        84134                  []    CHEMBL753614
# 32              None        92094                  []    CHEMBL753614
# 33              None        93112                  []    CHEMBL753614
# 34              None        96028                  []    CHEMBL753614
# 35              None       100976                  []    CHEMBL753614
# 36              None       101106                  []    CHEMBL753614
# 37              None       101114                  []    CHEMBL753614
# 38              None       104026                  []    CHEMBL753614
# ...

# %%
fix = []

for i in df.standard_value:
    fix.append(float(i))

STATUS = []

for i in fix:
    if i < 20000:
        STATUS.append("Yes") #active
        
    elif 50000 <= i <= 100000:
        STATUS.append("No") #inactive
        
    else:
        STATUS.append("IN") #intermediate     

df = df.drop('value', 1)
df['value'] = fix
df['Activity'] = STATUS
df
# Out:
# <ipython-input-27-12988964c194>:18: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df = df.drop('value', 1)
#     activity_comment  activity_id activity_properties assay_chembl_id  \
# 27              None        73099                  []    CHEMBL753614
# 28              None        73112                  []    CHEMBL753614
# 29              None        75211                  []    CHEMBL753614
# 30              None        79721                  []    CHEMBL753614
# 31              None        84134                  []    CHEMBL753614
# 32              None        92094                  []    CHEMBL753614
# 33              None        93112                  []    CHEMBL753614
# 34              None        96028                  []    CHEMBL753614
# 35              None       100976                  []    CHEMBL753614
# 36              None       101106                  []    CHEMBL753614
# ...

# %%
# considering nM unit for MIC
df = df[(df['Activity'] != 'IN')]
len(df)
# Out:
# 14

# %%
df.to_csv('/content/bioactivity_data_MIC_NG.csv', index=False)
