# %% [markdown]
# <a href="https://colab.research.google.com/github/Jahan08/Amber-tutorial/blob/main/Mtb_dataset_manipulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install chembl_webresource_client
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.8-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 KB 6.0 MB/s eta 0:00:00
# Requirement already satisfied: easydict in /usr/local/lib/python3.8/dist-packages (from chembl_webresource_client) (1.10)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.8/dist-packages (from chembl_webresource_client) (1.24.3)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.8/dist-packages (from chembl_webresource_client) (2.25.1)
# Collecting requests-cache~=0.7.0
#   Downloading requests_cache-0.7.5-py3-none-any.whl (39 kB)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.18.4->chembl_webresource_client) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2022.12.7)
# Collecting attrs<22.0,>=21.2
#   Downloading attrs-21.4.0-py2.py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 KB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.4 in /usr/local/lib/python3.8/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (6.0)
# Collecting itsdangerous>=2.0.1
#   Downloading itsdangerous-2.1.2-py3-none-any.whl (15 kB)
# Collecting url-normalize<2.0,>=1.4
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from url-normalize<2.0,>=1.4->requests-cache~=0.7.0->chembl_webresource_client) (1.15.0)
# Installing collected packages: url-normalize, itsdangerous, attrs, requests-cache, chembl_webresource_client
#   Attempting uninstall: itsdangerous
#     Found existing installation: itsdangerous 1.1.0
#     Uninstalling itsdangerous-1.1.0:
#       Successfully uninstalled itsdangerous-1.1.0
#   Attempting uninstall: attrs
#     Found existing installation: attrs 22.2.0
#     Uninstalling attrs-22.2.0:
#       Successfully uninstalled attrs-22.2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# flask 1.1.4 requires itsdangerous<2.0,>=0.24, but you have itsdangerous 2.1.2 which is incompatible.
# Successfully installed attrs-21.4.0 chembl_webresource_client-0.10.8 itsdangerous-2.1.2 requests-cache-0.7.5 url-normalize-1.4.3

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# target serach for Mtb

# %%
target = new_client.target
target_query = target.search('mycobacterium tuberculosis')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#     cross_references                          organism  \
# 0                 []        Mycobacterium tuberculosis
# 1                 []  Mycobacterium tuberculosis H37Rv
# 2                 []  Mycobacterium tuberculosis H37Ra
# 3                 []                     Mycobacterium
# 4                 []        Mycobacterium tuberculosis
# ..               ...                               ...
# 117               []        Mycobacterium tuberculosis
# 118               []        Mycobacterium tuberculosis
# 119               []        Mycobacterium tuberculosis
# 120               []        Mycobacterium tuberculosis
# 121               []        Mycobacterium tuberculosis
#
#                                              pref_name  score  \
# 0                           Mycobacterium tuberculosis   27.0
# 1                     Mycobacterium tuberculosis H37Rv   24.0
# 2                     Mycobacterium tuberculosis H37Ra   24.0
# 3                                        Mycobacterium   13.0
# 4            PYRAZINAMIDASE/NICOTINAMIDAS PNCA (PZase)   13.0
# ..                                                 ...    ...
# 117                                       70S ribosome    7.0
# 118                                       ATP synthase    7.0
# 119                              Thioredoxin reductase    7.0
# 120  ATP-dependent Clp protease ATP-binding subunit...    7.0
# 121   1,4-dihydroxy-2-naphthoate octaprenyltransferase    7.0
#
#      species_group_flag target_chembl_id  \
# 0                 False        CHEMBL360
# 1                 False    CHEMBL2111188
# 2                 False    CHEMBL2366634
# 3                  True     CHEMBL614981
# 4                 False    CHEMBL1697663
# ..                  ...              ...
# 117               False    CHEMBL2363965
# 118               False    CHEMBL2364166
# 119               False    CHEMBL2390811
# 120               False    CHEMBL4630874
# 121               False    CHEMBL4879548
#
#                                      target_components  \
# 0                                                   []
# 1                                                   []
# 2                                                   []
# 3                                                   []
# 4    [{'accession': 'Q50575', 'component_descriptio...
# ..                                                 ...
# 117  [{'accession': 'P9WHE1', 'component_descriptio...
# 118  [{'accession': 'P9WPU9', 'component_descriptio...
# 119  [{'accession': 'P9WHH1', 'component_descriptio...
# 120  [{'accession': 'P9WPC9', 'component_descriptio...
# 121  [{'accession': 'P9WIP3', 'component_descriptio...
#
#                       target_type  tax_id
# 0                        ORGANISM    1773
# 1                        ORGANISM   83332
# 2                        ORGANISM  419947
# 3                        ORGANISM    1763
# 4                  SINGLE PROTEIN    1773
# ..                            ...     ...
# 117  PROTEIN NUCLEIC-ACID COMPLEX    1773
# 118               PROTEIN COMPLEX    1773
# 119                SINGLE PROTEIN    1773
# 120                SINGLE PROTEIN    1773
# 121                SINGLE PROTEIN    1773
#
# [122 rows x 9 columns]

# %% [markdown]
# selecting the target

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL360'

# %%
activity = new_client.activity
SEL = activity.filter(target_chembl_id=selected_target)
df = pd.DataFrame.from_dict(SEL)
df
# Out:
#        activity_comment  activity_id  \
# 0        Not Determined        31883
# 1                  None        33041
# 2                  None        33985
# 3                  None        33986
# 4                  None        34021
# ...                 ...          ...
# 169139             None     23311398
# 169140             None     23311399
# 169141             None     23311524
# 169142             None     23311525
# 169143             None     23311526
#
#                                       activity_properties assay_chembl_id  \
# 0                                                      []    CHEMBL752464
# 1                                                      []    CHEMBL752463
# 2                                                      []    CHEMBL749419
# 3                                                      []    CHEMBL749419
# 4                                                      []    CHEMBL715914
# ...                                                   ...             ...
# 169139                                                 []   CHEMBL4844138
# 169140                                                 []   CHEMBL4844139
# 169141  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4844154
# 169142  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4844155
# 169143  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4844155
#
#                                         assay_description assay_type  \
# 0       Antimycobacterial activity against Mycobacteri...          F
# 1       Antimycobacterial activity against Mycobacteri...          F
# 2       Minimum inhibitory concentration against Mycob...          F
# 3       Minimum inhibitory concentration against Mycob...          F
# 4       In vitro antibacterial activity of compound ag...          F
# ...                                                   ...        ...
# 169139  Antimycobacterial activity against multi drug-...          F
# 169140  Antimycobacterial activity against rifampicin-...          F
# 169141  In vivo antimycobacterial activity against Myc...          F
# 169142  In vivo antimycobacterial activity against Myc...          F
# 169143  In vivo antimycobacterial activity against Myc...          F
#
#        assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0                         None                   None  BAO_0000201
# 1                         None                   None  BAO_0000201
# 2                         None                   None  BAO_0000179
# 3                         None                   None  BAO_0000179
# 4                         None                   None  BAO_0002146
# ...                        ...                    ...          ...
# 169139                    None                   None  BAO_0002146
# 169140                    None                   None  BAO_0002146
# 169141                    None                   None  BAO_0000181
# 169142                    None                   None  BAO_0002146
# 169143                    None                   None  BAO_0000179
#
#          bao_format  ...             target_organism  \
# 0       BAO_0000218  ...  Mycobacterium tuberculosis
# 1       BAO_0000218  ...  Mycobacterium tuberculosis
# 2       BAO_0000218  ...  Mycobacterium tuberculosis
# 3       BAO_0000218  ...  Mycobacterium tuberculosis
# 4       BAO_0000218  ...  Mycobacterium tuberculosis
# ...             ...  ...                         ...
# 169139  BAO_0000218  ...  Mycobacterium tuberculosis
# 169140  BAO_0000218  ...  Mycobacterium tuberculosis
# 169141  BAO_0000218  ...  Mycobacterium tuberculosis
# 169142  BAO_0000218  ...  Mycobacterium tuberculosis
# 169143  BAO_0000218  ...  Mycobacterium tuberculosis
#
#                   target_pref_name target_tax_id text_value  toid        type  \
# 0       Mycobacterium tuberculosis          1773       None  None  Inhibition
# 1       Mycobacterium tuberculosis          1773       None  None  Inhibition
# 2       Mycobacterium tuberculosis          1773       None  None        pMIC
# 3       Mycobacterium tuberculosis          1773       None  None        pMIC
# 4       Mycobacterium tuberculosis          1773       None  None         MIC
# ...                            ...           ...        ...   ...         ...
# 169139  Mycobacterium tuberculosis          1773       None  None         MIC
# 169140  Mycobacterium tuberculosis          1773       None  None         MIC
# 169141  Mycobacterium tuberculosis          1773       None  None    Activity
# 169142  Mycobacterium tuberculosis          1773       None  None         MIC
# 169143  Mycobacterium tuberculosis          1773       None  None       fIC50
#
#            units    uo_units upper_value value
# 0           None  UO_0000187        None  None
# 1              %  UO_0000187        None   0.0
# 2           None        None        None  1.92
# 3           None        None        None  1.82
# 4        ug ml-1  UO_0000274        None   0.5
# ...          ...         ...         ...   ...
# 169139        uM  UO_0000065        None  60.0
# 169140        uM  UO_0000065        None  60.0
# 169141  log10CFU        None        None   2.0
# 169142        uM  UO_0000065        None   9.1
# 169143        uM  UO_0000064        None  11.0
#
# [169144 rows x 45 columns]

# %% [markdown]
# Consider MIC as Bioactivity property

# %%
df.to_csv('bioactivity_data_Mtb_raw_data.csv', index=False)

# %%
import pandas as pd 
df = pd.read_csv('/content/bioactivity_data_Mtb_raw_data.csv', header = 0)
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (0,12,13,15,19) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#      activity_comment  activity_id  \
# 0                None       347357
# 1                None       364157
# 2      Not Determined       948666
# 3      Not Determined       952655
# 4      Not Determined       955268
# ...               ...          ...
# 1341             None     22905901
# 1342             None     23195633
# 1343             None     23195634
# 1344             None     23195635
# 1345             None     23228723
#
#                                     activity_properties assay_chembl_id  \
# 0                                                    []    CHEMBL747092
# 1                                                    []    CHEMBL747092
# 2                                                    []    CHEMBL748922
# 3                                                    []    CHEMBL748922
# 4                                                    []    CHEMBL748922
# ...                                                 ...             ...
# 1341                                                 []   CHEMBL4733164
# 1342  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4819638
# 1343  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4819638
# 1344  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4819638
# 1345                                                 []   CHEMBL4826255
#
#                                       assay_description assay_type  \
# 0     Concentration required for inhibition of growt...          F
# 1     Concentration required for inhibition of growt...          F
# 2     Inhibitory concentration against Mycobacterium...          F
# 3     Inhibitory concentration against Mycobacterium...          F
# 4     Inhibitory concentration against Mycobacterium...          F
# ...                                                 ...        ...
# 1341  Antimycobacterial activity against Mycobacteri...          F
# 1342  Antibacterial activity against Mycobacterium t...          F
# 1343  Antibacterial activity against Mycobacterium t...          F
# 1344  Antibacterial activity against Mycobacterium t...          F
# 1345  Antibacterial activity against Mycobacterium t...          F
#
#      assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                       None                   None  BAO_0000190  BAO_0000218
# 1                       None                   None  BAO_0000190  BAO_0000218
# 2                       None                   None  BAO_0000190  BAO_0000218
# 3                       None                   None  BAO_0000190  BAO_0000218
# 4                       None                   None  BAO_0000190  BAO_0000218
# ...                      ...                    ...          ...          ...
# 1341                    None                   None  BAO_0000190  BAO_0000218
# 1342                    None                   None  BAO_0000190  BAO_0000218
# 1343                    None                   None  BAO_0000190  BAO_0000218
# 1344                    None                   None  BAO_0000190  BAO_0000218
# 1345                    None                   None  BAO_0000190  BAO_0000218
#
#       ...             target_organism            target_pref_name  \
# 0     ...  Mycobacterium tuberculosis  Mycobacterium tuberculosis
# 1     ...  Mycobacterium tuberculosis  Mycobacterium tuberculosis
# 2     ...  Mycobacterium tuberculosis  Mycobacterium tuberculosis
# 3     ...  Mycobacterium tuberculosis  Mycobacterium tuberculosis
# 4     ...  Mycobacterium tuberculosis  Mycobacterium tuberculosis
# ...   ...                         ...                         ...
# 1341  ...  Mycobacterium tuberculosis  Mycobacterium tuberculosis
# 1342  ...  Mycobacterium tuberculosis  Mycobacterium tuberculosis
# 1343  ...  Mycobacterium tuberculosis  Mycobacterium tuberculosis
# 1344  ...  Mycobacterium tuberculosis  Mycobacterium tuberculosis
# 1345  ...  Mycobacterium tuberculosis  Mycobacterium tuberculosis
#
#      target_tax_id text_value  toid  type    units    uo_units upper_value  \
# 0             1773       None  None  IC50  ug ml-1  UO_0000274        None
# 1             1773       None  None  IC50  ug ml-1  UO_0000274        None
# 2             1773       None  None  IC50     None        None        None
# 3             1773       None  None  IC50     None        None        None
# 4             1773       None  None  IC50     None        None        None
# ...            ...        ...   ...   ...      ...         ...         ...
# 1341          1773       None  None  IC50       uM  UO_0000065        None
# 1342          1773       None  None  IC50       uM  UO_0000065        None
# 1343          1773       None  None  IC50       uM  UO_0000065        None
# 1344          1773       None  None  IC50       uM  UO_0000065        None
# 1345          1773       None  None  IC50       uM  UO_0000065        None
#
#       value
# 0      10.0
# 1     147.0
# 2      None
# 3      None
# 4      None
# ...     ...
# 1341    0.4
# 1342   24.7
# 1343   0.25
# 1344    0.1
# 1345    1.1
#
# [1346 rows x 45 columns]

# %%
df.to_csv('bioactivity_data_Mtb_IC50.csv', index=False)

# %%
# considering nM unit for MIC
df = df[(df['standard_units'] == 'nM')]
len(df)
# Out:
# 1065

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %%
df
# Out:
#      activity_comment  activity_id  \
# 16               None      1610787
# 17               None      1610790
# 18               None      1618276
# 19               None      1618279
# 20               None      1618282
# ...               ...          ...
# 1341             None     22905901
# 1342             None     23195633
# 1343             None     23195634
# 1344             None     23195635
# 1345             None     23228723
#
#                                     activity_properties assay_chembl_id  \
# 16                                                   []    CHEMBL885133
# 17                                                   []    CHEMBL885133
# 18                                                   []    CHEMBL885133
# 19                                                   []    CHEMBL885133
# 20                                                   []    CHEMBL885133
# ...                                                 ...             ...
# 1341                                                 []   CHEMBL4733164
# 1342  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4819638
# 1343  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4819638
# 1344  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4819638
# 1345                                                 []   CHEMBL4826255
#
#                                       assay_description assay_type  \
# 16    In vitro inhibitory concentration against Myco...          F
# 17    In vitro inhibitory concentration against Myco...          F
# 18    In vitro inhibitory concentration against Myco...          F
# 19    In vitro inhibitory concentration against Myco...          F
# 20    In vitro inhibitory concentration against Myco...          F
# ...                                                 ...        ...
# 1341  Antimycobacterial activity against Mycobacteri...          F
# 1342  Antibacterial activity against Mycobacterium t...          F
# 1343  Antibacterial activity against Mycobacterium t...          F
# 1344  Antibacterial activity against Mycobacterium t...          F
# 1345  Antibacterial activity against Mycobacterium t...          F
#
#      assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 16                      None                   None  BAO_0000190  BAO_0000218
# 17                      None                   None  BAO_0000190  BAO_0000218
# 18                      None                   None  BAO_0000190  BAO_0000218
# 19                      None                   None  BAO_0000190  BAO_0000218
# 20                      None                   None  BAO_0000190  BAO_0000218
# ...                      ...                    ...          ...          ...
# 1341                    None                   None  BAO_0000190  BAO_0000218
# 1342                    None                   None  BAO_0000190  BAO_0000218
# 1343                    None                   None  BAO_0000190  BAO_0000218
# 1344                    None                   None  BAO_0000190  BAO_0000218
# 1345                    None                   None  BAO_0000190  BAO_0000218
#
#       ...             target_organism            target_pref_name  \
# 16    ...  Mycobacterium tuberculosis  Mycobacterium tuberculosis
# 17    ...  Mycobacterium tuberculosis  Mycobacterium tuberculosis
# 18    ...  Mycobacterium tuberculosis  Mycobacterium tuberculosis
# 19    ...  Mycobacterium tuberculosis  Mycobacterium tuberculosis
# 20    ...  Mycobacterium tuberculosis  Mycobacterium tuberculosis
# ...   ...                         ...                         ...
# 1341  ...  Mycobacterium tuberculosis  Mycobacterium tuberculosis
# 1342  ...  Mycobacterium tuberculosis  Mycobacterium tuberculosis
# 1343  ...  Mycobacterium tuberculosis  Mycobacterium tuberculosis
# 1344  ...  Mycobacterium tuberculosis  Mycobacterium tuberculosis
# 1345  ...  Mycobacterium tuberculosis  Mycobacterium tuberculosis
#
#      target_tax_id text_value  toid  type  units    uo_units upper_value  \
# 16            1773       None  None  IC50     uM  UO_0000065        None
# 17            1773       None  None  IC50     uM  UO_0000065        None
# 18            1773       None  None  IC50     uM  UO_0000065        None
# 19            1773       None  None  IC50     uM  UO_0000065        None
# 20            1773       None  None  IC50     uM  UO_0000065        None
# ...            ...        ...   ...   ...    ...         ...         ...
# 1341          1773       None  None  IC50     uM  UO_0000065        None
# 1342          1773       None  None  IC50     uM  UO_0000065        None
# 1343          1773       None  None  IC50     uM  UO_0000065        None
# 1344          1773       None  None  IC50     uM  UO_0000065        None
# 1345          1773       None  None  IC50     uM  UO_0000065        None
#
#       value
# 16    13.97
# 17    45.57
# 18     20.0
# 19    18.35
# 20    15.76
# ...     ...
# 1341    0.4
# 1342   24.7
# 1343   0.25
# 1344    0.1
# 1345    1.1
#
# [1065 rows x 45 columns]

# %%
df.to_csv('bioactivity_data_Mtb_IC50_nM.csv', index=False)

# %% [markdown]
# handling the missing data

# %%
df = df[df.standard_value.notna()]
df = df[df.value.notna()]
df
# Out:
#      activity_comment  activity_id  \
# 16               None      1610787
# 17               None      1610790
# 18               None      1618276
# 19               None      1618279
# 20               None      1618282
# ...               ...          ...
# 1341             None     22905901
# 1342             None     23195633
# 1343             None     23195634
# 1344             None     23195635
# 1345             None     23228723
#
#                                     activity_properties assay_chembl_id  \
# 16                                                   []    CHEMBL885133
# 17                                                   []    CHEMBL885133
# 18                                                   []    CHEMBL885133
# 19                                                   []    CHEMBL885133
# 20                                                   []    CHEMBL885133
# ...                                                 ...             ...
# 1341                                                 []   CHEMBL4733164
# 1342  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4819638
# 1343  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4819638
# 1344  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4819638
# 1345                                                 []   CHEMBL4826255
#
#                                       assay_description assay_type  \
# 16    In vitro inhibitory concentration against Myco...          F
# 17    In vitro inhibitory concentration against Myco...          F
# 18    In vitro inhibitory concentration against Myco...          F
# 19    In vitro inhibitory concentration against Myco...          F
# 20    In vitro inhibitory concentration against Myco...          F
# ...                                                 ...        ...
# 1341  Antimycobacterial activity against Mycobacteri...          F
# 1342  Antibacterial activity against Mycobacterium t...          F
# 1343  Antibacterial activity against Mycobacterium t...          F
# 1344  Antibacterial activity against Mycobacterium t...          F
# 1345  Antibacterial activity against Mycobacterium t...          F
#
#      assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 16                      None                   None  BAO_0000190  BAO_0000218
# 17                      None                   None  BAO_0000190  BAO_0000218
# 18                      None                   None  BAO_0000190  BAO_0000218
# 19                      None                   None  BAO_0000190  BAO_0000218
# 20                      None                   None  BAO_0000190  BAO_0000218
# ...                      ...                    ...          ...          ...
# 1341                    None                   None  BAO_0000190  BAO_0000218
# 1342                    None                   None  BAO_0000190  BAO_0000218
# 1343                    None                   None  BAO_0000190  BAO_0000218
# 1344                    None                   None  BAO_0000190  BAO_0000218
# 1345                    None                   None  BAO_0000190  BAO_0000218
#
#       ...             target_organism            target_pref_name  \
# 16    ...  Mycobacterium tuberculosis  Mycobacterium tuberculosis
# 17    ...  Mycobacterium tuberculosis  Mycobacterium tuberculosis
# 18    ...  Mycobacterium tuberculosis  Mycobacterium tuberculosis
# 19    ...  Mycobacterium tuberculosis  Mycobacterium tuberculosis
# 20    ...  Mycobacterium tuberculosis  Mycobacterium tuberculosis
# ...   ...                         ...                         ...
# 1341  ...  Mycobacterium tuberculosis  Mycobacterium tuberculosis
# 1342  ...  Mycobacterium tuberculosis  Mycobacterium tuberculosis
# 1343  ...  Mycobacterium tuberculosis  Mycobacterium tuberculosis
# 1344  ...  Mycobacterium tuberculosis  Mycobacterium tuberculosis
# 1345  ...  Mycobacterium tuberculosis  Mycobacterium tuberculosis
#
#      target_tax_id text_value  toid  type  units    uo_units upper_value  \
# 16            1773       None  None  IC50     uM  UO_0000065        None
# 17            1773       None  None  IC50     uM  UO_0000065        None
# 18            1773       None  None  IC50     uM  UO_0000065        None
# 19            1773       None  None  IC50     uM  UO_0000065        None
# 20            1773       None  None  IC50     uM  UO_0000065        None
# ...            ...        ...   ...   ...    ...         ...         ...
# 1341          1773       None  None  IC50     uM  UO_0000065        None
# 1342          1773       None  None  IC50     uM  UO_0000065        None
# 1343          1773       None  None  IC50     uM  UO_0000065        None
# 1344          1773       None  None  IC50     uM  UO_0000065        None
# 1345          1773       None  None  IC50     uM  UO_0000065        None
#
#       value
# 16    13.97
# 17    45.57
# 18     20.0
# 19    18.35
# 20    15.76
# ...     ...
# 1341    0.4
# 1342   24.7
# 1343   0.25
# 1344    0.1
# 1345    1.1
#
# [1065 rows x 45 columns]

# %%
df = df[df.canonical_smiles.notna()]
df
# Out:
#      activity_comment  activity_id  \
# 16               None      1610787
# 17               None      1610790
# 18               None      1618276
# 19               None      1618279
# 20               None      1618282
# ...               ...          ...
# 1341             None     22905901
# 1342             None     23195633
# 1343             None     23195634
# 1344             None     23195635
# 1345             None     23228723
#
#                                     activity_properties assay_chembl_id  \
# 16                                                   []    CHEMBL885133
# 17                                                   []    CHEMBL885133
# 18                                                   []    CHEMBL885133
# 19                                                   []    CHEMBL885133
# 20                                                   []    CHEMBL885133
# ...                                                 ...             ...
# 1341                                                 []   CHEMBL4733164
# 1342  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4819638
# 1343  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4819638
# 1344  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4819638
# 1345                                                 []   CHEMBL4826255
#
#                                       assay_description assay_type  \
# 16    In vitro inhibitory concentration against Myco...          F
# 17    In vitro inhibitory concentration against Myco...          F
# 18    In vitro inhibitory concentration against Myco...          F
# 19    In vitro inhibitory concentration against Myco...          F
# 20    In vitro inhibitory concentration against Myco...          F
# ...                                                 ...        ...
# 1341  Antimycobacterial activity against Mycobacteri...          F
# 1342  Antibacterial activity against Mycobacterium t...          F
# 1343  Antibacterial activity against Mycobacterium t...          F
# 1344  Antibacterial activity against Mycobacterium t...          F
# 1345  Antibacterial activity against Mycobacterium t...          F
#
#      assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 16                      None                   None  BAO_0000190  BAO_0000218
# 17                      None                   None  BAO_0000190  BAO_0000218
# 18                      None                   None  BAO_0000190  BAO_0000218
# 19                      None                   None  BAO_0000190  BAO_0000218
# 20                      None                   None  BAO_0000190  BAO_0000218
# ...                      ...                    ...          ...          ...
# 1341                    None                   None  BAO_0000190  BAO_0000218
# 1342                    None                   None  BAO_0000190  BAO_0000218
# 1343                    None                   None  BAO_0000190  BAO_0000218
# 1344                    None                   None  BAO_0000190  BAO_0000218
# 1345                    None                   None  BAO_0000190  BAO_0000218
#
#       ...             target_organism            target_pref_name  \
# 16    ...  Mycobacterium tuberculosis  Mycobacterium tuberculosis
# 17    ...  Mycobacterium tuberculosis  Mycobacterium tuberculosis
# 18    ...  Mycobacterium tuberculosis  Mycobacterium tuberculosis
# 19    ...  Mycobacterium tuberculosis  Mycobacterium tuberculosis
# 20    ...  Mycobacterium tuberculosis  Mycobacterium tuberculosis
# ...   ...                         ...                         ...
# 1341  ...  Mycobacterium tuberculosis  Mycobacterium tuberculosis
# 1342  ...  Mycobacterium tuberculosis  Mycobacterium tuberculosis
# 1343  ...  Mycobacterium tuberculosis  Mycobacterium tuberculosis
# 1344  ...  Mycobacterium tuberculosis  Mycobacterium tuberculosis
# 1345  ...  Mycobacterium tuberculosis  Mycobacterium tuberculosis
#
#      target_tax_id text_value  toid  type  units    uo_units upper_value  \
# 16            1773       None  None  IC50     uM  UO_0000065        None
# 17            1773       None  None  IC50     uM  UO_0000065        None
# 18            1773       None  None  IC50     uM  UO_0000065        None
# 19            1773       None  None  IC50     uM  UO_0000065        None
# 20            1773       None  None  IC50     uM  UO_0000065        None
# ...            ...        ...   ...   ...    ...         ...         ...
# 1341          1773       None  None  IC50     uM  UO_0000065        None
# 1342          1773       None  None  IC50     uM  UO_0000065        None
# 1343          1773       None  None  IC50     uM  UO_0000065        None
# 1344          1773       None  None  IC50     uM  UO_0000065        None
# 1345          1773       None  None  IC50     uM  UO_0000065        None
#
#       value
# 16    13.97
# 17    45.57
# 18     20.0
# 19    18.35
# 20    15.76
# ...     ...
# 1341    0.4
# 1342   24.7
# 1343   0.25
# 1344    0.1
# 1345    1.1
#
# [1065 rows x 45 columns]

# %% [markdown]
# Define the activity
#
# <=1000 nM active
# rather inactive

# %%
fix = []

for i in df.standard_value:
    fix.append(float(i))

# %%
STATUS = []

for i in fix:
    if i <=10000:
        STATUS.append("Yes") #active
        
    #elif i >=10000:
        #STATUS.append("No") #inactive
        
    else:
        STATUS.append("No") #intermediate

# %%
df = df.drop('value', 1)
df['value'] = fix
df['Activity'] = STATUS
df.head(3)
# Out:
# <ipython-input-20-90299a80648f>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df = df.drop('value', 1)
#    activity_comment  activity_id activity_properties assay_chembl_id  \
# 16             None      1610787                  []    CHEMBL885133
# 17             None      1610790                  []    CHEMBL885133
# 18             None      1618276                  []    CHEMBL885133
#
#                                     assay_description assay_type  \
# 16  In vitro inhibitory concentration against Myco...          F
# 17  In vitro inhibitory concentration against Myco...          F
# 18  In vitro inhibitory concentration against Myco...          F
#
#    assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 16                    None                   None  BAO_0000190  BAO_0000218
# 17                    None                   None  BAO_0000190  BAO_0000218
# 18                    None                   None  BAO_0000190  BAO_0000218
#
#     ...            target_pref_name target_tax_id text_value  toid  type  \
# 16  ...  Mycobacterium tuberculosis          1773       None  None  IC50
# 17  ...  Mycobacterium tuberculosis          1773       None  None  IC50
# 18  ...  Mycobacterium tuberculosis          1773       None  None  IC50
#
#    units    uo_units upper_value    value Activity
# 16    uM  UO_0000065        None  13970.0       No
# 17    uM  UO_0000065        None  45570.0       No
# 18    uM  UO_0000065        None  20000.0       No
#
# [3 rows x 46 columns]

# %%
selection = ['molecule_chembl_id', 'canonical_smiles', 'standard_type', 'standard_value', 'standard_units', 'Activity']
df2 = df[selection]
df2
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 16         CHEMBL196076  C/C(=N/NC(=O)c1ccncc1)c1cccc(CN2CCN(c3ccc(F)cc...
# 17             CHEMBL64                                    NNC(=O)c1ccncc1
# 18         CHEMBL382508            C/C(=N/NC(=O)c1ccncc1)c1cccc(CN(C)C)c1O
# 19         CHEMBL371672          CCN(CC)Cc1cccc(/C(C)=N\NC(=O)c2ccncc2)c1O
# 20         CHEMBL198453      CCCCN(CCCC)Cc1cccc(/C(C)=N\NC(=O)c2ccncc2)c1O
# ...                 ...                                                ...
# 1341      CHEMBL4795102        O=C(CCCC(F)(F)F)C1CCC(c2nc(-c3nccs3)no2)CC1
# 1342      CHEMBL4869028  CCCCCc1ccc(-c2cn(CCC[C@@H]3CO[C@H](COS(=O)(=O)...
# 1343           CHEMBL32  COc1c(N2C[C@@H]3CCCN[C@@H]3C2)c(F)cc2c(=O)c(C(...
# 1344           CHEMBL64                                    NNC(=O)c1ccncc1
# 1345      CHEMBL3603852  Nc1nc2c(ncn2CCN(CCOCc2ccccc2)CCP(=O)(O)O)c(=O)...
#
#      standard_type standard_value standard_units Activity
# 16            IC50        13970.0             nM       No
# 17            IC50        45570.0             nM       No
# 18            IC50        20000.0             nM       No
# 19            IC50        18350.0             nM       No
# 20            IC50        15760.0             nM       No
# ...            ...            ...            ...      ...
# 1341          IC50          400.0             nM      Yes
# 1342          IC50        24700.0             nM       No
# 1343          IC50          250.0             nM      Yes
# 1344          IC50          100.0             nM      Yes
# 1345          IC50         1100.0             nM      Yes
#
# [1065 rows x 6 columns]

# %%
df2.to_csv('bioactivity_preprocessed_data_Mtb_IC50_nM.csv', index=False)

# %%
# find the duplicate and unique molecule_chembl_id
import pandas as pd

df_dup = pd.concat(g for _, 
                    g in df.groupby("molecule_chembl_id") 
                      if len(g) > 1)
df_non = df.loc[~df.index.isin(df_dup.index)]

print (str(len(df_non)), 
       str(len(df_dup)), 
       str(len(df_dup)+len(df_non)))
# Out:
# 521 544 1065

# %%
len(df_non), len(df_non['molecule_chembl_id'].unique())
# Out:
# (521, 521)

# %%
df_dup
# Out:
#      activity_comment  activity_id  \
# 508              None     18312016
# 515              None     18312023
# 591              None     18456778
# 621              None     18456875
# 404              None     18104128
# ...               ...          ...
# 1310             None     22837498
# 1344             None     23195635
# 403              None     18104127
# 768              None     18690285
# 1312             None     22837500
#
#                                     activity_properties assay_chembl_id  \
# 508                                                  []   CHEMBL4132277
# 515                                                  []   CHEMBL4132278
# 591                                                  []   CHEMBL4179593
# 621                                                  []   CHEMBL4179594
# 404                                                  []   CHEMBL4022472
# ...                                                 ...             ...
# 1310                                                 []   CHEMBL4719106
# 1344  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4819638
# 403                                                  []   CHEMBL4022472
# 768                                                  []   CHEMBL4252975
# 1312                                                 []   CHEMBL4719106
#
#                                       assay_description assay_type  \
# 508   Antitubercular activity against Mycobacterium ...          F
# 515   Antitubercular activity against Mycobacterium ...          F
# 591   Antitubercular activity against Mycobacterium ...          F
# 621   Antitubercular activity against Mycobacterium ...          F
# 404   Antimicrobial activity against Mycobacterium t...          F
# ...                                                 ...        ...
# 1310  Antimycobacterial activity against Mycobacteri...          F
# 1344  Antibacterial activity against Mycobacterium t...          F
# 403   Antimicrobial activity against Mycobacterium t...          F
# 768   Antimycobacterial activity against Mycobacteri...          F
# 1312  Antimycobacterial activity against Mycobacteri...          F
#
#      assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 508                     None                   None  BAO_0000190  BAO_0000218
# 515                     None                   None  BAO_0000190  BAO_0000218
# 591                     None                   None  BAO_0000190  BAO_0000218
# 621                     None                   None  BAO_0000190  BAO_0000218
# 404                     None                   None  BAO_0000190  BAO_0000019
# ...                      ...                    ...          ...          ...
# 1310                    None                   None  BAO_0000190  BAO_0000218
# 1344                    None                   None  BAO_0000190  BAO_0000218
# 403                     None                   None  BAO_0000190  BAO_0000019
# 768                     None                   None  BAO_0000190  BAO_0000218
# 1312                    None                   None  BAO_0000190  BAO_0000218
#
#       ...            target_pref_name target_tax_id text_value  toid  type  \
# 508   ...  Mycobacterium tuberculosis          1773       None  None  IC50
# 515   ...  Mycobacterium tuberculosis          1773       None  None  IC50
# 591   ...  Mycobacterium tuberculosis          1773       None  None  IC50
# 621   ...  Mycobacterium tuberculosis          1773       None  None  IC50
# 404   ...  Mycobacterium tuberculosis          1773       None  None  IC50
# ...   ...                         ...           ...        ...   ...   ...
# 1310  ...  Mycobacterium tuberculosis          1773       None  None  IC50
# 1344  ...  Mycobacterium tuberculosis          1773       None  None  IC50
# 403   ...  Mycobacterium tuberculosis          1773       None  None  IC50
# 768   ...  Mycobacterium tuberculosis          1773       None  None  IC50
# 1312  ...  Mycobacterium tuberculosis          1773       None  None  IC50
#
#      units    uo_units upper_value     value Activity
# 508     uM  UO_0000065        None  200000.0       No
# 515     uM  UO_0000065        None   36000.0       No
# 591     uM  UO_0000065        None  200000.0       No
# 621     uM  UO_0000065        36.0   14000.0       No
# 404     uM  UO_0000065        None      70.0      Yes
# ...    ...         ...         ...       ...      ...
# 1310    uM  UO_0000065        None     180.0      Yes
# 1344    uM  UO_0000065        None     100.0      Yes
# 403     uM  UO_0000065        None   12470.0       No
# 768     uM  UO_0000065        None   20800.0       No
# 1312    uM  UO_0000065        None   12470.0       No
#
# [544 rows x 46 columns]

# %%
# mean and std of all duplicate
import numpy as np
import pandas as pd
from time import time

from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
import seaborn as sns
# %matplotlib inline

mean_std = df_dup.groupby(['molecule_chembl_id'], as_index=False).agg({'value':['mean', 'std']})
mean_std.head()
# Out:
#   molecule_chembl_id          value
#                                mean            std
# 0          CHEMBL137  112500.000000  101434.708064
# 1          CHEMBL177      73.333333       5.773503
# 2      CHEMBL2338333   10250.000000    6946.221995
# 3       CHEMBL255008  500000.000000       0.000000
# 4       CHEMBL255234   56000.000000   38183.766184

# %%
len(mean_std)
# Out:
# 170

# %%
df_dup = df_dup.merge(mean_std, on='molecule_chembl_id', how='inner')
len(df_dup)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:9190: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   return merge(
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py:4150: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# 544

# %%
#keep only SD less thab 2SD for duplicate chemblID

df_dup = df_dup[(df_dup[('value', 'std')] < 2)]
len(df_dup), len(df_dup['molecule_chembl_id'].unique())
# Out:
# (72, 36)

# %%
df_dup['select'] = (df_dup['value']- df_dup[('value', 'mean')]).abs()
#value_median = keep.groupby('chemblId')['value'].transform('median')

df_dup = df_dup.groupby(["molecule_chembl_id"]).apply(lambda x: x.sort_values(["select"], ascending = True)).reset_index(drop=True)
df_dup
# Out:
#    activity_comment  activity_id activity_properties assay_chembl_id  \
# 0              None      2164060                  []    CHEMBL932548
# 1              None      2164084                  []    CHEMBL932549
# 2              None      2164062                  []    CHEMBL932548
# 3              None      2164086                  []    CHEMBL932549
# 4              None      2164072                  []    CHEMBL932548
# ..              ...          ...                 ...             ...
# 67             None      2164078                  []    CHEMBL932549
# 68             None      2164064                  []    CHEMBL932548
# 69             None      2164088                  []    CHEMBL932549
# 70             None      2164066                  []    CHEMBL932548
# 71             None      2164090                  []    CHEMBL932549
#
#                                     assay_description assay_type  \
# 0   Antimycobacterial activity against Mycobacteri...          F
# 1   Antimycobacterial activity against Mycobacteri...          F
# 2   Antimycobacterial activity against Mycobacteri...          F
# 3   Antimycobacterial activity against Mycobacteri...          F
# 4   Antimycobacterial activity against Mycobacteri...          F
# ..                                                ...        ...
# 67  Antimycobacterial activity against Mycobacteri...          F
# 68  Antimycobacterial activity against Mycobacteri...          F
# 69  Antimycobacterial activity against Mycobacteri...          F
# 70  Antimycobacterial activity against Mycobacteri...          F
# 71  Antimycobacterial activity against Mycobacteri...          F
#
#    assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                     None                   None  BAO_0000190  BAO_0000218
# 1                     None                   None  BAO_0000190  BAO_0000218
# 2                     None                   None  BAO_0000190  BAO_0000218
# 3                     None                   None  BAO_0000190  BAO_0000218
# 4                     None                   None  BAO_0000190  BAO_0000218
# ..                     ...                    ...          ...          ...
# 67                    None                   None  BAO_0000190  BAO_0000218
# 68                    None                   None  BAO_0000190  BAO_0000218
# 69                    None                   None  BAO_0000190  BAO_0000218
# 70                    None                   None  BAO_0000190  BAO_0000218
# 71                    None                   None  BAO_0000190  BAO_0000218
#
#     ...  toid  type units    uo_units upper_value     value  Activity  \
# 0   ...  None  IC50    uM  UO_0000065        None  500000.0        No
# 1   ...  None  IC50    uM  UO_0000065        None  500000.0        No
# 2   ...  None  IC50    uM  UO_0000065        None  500000.0        No
# 3   ...  None  IC50    uM  UO_0000065        None  500000.0        No
# 4   ...  None  IC50    uM  UO_0000065        None  500000.0        No
# ..  ...   ...   ...   ...         ...         ...       ...       ...
# 67  ...  None  IC50    uM  UO_0000065        None  500000.0        No
# 68  ...  None  IC50    uM  UO_0000065        None  500000.0        No
# 69  ...  None  IC50    uM  UO_0000065        None  500000.0        No
# 70  ...  None  IC50    uM  UO_0000065        None  500000.0        No
# 71  ...  None  IC50    uM  UO_0000065        None  500000.0        No
#
#    (value, mean) (value, std) select
# 0       500000.0          0.0    0.0
# 1       500000.0          0.0    0.0
# 2       500000.0          0.0    0.0
# 3       500000.0          0.0    0.0
# 4       500000.0          0.0    0.0
# ..           ...          ...    ...
# 67      500000.0          0.0    0.0
# 68      500000.0          0.0    0.0
# 69      500000.0          0.0    0.0
# 70      500000.0          0.0    0.0
# 71      500000.0          0.0    0.0
#
# [72 rows x 49 columns]

# %%
df_dup = df_dup.drop_duplicates(subset='molecule_chembl_id', keep='first')
df_dup
# Out:
#    activity_comment  activity_id  \
# 0              None      2164060
# 2              None      2164062
# 4              None      2164072
# 6              None      2164048
# 8              None      2164070
# 10             None     22063523
# 12             None     22063598
# 14             None     22062063
# 16             None     22062065
# 18             None     22062067
# 20             None     22063440
# 22             None     22063445
# 24             None     22062140
# 26             None     22062231
# 28             None     22062237
# 30             None     22062908
# 32             None     22063105
# 34             None     22063473
# 36             None     22068095
# 38             None     22068410
# 40             None     22068412
# 42             None     22068497
# 44             None     22063390
# 46             None     22063533
# 48             None     22063447
# 50             None     22063449
# 52             None     22063457
# 54             None      2164056
# 56             None      2164068
# 58             None      2164052
# 60             None      2164058
# 62             None      2164074
# 64             None      2164100
# 66             None      2164054
# 68             None      2164064
# 70             None      2164066
#
#                                   activity_properties assay_chembl_id  \
# 0                                                  []    CHEMBL932548
# 2                                                  []    CHEMBL932548
# 4                                                  []    CHEMBL932548
# 6                                                  []    CHEMBL932548
# 8                                                  []    CHEMBL932548
# 10  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4649971
# 12  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4649971
# 14  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4649971
# 16  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4649971
# 18  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4649971
# 20  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4649971
# 22  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4649971
# 24  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4649971
# 26  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4649971
# 28  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4649971
# 30  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4649971
# 32  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4649971
# 34  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4649971
# 36  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4649971
# 38  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4649971
# 40  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4649971
# 42  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4649971
# 44  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4649971
# 46  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4649971
# 48  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4649971
# 50  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4649971
# 52  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4649971
# 54                                                 []    CHEMBL932548
# 56                                                 []    CHEMBL932548
# 58                                                 []    CHEMBL932548
# 60                                                 []    CHEMBL932548
# 62                                                 []    CHEMBL932548
# 64                                                 []    CHEMBL932548
# 66                                                 []    CHEMBL932548
# 68                                                 []    CHEMBL932548
# 70                                                 []    CHEMBL932548
#
#                                     assay_description assay_type  \
# 0   Antimycobacterial activity against Mycobacteri...          F
# 2   Antimycobacterial activity against Mycobacteri...          F
# 4   Antimycobacterial activity against Mycobacteri...          F
# 6   Antimycobacterial activity against Mycobacteri...          F
# 8   Antimycobacterial activity against Mycobacteri...          F
# 10                      Cornell M. t heat shock assay          F
# 12                      Cornell M. t heat shock assay          F
# 14                      Cornell M. t heat shock assay          F
# 16                      Cornell M. t heat shock assay          F
# 18                      Cornell M. t heat shock assay          F
# 20                      Cornell M. t heat shock assay          F
# 22                      Cornell M. t heat shock assay          F
# 24                      Cornell M. t heat shock assay          F
# 26                      Cornell M. t heat shock assay          F
# 28                      Cornell M. t heat shock assay          F
# 30                      Cornell M. t heat shock assay          F
# 32                      Cornell M. t heat shock assay          F
# 34                      Cornell M. t heat shock assay          F
# 36                      Cornell M. t heat shock assay          F
# 38                      Cornell M. t heat shock assay          F
# 40                      Cornell M. t heat shock assay          F
# 42                      Cornell M. t heat shock assay          F
# 44                      Cornell M. t heat shock assay          F
# 46                      Cornell M. t heat shock assay          F
# 48                      Cornell M. t heat shock assay          F
# 50                      Cornell M. t heat shock assay          F
# 52                      Cornell M. t heat shock assay          F
# 54  Antimycobacterial activity against Mycobacteri...          F
# 56  Antimycobacterial activity against Mycobacteri...          F
# 58  Antimycobacterial activity against Mycobacteri...          F
# 60  Antimycobacterial activity against Mycobacteri...          F
# 62  Antimycobacterial activity against Mycobacteri...          F
# 64  Antimycobacterial activity against Mycobacteri...          F
# 66  Antimycobacterial activity against Mycobacteri...          F
# 68  Antimycobacterial activity against Mycobacteri...          F
# 70  Antimycobacterial activity against Mycobacteri...          F
#
#    assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                     None                   None  BAO_0000190  BAO_0000218
# 2                     None                   None  BAO_0000190  BAO_0000218
# 4                     None                   None  BAO_0000190  BAO_0000218
# 6                     None                   None  BAO_0000190  BAO_0000218
# 8                     None                   None  BAO_0000190  BAO_0000218
# 10                    None                   None  BAO_0000190  BAO_0000218
# 12                    None                   None  BAO_0000190  BAO_0000218
# 14                    None                   None  BAO_0000190  BAO_0000218
# 16                    None                   None  BAO_0000190  BAO_0000218
# 18                    None                   None  BAO_0000190  BAO_0000218
# 20                    None                   None  BAO_0000190  BAO_0000218
# 22                    None                   None  BAO_0000190  BAO_0000218
# 24                    None                   None  BAO_0000190  BAO_0000218
# 26                    None                   None  BAO_0000190  BAO_0000218
# 28                    None                   None  BAO_0000190  BAO_0000218
# 30                    None                   None  BAO_0000190  BAO_0000218
# 32                    None                   None  BAO_0000190  BAO_0000218
# 34                    None                   None  BAO_0000190  BAO_0000218
# 36                    None                   None  BAO_0000190  BAO_0000218
# 38                    None                   None  BAO_0000190  BAO_0000218
# 40                    None                   None  BAO_0000190  BAO_0000218
# 42                    None                   None  BAO_0000190  BAO_0000218
# 44                    None                   None  BAO_0000190  BAO_0000218
# 46                    None                   None  BAO_0000190  BAO_0000218
# 48                    None                   None  BAO_0000190  BAO_0000218
# 50                    None                   None  BAO_0000190  BAO_0000218
# 52                    None                   None  BAO_0000190  BAO_0000218
# 54                    None                   None  BAO_0000190  BAO_0000218
# 56                    None                   None  BAO_0000190  BAO_0000218
# 58                    None                   None  BAO_0000190  BAO_0000218
# 60                    None                   None  BAO_0000190  BAO_0000218
# 62                    None                   None  BAO_0000190  BAO_0000218
# 64                    None                   None  BAO_0000190  BAO_0000218
# 66                    None                   None  BAO_0000190  BAO_0000218
# 68                    None                   None  BAO_0000190  BAO_0000218
# 70                    None                   None  BAO_0000190  BAO_0000218
#
#     ...  toid   type units    uo_units upper_value     value  Activity  \
# 0   ...  None   IC50    uM  UO_0000065        None  500000.0        No
# 2   ...  None   IC50    uM  UO_0000065        None  500000.0        No
# 4   ...  None   IC50    uM  UO_0000065        None  500000.0        No
# 6   ...  None   IC50    uM  UO_0000065        None  500000.0        No
# 8   ...  None   IC50    uM  UO_0000065        None  500000.0        No
# 10  ...  None  pIC50  None  UO_0000065        None  100000.0        No
# 12  ...  None  pIC50  None  UO_0000065        None  100000.0        No
# 14  ...  None  pIC50  None  UO_0000065        None  100000.0        No
# 16  ...  None  pIC50  None  UO_0000065        None  100000.0        No
# 18  ...  None  pIC50  None  UO_0000065        None  100000.0        No
# 20  ...  None  pIC50  None  UO_0000065        None  100000.0        No
# 22  ...  None  pIC50  None  UO_0000065        None  100000.0        No
# 24  ...  None  pIC50  None  UO_0000065        None  100000.0        No
# 26  ...  None  pIC50  None  UO_0000065        None  100000.0        No
# 28  ...  None  pIC50  None  UO_0000065        None  100000.0        No
# 30  ...  None  pIC50  None  UO_0000065        None  100000.0        No
# 32  ...  None  pIC50  None  UO_0000065        None  100000.0        No
# 34  ...  None  pIC50  None  UO_0000065        None  100000.0        No
# 36  ...  None  pIC50  None  UO_0000065        None  100000.0        No
# 38  ...  None  pIC50  None  UO_0000065        None  100000.0        No
# 40  ...  None  pIC50  None  UO_0000065        None  100000.0        No
# 42  ...  None  pIC50  None  UO_0000065        None  100000.0        No
# 44  ...  None  pIC50  None  UO_0000065        None  100000.0        No
# 46  ...  None  pIC50  None  UO_0000065        None  100000.0        No
# 48  ...  None  pIC50  None  UO_0000065        None  100000.0        No
# 50  ...  None  pIC50  None  UO_0000065        None  100000.0        No
# 52  ...  None  pIC50  None  UO_0000065        None  100000.0        No
# 54  ...  None   IC50    uM  UO_0000065        None  500000.0        No
# 56  ...  None   IC50    uM  UO_0000065        None  500000.0        No
# 58  ...  None   IC50    uM  UO_0000065        None  500000.0        No
# 60  ...  None   IC50    uM  UO_0000065        None  500000.0        No
# 62  ...  None   IC50    uM  UO_0000065        None  500000.0        No
# 64  ...  None   IC50    uM  UO_0000065        None  250000.0        No
# 66  ...  None   IC50    uM  UO_0000065        None  500000.0        No
# 68  ...  None   IC50    uM  UO_0000065        None  500000.0        No
# 70  ...  None   IC50    uM  UO_0000065        None  500000.0        No
#
#    (value, mean) (value, std) select
# 0       500000.0          0.0    0.0
# 2       500000.0          0.0    0.0
# 4       500000.0          0.0    0.0
# 6       500000.0          0.0    0.0
# 8       500000.0          0.0    0.0
# 10      100000.0          0.0    0.0
# 12      100000.0          0.0    0.0
# 14      100000.0          0.0    0.0
# 16      100000.0          0.0    0.0
# 18      100000.0          0.0    0.0
# 20      100000.0          0.0    0.0
# 22      100000.0          0.0    0.0
# 24      100000.0          0.0    0.0
# 26      100000.0          0.0    0.0
# 28      100000.0          0.0    0.0
# 30      100000.0          0.0    0.0
# 32      100000.0          0.0    0.0
# 34      100000.0          0.0    0.0
# 36      100000.0          0.0    0.0
# 38      100000.0          0.0    0.0
# 40      100000.0          0.0    0.0
# 42      100000.0          0.0    0.0
# 44      100000.0          0.0    0.0
# 46      100000.0          0.0    0.0
# 48      100000.0          0.0    0.0
# 50      100000.0          0.0    0.0
# 52      100000.0          0.0    0.0
# 54      500000.0          0.0    0.0
# 56      500000.0          0.0    0.0
# 58      500000.0          0.0    0.0
# 60      500000.0          0.0    0.0
# 62      500000.0          0.0    0.0
# 64      250000.0          0.0    0.0
# 66      500000.0          0.0    0.0
# 68      500000.0          0.0    0.0
# 70      500000.0          0.0    0.0
#
# [36 rows x 49 columns]

# %%
len(df_dup), len(df_dup['molecule_chembl_id'].unique())
# Out:
# (36, 36)

# %%
df_dup = df_dup.drop('select', 1)
df_dup = df_dup.drop(('value', 'mean'), 1)
df_dup = df_dup.drop(('value', 'std'), 1)
# Out:
# <ipython-input-33-aca2d7831475>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df_dup = df_dup.drop('select', 1)
# <ipython-input-33-aca2d7831475>:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df_dup = df_dup.drop(('value', 'mean'), 1)
# <ipython-input-33-aca2d7831475>:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df_dup = df_dup.drop(('value', 'std'), 1)

# %%
df_final = pd.concat([df_non, df_dup])
len(df_dup), len(df_non), len(df_final)
# Out:
# (36, 521, 557)

# %%
df_final
# Out:
#    activity_comment  activity_id activity_properties assay_chembl_id  \
# 16             None      1610787                  []    CHEMBL885133
# 18             None      1618276                  []    CHEMBL885133
# 19             None      1618279                  []    CHEMBL885133
# 20             None      1618282                  []    CHEMBL885133
# 21             None      1618285                  []    CHEMBL885133
# ..              ...          ...                 ...             ...
# 62             None      2164074                  []    CHEMBL932548
# 64             None      2164100                  []    CHEMBL932548
# 66             None      2164054                  []    CHEMBL932548
# 68             None      2164064                  []    CHEMBL932548
# 70             None      2164066                  []    CHEMBL932548
#
#                                     assay_description assay_type  \
# 16  In vitro inhibitory concentration against Myco...          F
# 18  In vitro inhibitory concentration against Myco...          F
# 19  In vitro inhibitory concentration against Myco...          F
# 20  In vitro inhibitory concentration against Myco...          F
# 21  In vitro inhibitory concentration against Myco...          F
# ..                                                ...        ...
# 62  Antimycobacterial activity against Mycobacteri...          F
# 64  Antimycobacterial activity against Mycobacteri...          F
# 66  Antimycobacterial activity against Mycobacteri...          F
# 68  Antimycobacterial activity against Mycobacteri...          F
# 70  Antimycobacterial activity against Mycobacteri...          F
#
#    assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 16                    None                   None  BAO_0000190  BAO_0000218
# 18                    None                   None  BAO_0000190  BAO_0000218
# 19                    None                   None  BAO_0000190  BAO_0000218
# 20                    None                   None  BAO_0000190  BAO_0000218
# 21                    None                   None  BAO_0000190  BAO_0000218
# ..                     ...                    ...          ...          ...
# 62                    None                   None  BAO_0000190  BAO_0000218
# 64                    None                   None  BAO_0000190  BAO_0000218
# 66                    None                   None  BAO_0000190  BAO_0000218
# 68                    None                   None  BAO_0000190  BAO_0000218
# 70                    None                   None  BAO_0000190  BAO_0000218
#
#     ...            target_pref_name target_tax_id text_value  toid  type  \
# 16  ...  Mycobacterium tuberculosis          1773       None  None  IC50
# 18  ...  Mycobacterium tuberculosis          1773       None  None  IC50
# 19  ...  Mycobacterium tuberculosis          1773       None  None  IC50
# 20  ...  Mycobacterium tuberculosis          1773       None  None  IC50
# 21  ...  Mycobacterium tuberculosis          1773       None  None  IC50
# ..  ...                         ...           ...        ...   ...   ...
# 62  ...  Mycobacterium tuberculosis          1773       None  None  IC50
# 64  ...  Mycobacterium tuberculosis          1773       None  None  IC50
# 66  ...  Mycobacterium tuberculosis          1773       None  None  IC50
# 68  ...  Mycobacterium tuberculosis          1773       None  None  IC50
# 70  ...  Mycobacterium tuberculosis          1773       None  None  IC50
#
#    units    uo_units upper_value     value Activity
# 16    uM  UO_0000065        None   13970.0       No
# 18    uM  UO_0000065        None   20000.0       No
# 19    uM  UO_0000065        None   18350.0       No
# 20    uM  UO_0000065        None   15760.0       No
# 21    uM  UO_0000065        None   17730.0       No
# ..   ...         ...         ...       ...      ...
# 62    uM  UO_0000065        None  500000.0       No
# 64    uM  UO_0000065        None  250000.0       No
# 66    uM  UO_0000065        None  500000.0       No
# 68    uM  UO_0000065        None  500000.0       No
# 70    uM  UO_0000065        None  500000.0       No
#
# [557 rows x 46 columns]

# %%
df_final.to_csv('bioactivity_preprocessed_data_Mtb_nodup_IC50_nM.csv', index=False)

# %%
selection = ['molecule_chembl_id', 'canonical_smiles', 'value', 'Activity']
df3 = df_final[selection]
df3
# Out:
#    molecule_chembl_id                                   canonical_smiles  \
# 16       CHEMBL196076  C/C(=N/NC(=O)c1ccncc1)c1cccc(CN2CCN(c3ccc(F)cc...
# 18       CHEMBL382508            C/C(=N/NC(=O)c1ccncc1)c1cccc(CN(C)C)c1O
# 19       CHEMBL371672          CCN(CC)Cc1cccc(/C(C)=N\NC(=O)c2ccncc2)c1O
# 20       CHEMBL198453      CCCCN(CCCC)Cc1cccc(/C(C)=N\NC(=O)c2ccncc2)c1O
# 21       CHEMBL198317         C/C(=N/NC(=O)c1ccncc1)c1cccc(CN2CCCCC2)c1O
# ..                ...                                                ...
# 62       CHEMBL403164  Oc1ccccc1C1=NN(C(=S)Nc2ccccc2)[C@H](c2ccccc2Cl)C1
# 64       CHEMBL403496   COc1ccccc1[C@@H]1CC(c2ccccc2O)=NN1C(=S)Nc1ccccc1
# 66       CHEMBL404041  COc1cc([C@@H]2CC(c3ccccc3O)=NN2C(=S)Nc2ccc(C)c...
# 68       CHEMBL427902  COc1ccc(NC(=S)N2N=C(c3ccccc3O)C[C@H]2c2ccc(O)c...
# 70       CHEMBL444374  COc1ccccc1NC(=S)N1N=C(c2ccccc2O)C[C@H]1c1ccc(O...
#
#        value Activity
# 16   13970.0       No
# 18   20000.0       No
# 19   18350.0       No
# 20   15760.0       No
# 21   17730.0       No
# ..       ...      ...
# 62  500000.0       No
# 64  250000.0       No
# 66  500000.0       No
# 68  500000.0       No
# 70  500000.0       No
#
# [557 rows x 4 columns]

# %%
! wget https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
! chmod +x Miniconda3-py37_4.8.2-Linux-x86_64.sh
! bash ./Miniconda3-py37_4.8.2-Linux-x86_64.sh -b -f -p /usr/local
! conda install -c rdkit rdkit -y
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')
# Out:
# --2023-02-02 15:12:19--  https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.131.3, 104.16.130.3, 2606:4700::6810:8203, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.131.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85055499 (81M) [application/x-sh]
# Saving to: ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh’
#
# Miniconda3-py37_4.8 100%[===================>]  81.12M   205MB/s    in 0.4s
#
# 2023-02-02 15:12:19 (205 MB/s) - ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh’ saved [85055499/85055499]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - asn1crypto==1.3.0=py37_0
#     - ca-certificates==2020.1.1=0
#     - certifi==2019.11.28=py37_0
#     - cffi==1.14.0=py37h2e261b9_0
#     - chardet==3.0.4=py37_1003
#     - conda-package-handling==1.6.0=py37h7b6447c_0
#     - conda==4.8.2=py37_0
#     - cryptography==2.8=py37h1ba5d50_0
#     - idna==2.8=py37_0
#     - ld_impl_linux-64==2.33.1=h53a641e_7
#     - libedit==3.1.20181209=hc058e9b_0
#     - libffi==3.2.1=hd88cf55_4
#     - libgcc-ng==9.1.0=hdf63c60_0
#     - libstdcxx-ng==9.1.0=hdf63c60_0
#     - ncurses==6.2=he6710b0_0
#     - openssl==1.1.1d=h7b6447c_4
#     - pip==20.0.2=py37_1
#     - pycosat==0.6.3=py37h7b6447c_0
#     - pycparser==2.19=py37_0
#     - pyopenssl==19.1.0=py37_0
#     - pysocks==1.7.1=py37_0
#     - python==3.7.6=h0371630_2
#     - readline==7.0=h7b6447c_5
#     - requests==2.22.0=py37_1
#     - ruamel_yaml==0.15.87=py37h7b6447c_0
#     - setuptools==45.2.0=py37_0
#     - six==1.14.0=py37_0
#     - sqlite==3.31.1=h7b6447c_0
#     - tk==8.6.8=hbc83047_0
#     - tqdm==4.42.1=py_0
#     - urllib3==1.25.8=py37_0
#     - wheel==0.34.2=py37_0
#     - xz==5.2.4=h14c3975_4
#     - yaml==0.1.7=had09818_2
#     - zlib==1.2.11=h7b6447c_3
#
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
#   asn1crypto         pkgs/main/linux-64::asn1crypto-1.3.0-py37_0
#   ca-certificates    pkgs/main/linux-64::ca-certificates-2020.1.1-0
#   certifi            pkgs/main/linux-64::certifi-2019.11.28-py37_0
#   cffi               pkgs/main/linux-64::cffi-1.14.0-py37h2e261b9_0
#   chardet            pkgs/main/linux-64::chardet-3.0.4-py37_1003
#   conda              pkgs/main/linux-64::conda-4.8.2-py37_0
#   conda-package-han~ pkgs/main/linux-64::conda-package-handling-1.6.0-py37h7b6447c_0
#   cryptography       pkgs/main/linux-64::cryptography-2.8-py37h1ba5d50_0
#   idna               pkgs/main/linux-64::idna-2.8-py37_0
#   ld_impl_linux-64   pkgs/main/linux-64::ld_impl_linux-64-2.33.1-h53a641e_7
#   libedit            pkgs/main/linux-64::libedit-3.1.20181209-hc058e9b_0
#   libffi             pkgs/main/linux-64::libffi-3.2.1-hd88cf55_4
#   libgcc-ng          pkgs/main/linux-64::libgcc-ng-9.1.0-hdf63c60_0
#   libstdcxx-ng       pkgs/main/linux-64::libstdcxx-ng-9.1.0-hdf63c60_0
#   ncurses            pkgs/main/linux-64::ncurses-6.2-he6710b0_0
#   openssl            pkgs/main/linux-64::openssl-1.1.1d-h7b6447c_4
#   pip                pkgs/main/linux-64::pip-20.0.2-py37_1
#   pycosat            pkgs/main/linux-64::pycosat-0.6.3-py37h7b6447c_0
#   pycparser          pkgs/main/linux-64::pycparser-2.19-py37_0
#   pyopenssl          pkgs/main/linux-64::pyopenssl-19.1.0-py37_0
#   pysocks            pkgs/main/linux-64::pysocks-1.7.1-py37_0
#   python             pkgs/main/linux-64::python-3.7.6-h0371630_2
#   readline           pkgs/main/linux-64::readline-7.0-h7b6447c_5
#   requests           pkgs/main/linux-64::requests-2.22.0-py37_1
#   ruamel_yaml        pkgs/main/linux-64::ruamel_yaml-0.15.87-py37h7b6447c_0
#   setuptools         pkgs/main/linux-64::setuptools-45.2.0-py37_0
#   six                pkgs/main/linux-64::six-1.14.0-py37_0
#   sqlite             pkgs/main/linux-64::sqlite-3.31.1-h7b6447c_0
#   tk                 pkgs/main/linux-64::tk-8.6.8-hbc83047_0
#   tqdm               pkgs/main/noarch::tqdm-4.42.1-py_0
#   urllib3            pkgs/main/linux-64::urllib3-1.25.8-py37_0
#   wheel              pkgs/main/linux-64::wheel-0.34.2-py37_0
#   xz                 pkgs/main/linux-64::xz-5.2.4-h14c3975_4
#   yaml               pkgs/main/linux-64::yaml-0.1.7-had09818_2
#   zlib               pkgs/main/linux-64::zlib-1.2.11-h7b6447c_3
#
#
# done
# done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - rdkit
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-5.1          |            1_gnu          21 KB
#     blas-1.0                   |              mkl           6 KB
#     bottleneck-1.3.5           |   py37h7deecbd_0         115 KB
#     bzip2-1.0.8                |       h7b6447c_0          78 KB
#     ca-certificates-2023.01.10 |       h06a4308_0         120 KB
#     cairo-1.16.0               |       hb05425b_3         1.2 MB
#     certifi-2022.12.7          |   py37h06a4308_0         150 KB
#     conda-23.1.0               |   py37h06a4308_0         937 KB
#     expat-2.4.9                |       h6a678d5_0         156 KB
#     flit-core-3.6.0            |     pyhd3eb1b0_0          42 KB
#     fontconfig-2.14.1          |       h52c9d5c_1         281 KB
#     freetype-2.12.1            |       h4a9f257_0         626 KB
#     giflib-5.2.1               |       h5eee18b_1          75 KB
#     glib-2.69.1                |       he621ea3_2         1.9 MB
#     icu-58.2                   |       he6710b0_3        10.5 MB
#     importlib-metadata-4.11.3  |   py37h06a4308_0          40 KB
#     importlib_metadata-4.11.3  |       hd3eb1b0_0          12 KB
#     intel-openmp-2021.4.0      |    h06a4308_3561         4.2 MB
#     jpeg-9e                    |       h7f8727e_0         240 KB
#     lcms2-2.12                 |       h3be6417_0         312 KB
#     lerc-3.0                   |       h295c915_0         196 KB
#     libboost-1.73.0            |      h28710b8_12        13.8 MB
#     libdeflate-1.8             |       h7f8727e_5          51 KB
#     libffi-3.4.2               |       h6a678d5_6         136 KB
#     libgcc-ng-11.2.0           |       h1234567_1         5.3 MB
#     libgomp-11.2.0             |       h1234567_1         474 KB
#     libpng-1.6.37              |       hbc83047_0         278 KB
#     libstdcxx-ng-11.2.0        |       h1234567_1         4.7 MB
#     libtiff-4.5.0              |       h6a678d5_1         524 KB
#     libuuid-1.41.5             |       h5eee18b_0          27 KB
#     libwebp-1.2.4              |       h11a3e52_0          79 KB
#     libwebp-base-1.2.4         |       h5eee18b_0         347 KB
#     libxcb-1.15                |       h7f8727e_0         505 KB
#     libxml2-2.9.14             |       h74e7548_0         718 KB
#     lz4-c-1.9.4                |       h6a678d5_0         154 KB
#     mkl-2021.4.0               |     h06a4308_640       142.6 MB
#     mkl-service-2.4.0          |   py37h7f8727e_0          56 KB
#     mkl_fft-1.3.1              |   py37hd3c417c_0         172 KB
#     mkl_random-1.2.2           |   py37h51133e4_0         287 KB
#     numexpr-2.8.4              |   py37he184ba9_0         133 KB
#     numpy-1.21.5               |   py37h6c91a56_3          10 KB
#     numpy-base-1.21.5          |   py37ha15fc14_3         4.8 MB
#     openssl-1.1.1s             |       h7f8727e_0         3.6 MB
#     packaging-22.0             |   py37h06a4308_0          68 KB
#     pandas-1.3.5               |   py37h8c16a72_0         9.3 MB
#     pcre-8.45                  |       h295c915_0         207 KB
#     pillow-9.3.0               |   py37hace64e9_1         719 KB
#     pixman-0.40.0              |       h7f8727e_1         373 KB
#     pluggy-1.0.0               |   py37h06a4308_1          29 KB
#     py-boost-1.73.0            |  py37h51133e4_12         195 KB
#     python-dateutil-2.8.2      |     pyhd3eb1b0_0         233 KB
#     pytz-2022.7                |   py37h06a4308_0         207 KB
#     rdkit-2020.09.1.0          |   py37hd50e099_1        25.8 MB  rdkit
#     ruamel.yaml-0.17.21        |   py37h5eee18b_0         177 KB
#     ruamel.yaml.clib-0.2.6     |   py37h5eee18b_1         140 KB
#     toolz-0.12.0               |   py37h06a4308_0         104 KB
#     typing_extensions-4.4.0    |   py37h06a4308_0          45 KB
#     xz-5.2.10                  |       h5eee18b_1         429 KB
#     zipp-3.11.0                |   py37h06a4308_0          19 KB
#     zlib-1.2.13                |       h5eee18b_0         103 KB
#     zstd-1.5.2                 |       ha4553b6_0         488 KB
#     ------------------------------------------------------------
#                                            Total:       238.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   _openmp_mutex      pkgs/main/linux-64::_openmp_mutex-5.1-1_gnu
#   blas               pkgs/main/linux-64::blas-1.0-mkl
#   bottleneck         pkgs/main/linux-64::bottleneck-1.3.5-py37h7deecbd_0
#   bzip2              pkgs/main/linux-64::bzip2-1.0.8-h7b6447c_0
#   cairo              pkgs/main/linux-64::cairo-1.16.0-hb05425b_3
#   expat              pkgs/main/linux-64::expat-2.4.9-h6a678d5_0
#   flit-core          pkgs/main/noarch::flit-core-3.6.0-pyhd3eb1b0_0
#   fontconfig         pkgs/main/linux-64::fontconfig-2.14.1-h52c9d5c_1
#   freetype           pkgs/main/linux-64::freetype-2.12.1-h4a9f257_0
#   giflib             pkgs/main/linux-64::giflib-5.2.1-h5eee18b_1
#   glib               pkgs/main/linux-64::glib-2.69.1-he621ea3_2
#   icu                pkgs/main/linux-64::icu-58.2-he6710b0_3
#   importlib-metadata pkgs/main/linux-64::importlib-metadata-4.11.3-py37h06a4308_0
#   importlib_metadata pkgs/main/noarch::importlib_metadata-4.11.3-hd3eb1b0_0
#   intel-openmp       pkgs/main/linux-64::intel-openmp-2021.4.0-h06a4308_3561
#   jpeg               pkgs/main/linux-64::jpeg-9e-h7f8727e_0
#   lcms2              pkgs/main/linux-64::lcms2-2.12-h3be6417_0
#   lerc               pkgs/main/linux-64::lerc-3.0-h295c915_0
#   libboost           pkgs/main/linux-64::libboost-1.73.0-h28710b8_12
#   libdeflate         pkgs/main/linux-64::libdeflate-1.8-h7f8727e_5
#   libgomp            pkgs/main/linux-64::libgomp-11.2.0-h1234567_1
#   libpng             pkgs/main/linux-64::libpng-1.6.37-hbc83047_0
#   libtiff            pkgs/main/linux-64::libtiff-4.5.0-h6a678d5_1
#   libuuid            pkgs/main/linux-64::libuuid-1.41.5-h5eee18b_0
#   libwebp            pkgs/main/linux-64::libwebp-1.2.4-h11a3e52_0
#   libwebp-base       pkgs/main/linux-64::libwebp-base-1.2.4-h5eee18b_0
#   libxcb             pkgs/main/linux-64::libxcb-1.15-h7f8727e_0
#   libxml2            pkgs/main/linux-64::libxml2-2.9.14-h74e7548_0
#   lz4-c              pkgs/main/linux-64::lz4-c-1.9.4-h6a678d5_0
#   mkl                pkgs/main/linux-64::mkl-2021.4.0-h06a4308_640
#   mkl-service        pkgs/main/linux-64::mkl-service-2.4.0-py37h7f8727e_0
#   mkl_fft            pkgs/main/linux-64::mkl_fft-1.3.1-py37hd3c417c_0
#   mkl_random         pkgs/main/linux-64::mkl_random-1.2.2-py37h51133e4_0
#   numexpr            pkgs/main/linux-64::numexpr-2.8.4-py37he184ba9_0
#   numpy              pkgs/main/linux-64::numpy-1.21.5-py37h6c91a56_3
#   numpy-base         pkgs/main/linux-64::numpy-base-1.21.5-py37ha15fc14_3
#   packaging          pkgs/main/linux-64::packaging-22.0-py37h06a4308_0
#   pandas             pkgs/main/linux-64::pandas-1.3.5-py37h8c16a72_0
#   pcre               pkgs/main/linux-64::pcre-8.45-h295c915_0
#   pillow             pkgs/main/linux-64::pillow-9.3.0-py37hace64e9_1
#   pixman             pkgs/main/linux-64::pixman-0.40.0-h7f8727e_1
#   pluggy             pkgs/main/linux-64::pluggy-1.0.0-py37h06a4308_1
#   py-boost           pkgs/main/linux-64::py-boost-1.73.0-py37h51133e4_12
#   python-dateutil    pkgs/main/noarch::python-dateutil-2.8.2-pyhd3eb1b0_0
#   pytz               pkgs/main/linux-64::pytz-2022.7-py37h06a4308_0
#   rdkit              rdkit/linux-64::rdkit-2020.09.1.0-py37hd50e099_1
#   ruamel.yaml        pkgs/main/linux-64::ruamel.yaml-0.17.21-py37h5eee18b_0
#   ruamel.yaml.clib   pkgs/main/linux-64::ruamel.yaml.clib-0.2.6-py37h5eee18b_1
#   toolz              pkgs/main/linux-64::toolz-0.12.0-py37h06a4308_0
#   typing_extensions  pkgs/main/linux-64::typing_extensions-4.4.0-py37h06a4308_0
#   zipp               pkgs/main/linux-64::zipp-3.11.0-py37h06a4308_0
#   zstd               pkgs/main/linux-64::zstd-1.5.2-ha4553b6_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                                2020.1.1-0 --> 2023.01.10-h06a4308_0
#   certifi                                 2019.11.28-py37_0 --> 2022.12.7-py37h06a4308_0
#   conda                                        4.8.2-py37_0 --> 23.1.0-py37h06a4308_0
#   libffi                                   3.2.1-hd88cf55_4 --> 3.4.2-h6a678d5_6
#   libgcc-ng                                9.1.0-hdf63c60_0 --> 11.2.0-h1234567_1
#   libstdcxx-ng                             9.1.0-hdf63c60_0 --> 11.2.0-h1234567_1
#   openssl                                 1.1.1d-h7b6447c_4 --> 1.1.1s-h7f8727e_0
#   xz                                       5.2.4-h14c3975_4 --> 5.2.10-h5eee18b_1
#   zlib                                    1.2.11-h7b6447c_3 --> 1.2.13-h5eee18b_0
#
#
#
# Downloading and Extracting Packages
# glib-2.69.1          | 1.9 MB    | : 100% 1.0/1 [00:00<00:00,  6.62it/s]
# libuuid-1.41.5       | 27 KB     | : 100% 1.0/1 [00:00<00:00, 15.79it/s]
# typing_extensions-4. | 45 KB     | : 100% 1.0/1 [00:00<00:00, 19.16it/s]
# _openmp_mutex-5.1    | 21 KB     | : 100% 1.0/1 [00:00<00:00, 16.87it/s]
# flit-core-3.6.0      | 42 KB     | : 100% 1.0/1 [00:00<00:00, 17.01it/s]
# numpy-base-1.21.5    | 4.8 MB    | : 100% 1.0/1 [00:00<00:00,  3.21it/s]
# libgomp-11.2.0       | 474 KB    | : 100% 1.0/1 [00:00<00:00, 15.15it/s]
# pytz-2022.7          | 207 KB    | : 100% 1.0/1 [00:00<00:00,  9.62it/s]
# zlib-1.2.13          | 103 KB    | : 100% 1.0/1 [00:00<00:00, 15.60it/s]
# expat-2.4.9          | 156 KB    | : 100% 1.0/1 [00:00<00:00, 17.42it/s]
# numexpr-2.8.4        | 133 KB    | : 100% 1.0/1 [00:00<00:00, 18.13it/s]
# xz-5.2.10            | 429 KB    | : 100% 1.0/1 [00:00<00:00, 12.16it/s]
# jpeg-9e              | 240 KB    | : 100% 1.0/1 [00:00<00:00, 16.19it/s]
# pixman-0.40.0        | 373 KB    | : 100% 1.0/1 [00:00<00:00, 15.63it/s]
# bottleneck-1.3.5     | 115 KB    | : 100% 1.0/1 [00:00<00:00, 15.96it/s]
# py-boost-1.73.0      | 195 KB    | : 100% 1.0/1 [00:00<00:00, 15.08it/s]
# libdeflate-1.8       | 51 KB     | : 100% 1.0/1 [00:00<00:00, 17.32it/s]
# ca-certificates-2023 | 120 KB    | : 100% 1.0/1 [00:00<00:00, 20.14it/s]
# zipp-3.11.0          | 19 KB     | : 100% 1.0/1 [00:00<00:00, 14.85it/s]
# python-dateutil-2.8. | 233 KB    | : 100% 1.0/1 [00:00<00:00, 12.64it/s]
# lcms2-2.12           | 312 KB    | : 100% 1.0/1 [00:00<00:00, 15.71it/s]
# libxcb-1.15          | 505 KB    | : 100% 1.0/1 [00:00<00:00, 11.96it/s]
# toolz-0.12.0         | 104 KB    | : 100% 1.0/1 [00:00<00:00, 15.36it/s]
# libboost-1.73.0      | 13.8 MB   | : 100% 1.0/1 [00:02<00:00,  2.06s/it]
# importlib_metadata-4 | 12 KB     | : 100% 1.0/1 [00:00<00:00, 15.68it/s]
# blas-1.0             | 6 KB      | : 100% 1.0/1 [00:00<00:00, 15.52it/s]
# conda-23.1.0         | 937 KB    | : 100% 1.0/1 [00:00<00:00,  8.53it/s]
# lz4-c-1.9.4          | 154 KB    | : 100% 1.0/1 [00:00<00:00, 15.73it/s]
# libxml2-2.9.14       | 718 KB    | : 100% 1.0/1 [00:00<00:00, 13.45it/s]
# mkl_random-1.2.2     | 287 KB    | : 100% 1.0/1 [00:00<00:00, 14.78it/s]
# libwebp-base-1.2.4   | 347 KB    | : 100% 1.0/1 [00:00<00:00, 14.01it/s]
# packaging-22.0       | 68 KB     | : 100% 1.0/1 [00:00<00:00, 15.76it/s]
# rdkit-2020.09.1.0    | 25.8 MB   | : 100% 1.0/1 [00:05<00:00,  5.52s/it]
# fontconfig-2.14.1    | 281 KB    | : 100% 1.0/1 [00:00<00:00, 12.98it/s]
# numpy-1.21.5         | 10 KB     | : 100% 1.0/1 [00:00<00:00, 16.67it/s]
# bzip2-1.0.8          | 78 KB     | : 100% 1.0/1 [00:00<00:00, 14.87it/s]
# zstd-1.5.2           | 488 KB    | : 100% 1.0/1 [00:00<00:00, 10.85it/s]
# giflib-5.2.1         | 75 KB     | : 100% 1.0/1 [00:00<00:00, 13.74it/s]
# cairo-1.16.0         | 1.2 MB    | : 100% 1.0/1 [00:00<00:00,  6.77it/s]
# ruamel.yaml.clib-0.2 | 140 KB    | : 100% 1.0/1 [00:00<00:00, 12.99it/s]
# importlib-metadata-4 | 40 KB     | : 100% 1.0/1 [00:00<00:00, 13.87it/s]
# pandas-1.3.5         | 9.3 MB    | : 100% 1.0/1 [00:00<00:00,  1.33it/s]
# libwebp-1.2.4        | 79 KB     | : 100% 1.0/1 [00:00<00:00, 10.41it/s]
# openssl-1.1.1s       | 3.6 MB    | : 100% 1.0/1 [00:00<00:00,  6.78it/s]
# ruamel.yaml-0.17.21  | 177 KB    | : 100% 1.0/1 [00:00<00:00, 15.57it/s]
# icu-58.2             | 10.5 MB   | : 100% 1.0/1 [00:00<00:00,  1.90it/s]
# libstdcxx-ng-11.2.0  | 4.7 MB    | : 100% 1.0/1 [00:00<00:00,  4.56it/s]
# freetype-2.12.1      | 626 KB    | : 100% 1.0/1 [00:00<00:00, 10.02it/s]
# libgcc-ng-11.2.0     | 5.3 MB    | : 100% 1.0/1 [00:00<00:00,  4.19it/s]
# libtiff-4.5.0        | 524 KB    | : 100% 1.0/1 [00:00<00:00, 12.76it/s]
# lerc-3.0             | 196 KB    | : 100% 1.0/1 [00:00<00:00, 14.92it/s]
# mkl-2021.4.0         | 142.6 MB  | : 100% 1.0/1 [00:05<00:00, 18.58s/it]
# pluggy-1.0.0         | 29 KB     | : 100% 1.0/1 [00:00<00:00, 16.25it/s]
# libffi-3.4.2         | 136 KB    | : 100% 1.0/1 [00:00<00:00, 13.13it/s]
# certifi-2022.12.7    | 150 KB    | : 100% 1.0/1 [00:00<00:00, 14.41it/s]
# mkl_fft-1.3.1        | 172 KB    | : 100% 1.0/1 [00:00<00:00, 13.22it/s]
# libpng-1.6.37        | 278 KB    | : 100% 1.0/1 [00:00<00:00, 15.66it/s]
# pillow-9.3.0         | 719 KB    | : 100% 1.0/1 [00:00<00:00, 11.18it/s]
# mkl-service-2.4.0    | 56 KB     | : 100% 1.0/1 [00:00<00:00, 15.69it/s]
# intel-openmp-2021.4. | 4.2 MB    | : 100% 1.0/1 [00:00<00:00,  5.18it/s]
# pcre-8.45            | 207 KB    | : 100% 1.0/1 [00:00<00:00, 13.67it/s]
# done
# done
# done

# %% [markdown]
# # Lipniski's Rule of 5

# %%
import numpy as np
from rdkit import Chem
from rdkit.Chem import Descriptors, Lipinski
import pandas as pd

# %% [markdown]
# Molecular Descriptors calculation

# %%
def lipinski(smiles, verbose=False):

    moldata= []
    for elem in smiles:
        mol=Chem.MolFromSmiles(elem) 
        moldata.append(mol)
       
    baseData= np.arange(1,1)
    i=0  
    for mol in moldata:        
       
        desc_MolWt = Descriptors.MolWt(mol)
        desc_MolLogP = Descriptors.MolLogP(mol)
        desc_NumHDonors = Lipinski.NumHDonors(mol)
        desc_NumHAcceptors = Lipinski.NumHAcceptors(mol)
           
        row = np.array([desc_MolWt,
                        desc_MolLogP,
                        desc_NumHDonors,
                        desc_NumHAcceptors])   
    
        if(i==0):
            baseData=row
        else:
            baseData=np.vstack([baseData, row])
        i=i+1      
    
    columnNames=["MW","LogP","NumHDonors","NumHAcceptors"]   
    descriptors = pd.DataFrame(data=baseData,columns=columnNames)
    
    return descriptors

# %%
df_lipinski = lipinski(df3.canonical_smiles)

# %%
df_final2 = df_final.reset_index()
df_final2
# Out:
#      index activity_comment  activity_id activity_properties assay_chembl_id  \
# 0       16             None      1610787                  []    CHEMBL885133
# 1       18             None      1618276                  []    CHEMBL885133
# 2       19             None      1618279                  []    CHEMBL885133
# 3       20             None      1618282                  []    CHEMBL885133
# 4       21             None      1618285                  []    CHEMBL885133
# ..     ...              ...          ...                 ...             ...
# 552     62             None      2164074                  []    CHEMBL932548
# 553     64             None      2164100                  []    CHEMBL932548
# 554     66             None      2164054                  []    CHEMBL932548
# 555     68             None      2164064                  []    CHEMBL932548
# 556     70             None      2164066                  []    CHEMBL932548
#
#                                      assay_description assay_type  \
# 0    In vitro inhibitory concentration against Myco...          F
# 1    In vitro inhibitory concentration against Myco...          F
# 2    In vitro inhibitory concentration against Myco...          F
# 3    In vitro inhibitory concentration against Myco...          F
# 4    In vitro inhibitory concentration against Myco...          F
# ..                                                 ...        ...
# 552  Antimycobacterial activity against Mycobacteri...          F
# 553  Antimycobacterial activity against Mycobacteri...          F
# 554  Antimycobacterial activity against Mycobacteri...          F
# 555  Antimycobacterial activity against Mycobacteri...          F
# 556  Antimycobacterial activity against Mycobacteri...          F
#
#     assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0                      None                   None  BAO_0000190  ...
# 1                      None                   None  BAO_0000190  ...
# 2                      None                   None  BAO_0000190  ...
# 3                      None                   None  BAO_0000190  ...
# 4                      None                   None  BAO_0000190  ...
# ..                      ...                    ...          ...  ...
# 552                    None                   None  BAO_0000190  ...
# 553                    None                   None  BAO_0000190  ...
# 554                    None                   None  BAO_0000190  ...
# 555                    None                   None  BAO_0000190  ...
# 556                    None                   None  BAO_0000190  ...
#
#                target_pref_name target_tax_id text_value  toid  type units  \
# 0    Mycobacterium tuberculosis          1773       None  None  IC50    uM
# 1    Mycobacterium tuberculosis          1773       None  None  IC50    uM
# 2    Mycobacterium tuberculosis          1773       None  None  IC50    uM
# 3    Mycobacterium tuberculosis          1773       None  None  IC50    uM
# 4    Mycobacterium tuberculosis          1773       None  None  IC50    uM
# ..                          ...           ...        ...   ...   ...   ...
# 552  Mycobacterium tuberculosis          1773       None  None  IC50    uM
# 553  Mycobacterium tuberculosis          1773       None  None  IC50    uM
# 554  Mycobacterium tuberculosis          1773       None  None  IC50    uM
# 555  Mycobacterium tuberculosis          1773       None  None  IC50    uM
# 556  Mycobacterium tuberculosis          1773       None  None  IC50    uM
#
#        uo_units  upper_value     value Activity
# 0    UO_0000065         None   13970.0       No
# 1    UO_0000065         None   20000.0       No
# 2    UO_0000065         None   18350.0       No
# 3    UO_0000065         None   15760.0       No
# 4    UO_0000065         None   17730.0       No
# ..          ...          ...       ...      ...
# 552  UO_0000065         None  500000.0       No
# 553  UO_0000065         None  250000.0       No
# 554  UO_0000065         None  500000.0       No
# 555  UO_0000065         None  500000.0       No
# 556  UO_0000065         None  500000.0       No
#
# [557 rows x 47 columns]

# %%
df_lipinski
# Out:
#           MW     LogP  NumHDonors  NumHAcceptors
# 0    447.514  3.40250         2.0            6.0
# 1    312.373  2.00280         2.0            5.0
# 2    340.427  2.78300         2.0            5.0
# 3    396.535  4.34340         2.0            5.0
# 4    352.438  2.92710         2.0            5.0
# ..       ...      ...         ...            ...
# 552  407.926  5.59370         2.0            3.0
# 553  403.507  4.94890         2.0            4.0
# 554  433.533  4.96292         3.0            5.0
# 555  419.506  4.65450         3.0            5.0
# 556  419.506  4.65450         3.0            5.0
#
# [557 rows x 4 columns]

# %%
df_combined = pd.concat([df_final2,df_lipinski], axis=1)

# %%
df_combined
# Out:
#      index activity_comment  activity_id activity_properties assay_chembl_id  \
# 0       16             None      1610787                  []    CHEMBL885133
# 1       18             None      1618276                  []    CHEMBL885133
# 2       19             None      1618279                  []    CHEMBL885133
# 3       20             None      1618282                  []    CHEMBL885133
# 4       21             None      1618285                  []    CHEMBL885133
# ..     ...              ...          ...                 ...             ...
# 552     62             None      2164074                  []    CHEMBL932548
# 553     64             None      2164100                  []    CHEMBL932548
# 554     66             None      2164054                  []    CHEMBL932548
# 555     68             None      2164064                  []    CHEMBL932548
# 556     70             None      2164066                  []    CHEMBL932548
#
#                                      assay_description assay_type  \
# 0    In vitro inhibitory concentration against Myco...          F
# 1    In vitro inhibitory concentration against Myco...          F
# 2    In vitro inhibitory concentration against Myco...          F
# 3    In vitro inhibitory concentration against Myco...          F
# 4    In vitro inhibitory concentration against Myco...          F
# ..                                                 ...        ...
# 552  Antimycobacterial activity against Mycobacteri...          F
# 553  Antimycobacterial activity against Mycobacteri...          F
# 554  Antimycobacterial activity against Mycobacteri...          F
# 555  Antimycobacterial activity against Mycobacteri...          F
# 556  Antimycobacterial activity against Mycobacteri...          F
#
#     assay_variant_accession assay_variant_mutation bao_endpoint  ...  type  \
# 0                      None                   None  BAO_0000190  ...  IC50
# 1                      None                   None  BAO_0000190  ...  IC50
# 2                      None                   None  BAO_0000190  ...  IC50
# 3                      None                   None  BAO_0000190  ...  IC50
# 4                      None                   None  BAO_0000190  ...  IC50
# ..                      ...                    ...          ...  ...   ...
# 552                    None                   None  BAO_0000190  ...  IC50
# 553                    None                   None  BAO_0000190  ...  IC50
# 554                    None                   None  BAO_0000190  ...  IC50
# 555                    None                   None  BAO_0000190  ...  IC50
# 556                    None                   None  BAO_0000190  ...  IC50
#
#     units    uo_units upper_value     value Activity       MW     LogP  \
# 0      uM  UO_0000065        None   13970.0       No  447.514  3.40250
# 1      uM  UO_0000065        None   20000.0       No  312.373  2.00280
# 2      uM  UO_0000065        None   18350.0       No  340.427  2.78300
# 3      uM  UO_0000065        None   15760.0       No  396.535  4.34340
# 4      uM  UO_0000065        None   17730.0       No  352.438  2.92710
# ..    ...         ...         ...       ...      ...      ...      ...
# 552    uM  UO_0000065        None  500000.0       No  407.926  5.59370
# 553    uM  UO_0000065        None  250000.0       No  403.507  4.94890
# 554    uM  UO_0000065        None  500000.0       No  433.533  4.96292
# 555    uM  UO_0000065        None  500000.0       No  419.506  4.65450
# 556    uM  UO_0000065        None  500000.0       No  419.506  4.65450
#
#     NumHDonors NumHAcceptors
# 0          2.0           6.0
# 1          2.0           5.0
# 2          2.0           5.0
# 3          2.0           5.0
# 4          2.0           5.0
# ..         ...           ...
# 552        2.0           3.0
# 553        2.0           4.0
# 554        3.0           5.0
# 555        3.0           5.0
# 556        3.0           5.0
#
# [557 rows x 51 columns]

# %%
df_combined.to_csv('Mtb_IC50_nm_MolDes.csv', sep=',' ,index=False)
