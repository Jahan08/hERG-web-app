# %% [markdown]
# <a href="https://colab.research.google.com/github/Jahan08/Amber-tutorial/blob/main/Dataset-preparation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
excelFile = pd.read_excel ('/content/LC_Stock_HTS_Compounds_noHTSduplicate_noPAINS_activity_stability_solubility.xlsx')

# %%
excelFile.to_csv ("LC_Stock_HTS_Compounds_noHTSduplicate_noPAINS_activity_stability_solubility.csv", index = None, header=True)
df = pd.DataFrame(pd.read_csv("LC_Stock_HTS_Compounds_noHTSduplicate_noPAINS_activity_stability_solubility.csv"))
df
# Out:
# <ipython-input-6-19b5367ba81a>:2: DtypeWarning: Columns (9,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.DataFrame(pd.read_csv("LC_Stock_HTS_Compounds_noHTSduplicate_noPAINS_activity_stability_solubility.csv"))
#               Name Activity_against_INF     Stability Solubility  \
# 0       F1903-0751         Inconclusive  Inconclusive        Yes
# 1       F1903-9899         Inconclusive            No        Yes
# 2       F1903-9900         Inconclusive           Yes        Yes
# 3       F1904-0726         Inconclusive           Yes        Yes
# 4       F1904-0909         Inconclusive           Yes        Yes
# ...            ...                  ...           ...        ...
# 456459  F1916-0071         Inconclusive  Inconclusive         No
# 456460  F1170-0375         Inconclusive           Yes         No
# 456461  F0020-0431         Inconclusive            No         No
# 456462  F0880-0036         Inconclusive            No         No
# ...

# %%
df = df[(df['Activity_against_INF'] == 'Yes')]
df = df[(df['Stability'] == 'Yes')]
df = df[(df['Solubility'] == 'Yes')]

# %%
df = df.drop(['Name[1]'], axis=1)
df = df.drop(['Name[2]'], axis=1)
df = df.drop(['Name[3]'], axis=1)
df = df.drop(['Activity_against_INF[1]'], axis=1)
df = df.drop(['Activity_against_INF[2]'], axis=1)
df = df.drop(['Activity_against_INF[3]'], axis=1)

# %%
df
# Out:
#               Name Activity_against_INF Stability Solubility  \
# 5       F1904-9831                  Yes       Yes        Yes
# 34      F6438-6904                  Yes       Yes        Yes
# 38      F6438-7101                  Yes       Yes        Yes
# 39      F6438-7110                  Yes       Yes        Yes
# 94      F6608-0254                  Yes       Yes        Yes
# ...            ...                  ...       ...        ...
# 453628  F2001-0092                  Yes       Yes        Yes
# 453644  F6518-4859                  Yes       Yes        Yes
# 453917  F6518-4909                  Yes       Yes        Yes
# 455179  F6518-4917                  Yes       Yes        Yes
# 455804  F3375-2150                  Yes       Yes        Yes
#
#                                                    Smiles
# 5                         n1c(ccc(OCC(CCN2)C2)n1)C(C)(C)C
# 34                           n1c(ccc(n1)NC2CCC2O)C(C)(C)C
# ...

# %%
df.to_csv ("LC_activite_stabile_soluble_INF.csv", index = None, header=True)
