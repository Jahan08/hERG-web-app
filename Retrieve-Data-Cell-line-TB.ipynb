# %% [markdown]
# <a href="https://colab.research.google.com/github/Jahan08/Amber-tutorial/blob/main/Retrieve-Data-Cell-line-TB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install chembl_webresource_client
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 KB 1.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 KB 1.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: attrs
#     Found existing installation: attrs 22.2.0
#     Uninstalling attrs-22.2.0:
#       Successfully uninstalled attrs-22.2.0
# ...

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %%
target = new_client.target
target_query = target.search('A549')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#   cross_references      organism  pref_name  score  species_group_flag  \
# 0               []  Homo sapiens       A549   19.0               False
# 1               []  Homo sapiens  A549/CDDP   16.0               False
# 2               []  Homo sapiens    A549/TR   16.0               False
#
#   target_chembl_id target_components target_type  tax_id
# 0        CHEMBL392                []   CELL-LINE    9606
# 1    CHEMBL4483225                []   CELL-LINE    9606
# 2    CHEMBL4483226                []   CELL-LINE    9606

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL392'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)
df
# Out:
#       activity_comment  activity_id activity_properties assay_chembl_id  \
# 0                 None        33044                  []    CHEMBL621424
# 1                 None        34302                  []    CHEMBL621424
# 2                 None        36751                  []    CHEMBL621424
# 3                 None        36757                  []    CHEMBL621424
# 4                 None        37932                  []    CHEMBL621424
# ...                ...          ...                 ...             ...
# 42997             None     24517073                  []   CHEMBL5057666
# 42998             None     24517074                  []   CHEMBL5057666
# 42999             None     24517075                  []   CHEMBL5057666
# 43000             None     24517076                  []   CHEMBL5057666
# 43001             None     24517077                  []   CHEMBL5057666
#
#                                        assay_description assay_type  \
# ...

# %%
df = pd.read_csv('/content/bioactivity_data_UO-31.csv', header = 0)
# Out:
# <ipython-input-176-0c86e62881e9>:1: DtypeWarning: Columns (15,25,28,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/bioactivity_data_UO-31.csv', header = 0)

# %%
# considering nM unit for MIC
#df = df[(df['standard_type'] == 'GI50')]
#df = df[(df['standard_type'] == 'IC50')]
#df = df[(df['standard_type'] == 'EC50')]
df = df[(df['standard_units'] == 'nM')]
df = df[(df['relation'] == '=')]
df = df[df.canonical_smiles.notna()]
df = df[df.standard_value.notna()]
df
# Out:
#       activity_comment  activity_id  \
# 0                 None        33044
# 1                 None        34302
# 2                 None        36751
# 3                 None        36757
# 4                 None        37932
# ...                ...          ...
# 42993             None     24515595
# 42994             None     24515596
# 42995             None     24515597
# 42996             None     24515598
# 43001             None     24517077
#
#                                      activity_properties assay_chembl_id  \
# 0                                                     []    CHEMBL621424
# 1                                                     []    CHEMBL621424
# 2                                                     []    CHEMBL621424
# 3                                                     []    CHEMBL621424
# 4                                                     []    CHEMBL621424
# ...                                                  ...             ...
# ...

# %%
fix = []

for i in df.standard_value:
    fix.append(float(i))

STATUS = []

for i in fix:
    if i < 1000:
        STATUS.append("Yes") #active
        
    elif 50000 <= i <= 100000:
        STATUS.append("No") #inactive
        
    else:
        STATUS.append("IN") #intermediate     

df = df.drop('value', 1)
df['value'] = fix
df['Activity'] = STATUS
df
# Out:
# <ipython-input-14-73640f0735c0>:18: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df = df.drop('value', 1)
#       activity_comment  activity_id  \
# 0                 None        33044
# 1                 None        34302
# 2                 None        36751
# 3                 None        36757
# 4                 None        37932
# ...                ...          ...
# 42993             None     24515595
# 42994             None     24515596
# 42995             None     24515597
# 42996             None     24515598
# 43001             None     24517077
#
#                                      activity_properties assay_chembl_id  \
# 0                                                     []    CHEMBL621424
# 1                                                     []    CHEMBL621424
# 2                                                     []    CHEMBL621424
# ...

# %%
# considering nM unit for MIC
df = df[(df['Activity'] != 'IN')]
len(df)
# Out:
# 8807

# %%
df.to_csv('/content/bioactivity_data_TB-cell-line_IC50_new.csv', index=False)
