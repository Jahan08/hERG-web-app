# %% [markdown]
# <a href="https://colab.research.google.com/github/Jahan08/Amber-tutorial/blob/main/Retrieve-Data-Cell-line-TB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install chembl_webresource_client
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.8-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 KB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.9/dist-packages (from chembl_webresource_client) (1.26.15)
# Requirement already satisfied: easydict in /usr/local/lib/python3.9/dist-packages (from chembl_webresource_client) (1.10)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.9/dist-packages (from chembl_webresource_client) (2.25.1)
# Collecting requests-cache~=0.7.0
#   Downloading requests_cache-0.7.5-py3-none-any.whl (39 kB)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from requests>=2.18.4->chembl_webresource_client) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2.10)
# Collecting url-normalize<2.0,>=1.4
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: itsdangerous>=2.0.1 in /usr/local/lib/python3.9/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (2.1.2)
# Requirement already satisfied: pyyaml>=5.4 in /usr/local/lib/python3.9/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (6.0)
# Collecting attrs<22.0,>=21.2
#   Downloading attrs-21.4.0-py2.py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 KB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from url-normalize<2.0,>=1.4->requests-cache~=0.7.0->chembl_webresource_client) (1.15.0)
# Installing collected packages: url-normalize, attrs, requests-cache, chembl_webresource_client
#   Attempting uninstall: attrs
#     Found existing installation: attrs 22.2.0
#     Uninstalling attrs-22.2.0:
#       Successfully uninstalled attrs-22.2.0
# Successfully installed attrs-21.4.0 chembl_webresource_client-0.10.8 requests-cache-0.7.5 url-normalize-1.4.3

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %%
target = new_client.target
target_query = target.search('A549')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#   cross_references      organism  pref_name  score  species_group_flag  \
# 0               []  Homo sapiens       A549   19.0               False
# 1               []  Homo sapiens  A549/CDDP   16.0               False
# 2               []  Homo sapiens    A549/TR   16.0               False
#
#   target_chembl_id target_components target_type  tax_id
# 0        CHEMBL392                []   CELL-LINE    9606
# 1    CHEMBL4483225                []   CELL-LINE    9606
# 2    CHEMBL4483226                []   CELL-LINE    9606

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL392'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)
df

# %%
df = pd.read_csv('/content/bioactivity_data_UO-31.csv', header = 0)
# Out:
# <ipython-input-176-0c86e62881e9>:1: DtypeWarning: Columns (15,25,28,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/bioactivity_data_UO-31.csv', header = 0)

# %%
# considering nM unit for MIC
#df = df[(df['standard_type'] == 'GI50')]
#df = df[(df['standard_type'] == 'IC50')]
#df = df[(df['standard_type'] == 'EC50')]
df = df[(df['standard_units'] == 'nM')]
df = df[(df['relation'] == '=')]
df = df[df.canonical_smiles.notna()]
df = df[df.standard_value.notna()]
df
# Out:
#       activity_comment  activity_id  \
# 0                  NaN       138333
# 1                  NaN       186182
# 2                  NaN       196835
# 4                  NaN       307238
# 5                  NaN       314063
# ...                ...          ...
# 46046              NaN     23282674
# 46047              NaN     23282675
# 46048              NaN     23282676
# 46049              NaN     23282677
# 46050              NaN     23282678
#
#                                      activity_properties assay_chembl_id  \
# 0                                                     []    CHEMBL815294
# 1                                                     []    CHEMBL815292
# 2                                                     []    CHEMBL815292
# 4                                                     []    CHEMBL885010
# 5                                                     []    CHEMBL815275
# ...                                                  ...             ...
# 46046  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4837609
# 46047  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4837609
# 46048  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4837609
# 46049  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4837609
# 46050  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4837609
#
#                                        assay_description assay_type  \
# 0      Tested for cytotoxicity against UO-31 cell lin...          F
# 1      Growth inhibition of the UO-31 Renal cancer ce...          F
# 2      Growth inhibition of the UO-31 Renal cancer ce...          F
# 4      In vitro cytotoxicity against human renal canc...          F
# 5      In vitro antitumor activity against human rena...          F
# ...                                                  ...        ...
# 46046  Growth inhibition of human UO-31 cells measure...          F
# 46047  Growth inhibition of human UO-31 cells measure...          F
# 46048  Growth inhibition of human UO-31 cells measure...          F
# 46049  Growth inhibition of human UO-31 cells measure...          F
# 46050  Growth inhibition of human UO-31 cells measure...          F
#
#        assay_variant_accession  assay_variant_mutation bao_endpoint  \
# 0                          NaN                     NaN  BAO_0000189
# 1                          NaN                     NaN  BAO_0000189
# 2                          NaN                     NaN  BAO_0000189
# 4                          NaN                     NaN  BAO_0000189
# 5                          NaN                     NaN  BAO_0000189
# ...                        ...                     ...          ...
# 46046                      NaN                     NaN  BAO_0000189
# 46047                      NaN                     NaN  BAO_0000189
# 46048                      NaN                     NaN  BAO_0000189
# 46049                      NaN                     NaN  BAO_0000189
# 46050                      NaN                     NaN  BAO_0000189
#
#         bao_format  ... target_organism target_pref_name target_tax_id  \
# 0      BAO_0000219  ...    Homo sapiens            UO-31          9606
# 1      BAO_0000219  ...    Homo sapiens            UO-31          9606
# 2      BAO_0000219  ...    Homo sapiens            UO-31          9606
# 4      BAO_0000219  ...    Homo sapiens            UO-31          9606
# 5      BAO_0000219  ...    Homo sapiens            UO-31          9606
# ...            ...  ...             ...              ...           ...
# 46046  BAO_0000219  ...    Homo sapiens            UO-31          9606
# 46047  BAO_0000219  ...    Homo sapiens            UO-31          9606
# 46048  BAO_0000219  ...    Homo sapiens            UO-31          9606
# 46049  BAO_0000219  ...    Homo sapiens            UO-31          9606
# 46050  BAO_0000219  ...    Homo sapiens            UO-31          9606
#
#       text_value toid      type  units    uo_units upper_value    value
# 0            NaN  NaN  Log GI50    NaN  UO_0000065         NaN    -6.08
# 1            NaN  NaN  Log GI50    NaN  UO_0000065         NaN    -5.19
# 2            NaN  NaN  Log GI50    NaN  UO_0000065         NaN    -4.67
# 4            NaN  NaN      GI50     uM  UO_0000065         NaN     1.62
# 5            NaN  NaN      GI50     uM  UO_0000065         NaN    15.20
# ...          ...  ...       ...    ...         ...         ...      ...
# 46046        NaN  NaN      GI50     nM  UO_0000065         NaN  6060.00
# 46047        NaN  NaN      GI50     nM  UO_0000065         NaN     9.00
# 46048        NaN  NaN      GI50     nM  UO_0000065         NaN  2150.00
# 46049        NaN  NaN      GI50     nM  UO_0000065         NaN   940.00
# 46050        NaN  NaN      GI50     nM  UO_0000065         NaN  1600.00
#
# [1034 rows x 45 columns]

# %%
fix = []

for i in df.standard_value:
    fix.append(float(i))

STATUS = []

for i in fix:
    if i < 1000:
        STATUS.append("Yes") #active
        
    elif 30000 <= i <= 100000:
        STATUS.append("No") #inactive
        
    else:
        STATUS.append("IN") #intermediate     

df = df.drop('value', 1)
df['value'] = fix
df['Activity'] = STATUS
df
# Out:
# <ipython-input-178-d453deb383ef>:18: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df = df.drop('value', 1)
#       activity_comment  activity_id  \
# 0                  NaN       138333
# 1                  NaN       186182
# 2                  NaN       196835
# 4                  NaN       307238
# 5                  NaN       314063
# ...                ...          ...
# 46046              NaN     23282674
# 46047              NaN     23282675
# 46048              NaN     23282676
# 46049              NaN     23282677
# 46050              NaN     23282678
#
#                                      activity_properties assay_chembl_id  \
# 0                                                     []    CHEMBL815294
# 1                                                     []    CHEMBL815292
# 2                                                     []    CHEMBL815292
# 4                                                     []    CHEMBL885010
# 5                                                     []    CHEMBL815275
# ...                                                  ...             ...
# 46046  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4837609
# 46047  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4837609
# 46048  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4837609
# 46049  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4837609
# 46050  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4837609
#
#                                        assay_description assay_type  \
# 0      Tested for cytotoxicity against UO-31 cell lin...          F
# 1      Growth inhibition of the UO-31 Renal cancer ce...          F
# 2      Growth inhibition of the UO-31 Renal cancer ce...          F
# 4      In vitro cytotoxicity against human renal canc...          F
# 5      In vitro antitumor activity against human rena...          F
# ...                                                  ...        ...
# 46046  Growth inhibition of human UO-31 cells measure...          F
# 46047  Growth inhibition of human UO-31 cells measure...          F
# 46048  Growth inhibition of human UO-31 cells measure...          F
# 46049  Growth inhibition of human UO-31 cells measure...          F
# 46050  Growth inhibition of human UO-31 cells measure...          F
#
#        assay_variant_accession  assay_variant_mutation bao_endpoint  \
# 0                          NaN                     NaN  BAO_0000189
# 1                          NaN                     NaN  BAO_0000189
# 2                          NaN                     NaN  BAO_0000189
# 4                          NaN                     NaN  BAO_0000189
# 5                          NaN                     NaN  BAO_0000189
# ...                        ...                     ...          ...
# 46046                      NaN                     NaN  BAO_0000189
# 46047                      NaN                     NaN  BAO_0000189
# 46048                      NaN                     NaN  BAO_0000189
# 46049                      NaN                     NaN  BAO_0000189
# 46050                      NaN                     NaN  BAO_0000189
#
#         bao_format  ... target_pref_name target_tax_id text_value toid  \
# 0      BAO_0000219  ...            UO-31          9606        NaN  NaN
# 1      BAO_0000219  ...            UO-31          9606        NaN  NaN
# 2      BAO_0000219  ...            UO-31          9606        NaN  NaN
# 4      BAO_0000219  ...            UO-31          9606        NaN  NaN
# 5      BAO_0000219  ...            UO-31          9606        NaN  NaN
# ...            ...  ...              ...           ...        ...  ...
# 46046  BAO_0000219  ...            UO-31          9606        NaN  NaN
# 46047  BAO_0000219  ...            UO-31          9606        NaN  NaN
# 46048  BAO_0000219  ...            UO-31          9606        NaN  NaN
# 46049  BAO_0000219  ...            UO-31          9606        NaN  NaN
# 46050  BAO_0000219  ...            UO-31          9606        NaN  NaN
#
#            type units    uo_units  upper_value     value Activity
# 0      Log GI50   NaN  UO_0000065          NaN    831.76      Yes
# 1      Log GI50   NaN  UO_0000065          NaN   6456.54       IN
# 2      Log GI50   NaN  UO_0000065          NaN  21379.62       No
# 4          GI50    uM  UO_0000065          NaN   1620.00       IN
# 5          GI50    uM  UO_0000065          NaN  15200.00       IN
# ...         ...   ...         ...          ...       ...      ...
# 46046      GI50    nM  UO_0000065          NaN   6060.00       IN
# 46047      GI50    nM  UO_0000065          NaN      9.00      Yes
# 46048      GI50    nM  UO_0000065          NaN   2150.00       IN
# 46049      GI50    nM  UO_0000065          NaN    940.00      Yes
# 46050      GI50    nM  UO_0000065          NaN   1600.00       IN
#
# [1034 rows x 46 columns]

# %%
# considering nM unit for MIC
df = df[(df['Activity'] != 'IN')]
len(df)
# Out:
# 366

# %%
df.to_csv('/content/bioactivity_data_UO-31_GI50_new.csv', index=False)
