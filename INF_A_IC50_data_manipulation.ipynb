# %% [markdown]
# <a href="https://colab.research.google.com/github/Jahan08/Amber-tutorial/blob/main/INF_A_IC50_data_manipulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install chembl_webresource_client
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.8-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 KB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: easydict in /usr/local/lib/python3.8/dist-packages (from chembl_webresource_client) (1.10)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.8/dist-packages (from chembl_webresource_client) (1.24.3)
# Collecting requests-cache~=0.7.0
#   Downloading requests_cache-0.7.5-py3-none-any.whl (39 kB)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.8/dist-packages (from chembl_webresource_client) (2.25.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.18.4->chembl_webresource_client) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2022.12.7)
# Requirement already satisfied: pyyaml>=5.4 in /usr/local/lib/python3.8/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (6.0)
# Collecting url-normalize<2.0,>=1.4
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Collecting attrs<22.0,>=21.2
#   Downloading attrs-21.4.0-py2.py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 KB 3.3 MB/s eta 0:00:00
# Collecting itsdangerous>=2.0.1
#   Downloading itsdangerous-2.1.2-py3-none-any.whl (15 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from url-normalize<2.0,>=1.4->requests-cache~=0.7.0->chembl_webresource_client) (1.15.0)
# Installing collected packages: url-normalize, itsdangerous, attrs, requests-cache, chembl_webresource_client
#   Attempting uninstall: itsdangerous
#     Found existing installation: itsdangerous 1.1.0
#     Uninstalling itsdangerous-1.1.0:
#       Successfully uninstalled itsdangerous-1.1.0
#   Attempting uninstall: attrs
#     Found existing installation: attrs 22.2.0
#     Uninstalling attrs-22.2.0:
#       Successfully uninstalled attrs-22.2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# flask 1.1.4 requires itsdangerous<2.0,>=0.24, but you have itsdangerous 2.1.2 which is incompatible.
# Successfully installed attrs-21.4.0 chembl_webresource_client-0.10.8 itsdangerous-2.1.2 requests-cache-0.7.5 url-normalize-1.4.3

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# target serach for Mtb

# %%
target = new_client.target
target_query = target.search('influenza')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                      cross_references  \
# 0                                                  []
# 1                                                  []
# 2                                                  []
# 3                                                  []
# 4   [{'xref_id': 'P03438', 'xref_name': None, 'xre...
# 5                                                  []
# 6                                                  []
# 7   [{'xref_id': 'P63231', 'xref_name': None, 'xre...
# 8                                                  []
# 9                                                  []
# 10                                                 []
# 11                                                 []
#
#                                           organism  \
# 0                     unidentified influenza virus
# 1                                Influenza B virus
# 2                                Influenza A virus
# 3                                Influenza C virus
# 4           Influenza A virus (strain A/X-31 H3N2)
# 5                         Influenza A virus (H5N1)
# 6                           Influenza A virus H3N2
# 7       Influenza A virus (A/Udorn/307/1972(H3N2))
# 8                     Influenza B virus (B/Lee/40)
# 9            Unidentified Influenza A virus (H1N2)
# 10  Influenza A virus (A/Puerto Rico/8/1934(H1N1))
# 11                          Haemophilus influenzae
#
#                                 pref_name  score  species_group_flag  \
# 0            unidentified influenza virus   12.0               False
# 1                       Influenza B virus   12.0               False
# 2                       Influenza A virus   12.0               False
# 3                       Influenza C virus   12.0               False
# 4         Influenza A virus Hemagglutinin   11.0               False
# 5                Influenza A virus (H5N1)   11.0               False
# 6                  Influenza A virus H3N2   11.0               False
# 7     Influenza virus A matrix protein M2    9.0               False
# 8            Influenza B virus (B/Lee/40)    9.0               False
# 9   Unidentified Influenza A virus (H1N2)    9.0               False
# 10    Influenza A virus (A/PR/8/34(H1N1))    8.0               False
# 11                 Haemophilus influenzae    6.0               False
#
#    target_chembl_id                                  target_components  \
# 0      CHEMBL613128                                                 []
# 1      CHEMBL613129                                                 []
# 2      CHEMBL613740                                                 []
# 3      CHEMBL612783                                                 []
# 4        CHEMBL4918  [{'accession': 'P03438', 'component_descriptio...
# 5      CHEMBL613845                                                 []
# 6     CHEMBL2366902                                                 []
# 7        CHEMBL2052  [{'accession': 'P0DOF8', 'component_descriptio...
# 8      CHEMBL612452                                                 []
# 9     CHEMBL2367089                                                 []
# 10     CHEMBL612610                                                 []
# 11        CHEMBL355                                                 []
#
#        target_type   tax_id
# 0         ORGANISM    11309
# 1         ORGANISM    11520
# 2         ORGANISM    11320
# 3         ORGANISM    11552
# 4   SINGLE PROTEIN   132504
# 5         ORGANISM   102793
# 6         ORGANISM    41857
# 7   SINGLE PROTEIN   381517
# 8         ORGANISM   107412
# 9         ORGANISM  1323429
# 10        ORGANISM   211044
# 11        ORGANISM      727

# %% [markdown]
# selecting the target

# %%
selected_target = targets.target_chembl_id[2]
selected_target
# Out:
# 'CHEMBL613740'

# %%
activity = new_client.activity
SEL = activity.filter(target_chembl_id=selected_target)
df = pd.DataFrame.from_dict(SEL)
df
# Out:
#                                  activity_comment  activity_id  \
# 0     inactive at 100 uM and 1000 uM respectively        32866
# 1                                            None        41182
# 2     inactive at 100 uM and 1000 uM respectively        42536
# 3     inactive at 100 uM and 1000 uM respectively        48624
# 4     inactive at 100 uM and 1000 uM respectively        50071
# ...                                           ...          ...
# 8632                                         None     23316997
# 8633                                         None     23316998
# 8634                                         None     23316999
# 8635                                         None     23317000
# 8636                                         None     23317001
#
#      activity_properties assay_chembl_id  \
# 0                     []    CHEMBL697077
# 1                     []    CHEMBL841083
# 2                     []    CHEMBL697077
# 3                     []    CHEMBL697077
# 4                     []    CHEMBL697077
# ...                  ...             ...
# 8632                  []   CHEMBL4845561
# 8633                  []   CHEMBL4845561
# 8634                  []   CHEMBL4845561
# 8635                  []   CHEMBL4845561
# 8636                  []   CHEMBL4845561
#
#                                       assay_description assay_type  \
# 0     In vitro antiviral activity against influenza ...          F
# 1     Compound tested for the antiviral activity aga...          F
# 2     In vitro antiviral activity against influenza ...          F
# 3     In vitro antiviral activity against influenza ...          F
# 4     In vitro antiviral activity against influenza ...          F
# ...                                                 ...        ...
# 8632  Antiviral activity against Influenza A virus (...          F
# 8633  Antiviral activity against Influenza A virus (...          F
# 8634  Antiviral activity against Influenza A virus (...          F
# 8635  Antiviral activity against Influenza A virus (...          F
# 8636  Antiviral activity against Influenza A virus (...          F
#
#      assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                       None                   None  BAO_0000375  BAO_0000218
# 1                       None                   None  BAO_0000375  BAO_0000218
# 2                       None                   None  BAO_0000375  BAO_0000218
# 3                       None                   None  BAO_0000375  BAO_0000218
# 4                       None                   None  BAO_0000375  BAO_0000218
# ...                      ...                    ...          ...          ...
# 8632                    None                   None  BAO_0000190  BAO_0000218
# 8633                    None                   None  BAO_0000190  BAO_0000218
# 8634                    None                   None  BAO_0000190  BAO_0000218
# 8635                    None                   None  BAO_0000190  BAO_0000218
# 8636                    None                   None  BAO_0000190  BAO_0000218
#
#       ...    target_organism   target_pref_name target_tax_id text_value  \
# 0     ...  Influenza A virus  Influenza A virus         11320       None
# 1     ...  Influenza A virus  Influenza A virus         11320       None
# 2     ...  Influenza A virus  Influenza A virus         11320       None
# 3     ...  Influenza A virus  Influenza A virus         11320       None
# 4     ...  Influenza A virus  Influenza A virus         11320       None
# ...   ...                ...                ...           ...        ...
# 8632  ...  Influenza A virus  Influenza A virus         11320       None
# 8633  ...  Influenza A virus  Influenza A virus         11320       None
# 8634  ...  Influenza A virus  Influenza A virus         11320       None
# 8635  ...  Influenza A virus  Influenza A virus         11320       None
# 8636  ...  Influenza A virus  Influenza A virus         11320       None
#
#       toid      type  units    uo_units upper_value  value
# 0     None  Activity   None        None        None   None
# 1     None  Activity   None        None        None   None
# 2     None  Activity   None        None        None   None
# 3     None  Activity   None        None        None   None
# 4     None  Activity   None        None        None   None
# ...    ...       ...    ...         ...         ...    ...
# 8632  None      IC50     uM  UO_0000065        None   1.71
# 8633  None      IC50     uM  UO_0000065        None    1.2
# 8634  None      IC50     uM  UO_0000065        None   2.67
# 8635  None      IC50     uM  UO_0000065        None   4.58
# 8636  None      IC50     uM  UO_0000065        None  100.0
#
# [8637 rows x 45 columns]

# %% [markdown]
# Consider MIC as Bioactivity property

# %%
df.to_csv('bioactivity_data_Influenza_A_raw_data.csv', index=False)

# %%
import pandas as pd 
df = pd.read_csv('/content/bioactivity_data_Mtb_raw_data.csv', header = 0)

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#      activity_comment  activity_id activity_properties assay_chembl_id  \
# 0                None        76866                  []    CHEMBL808323
# 1                None        76868                  []    CHEMBL808324
# 2                None        77906                  []    CHEMBL808323
# 3                None        77908                  []    CHEMBL808324
# 4                None        79067                  []    CHEMBL808323
# ...               ...          ...                 ...             ...
# 2333             None     23316997                  []   CHEMBL4845561
# 2334             None     23316998                  []   CHEMBL4845561
# 2335             None     23316999                  []   CHEMBL4845561
# 2336             None     23317000                  []   CHEMBL4845561
# 2337             None     23317001                  []   CHEMBL4845561
#
#                                       assay_description assay_type  \
# 0     The compound was tested in vitro for the inhib...          F
# 1     The compound was tested in vitro for the inhib...          F
# 2     The compound was tested in vitro for the inhib...          F
# 3     The compound was tested in vitro for the inhib...          F
# 4     The compound was tested in vitro for the inhib...          F
# ...                                                 ...        ...
# 2333  Antiviral activity against Influenza A virus (...          F
# 2334  Antiviral activity against Influenza A virus (...          F
# 2335  Antiviral activity against Influenza A virus (...          F
# 2336  Antiviral activity against Influenza A virus (...          F
# 2337  Antiviral activity against Influenza A virus (...          F
#
#      assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                       None                   None  BAO_0000190  BAO_0000218
# 1                       None                   None  BAO_0000190  BAO_0000218
# 2                       None                   None  BAO_0000190  BAO_0000218
# 3                       None                   None  BAO_0000190  BAO_0000218
# 4                       None                   None  BAO_0000190  BAO_0000218
# ...                      ...                    ...          ...          ...
# 2333                    None                   None  BAO_0000190  BAO_0000218
# 2334                    None                   None  BAO_0000190  BAO_0000218
# 2335                    None                   None  BAO_0000190  BAO_0000218
# 2336                    None                   None  BAO_0000190  BAO_0000218
# 2337                    None                   None  BAO_0000190  BAO_0000218
#
#       ...    target_organism   target_pref_name target_tax_id text_value  \
# 0     ...  Influenza A virus  Influenza A virus         11320       None
# 1     ...  Influenza A virus  Influenza A virus         11320       None
# 2     ...  Influenza A virus  Influenza A virus         11320       None
# 3     ...  Influenza A virus  Influenza A virus         11320       None
# 4     ...  Influenza A virus  Influenza A virus         11320       None
# ...   ...                ...                ...           ...        ...
# 2333  ...  Influenza A virus  Influenza A virus         11320       None
# 2334  ...  Influenza A virus  Influenza A virus         11320       None
# 2335  ...  Influenza A virus  Influenza A virus         11320       None
# 2336  ...  Influenza A virus  Influenza A virus         11320       None
# 2337  ...  Influenza A virus  Influenza A virus         11320       None
#
#       toid  type  units    uo_units upper_value  value
# 0     None  IC50     mM  UO_0000065        None    4.0
# 1     None  IC50     mM  UO_0000065        None   10.0
# 2     None  IC50     mM  UO_0000065        None   0.75
# 3     None  IC50     mM  UO_0000065        None    1.0
# 4     None  IC50     mM  UO_0000065        None    5.0
# ...    ...   ...    ...         ...         ...    ...
# 2333  None  IC50     uM  UO_0000065        None   1.71
# 2334  None  IC50     uM  UO_0000065        None    1.2
# 2335  None  IC50     uM  UO_0000065        None   2.67
# 2336  None  IC50     uM  UO_0000065        None   4.58
# 2337  None  IC50     uM  UO_0000065        None  100.0
#
# [2338 rows x 45 columns]

# %%
df.to_csv('bioactivity_data_INA_IC50.csv', index=False)

# %%
# considering nM unit for MIC
df = df[(df['standard_units'] == 'nM')]
len(df)
# Out:
# 1901

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %%
df
# Out:
#      activity_comment  activity_id activity_properties assay_chembl_id  \
# 0                None        76866                  []    CHEMBL808323
# 1                None        76868                  []    CHEMBL808324
# 2                None        77906                  []    CHEMBL808323
# 3                None        77908                  []    CHEMBL808324
# 4                None        79067                  []    CHEMBL808323
# ...               ...          ...                 ...             ...
# 2333             None     23316997                  []   CHEMBL4845561
# 2334             None     23316998                  []   CHEMBL4845561
# 2335             None     23316999                  []   CHEMBL4845561
# 2336             None     23317000                  []   CHEMBL4845561
# 2337             None     23317001                  []   CHEMBL4845561
#
#                                       assay_description assay_type  \
# 0     The compound was tested in vitro for the inhib...          F
# 1     The compound was tested in vitro for the inhib...          F
# 2     The compound was tested in vitro for the inhib...          F
# 3     The compound was tested in vitro for the inhib...          F
# 4     The compound was tested in vitro for the inhib...          F
# ...                                                 ...        ...
# 2333  Antiviral activity against Influenza A virus (...          F
# 2334  Antiviral activity against Influenza A virus (...          F
# 2335  Antiviral activity against Influenza A virus (...          F
# 2336  Antiviral activity against Influenza A virus (...          F
# 2337  Antiviral activity against Influenza A virus (...          F
#
#      assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                       None                   None  BAO_0000190  BAO_0000218
# 1                       None                   None  BAO_0000190  BAO_0000218
# 2                       None                   None  BAO_0000190  BAO_0000218
# 3                       None                   None  BAO_0000190  BAO_0000218
# 4                       None                   None  BAO_0000190  BAO_0000218
# ...                      ...                    ...          ...          ...
# 2333                    None                   None  BAO_0000190  BAO_0000218
# 2334                    None                   None  BAO_0000190  BAO_0000218
# 2335                    None                   None  BAO_0000190  BAO_0000218
# 2336                    None                   None  BAO_0000190  BAO_0000218
# 2337                    None                   None  BAO_0000190  BAO_0000218
#
#       ...    target_organism   target_pref_name target_tax_id text_value  \
# 0     ...  Influenza A virus  Influenza A virus         11320       None
# 1     ...  Influenza A virus  Influenza A virus         11320       None
# 2     ...  Influenza A virus  Influenza A virus         11320       None
# 3     ...  Influenza A virus  Influenza A virus         11320       None
# 4     ...  Influenza A virus  Influenza A virus         11320       None
# ...   ...                ...                ...           ...        ...
# 2333  ...  Influenza A virus  Influenza A virus         11320       None
# 2334  ...  Influenza A virus  Influenza A virus         11320       None
# 2335  ...  Influenza A virus  Influenza A virus         11320       None
# 2336  ...  Influenza A virus  Influenza A virus         11320       None
# 2337  ...  Influenza A virus  Influenza A virus         11320       None
#
#       toid  type  units    uo_units upper_value  value
# 0     None  IC50     mM  UO_0000065        None    4.0
# 1     None  IC50     mM  UO_0000065        None   10.0
# 2     None  IC50     mM  UO_0000065        None   0.75
# 3     None  IC50     mM  UO_0000065        None    1.0
# 4     None  IC50     mM  UO_0000065        None    5.0
# ...    ...   ...    ...         ...         ...    ...
# 2333  None  IC50     uM  UO_0000065        None   1.71
# 2334  None  IC50     uM  UO_0000065        None    1.2
# 2335  None  IC50     uM  UO_0000065        None   2.67
# 2336  None  IC50     uM  UO_0000065        None   4.58
# 2337  None  IC50     uM  UO_0000065        None  100.0
#
# [1901 rows x 45 columns]

# %%
df.to_csv('bioactivity_data_INA_IC50_nM.csv', index=False)

# %% [markdown]
# handling the missing data

# %%
df = df[df.standard_value.notna()]
df = df[df.value.notna()]
df
# Out:
#      activity_comment  activity_id activity_properties assay_chembl_id  \
# 0                None        76866                  []    CHEMBL808323
# 1                None        76868                  []    CHEMBL808324
# 2                None        77906                  []    CHEMBL808323
# 3                None        77908                  []    CHEMBL808324
# 4                None        79067                  []    CHEMBL808323
# ...               ...          ...                 ...             ...
# 2333             None     23316997                  []   CHEMBL4845561
# 2334             None     23316998                  []   CHEMBL4845561
# 2335             None     23316999                  []   CHEMBL4845561
# 2336             None     23317000                  []   CHEMBL4845561
# 2337             None     23317001                  []   CHEMBL4845561
#
#                                       assay_description assay_type  \
# 0     The compound was tested in vitro for the inhib...          F
# 1     The compound was tested in vitro for the inhib...          F
# 2     The compound was tested in vitro for the inhib...          F
# 3     The compound was tested in vitro for the inhib...          F
# 4     The compound was tested in vitro for the inhib...          F
# ...                                                 ...        ...
# 2333  Antiviral activity against Influenza A virus (...          F
# 2334  Antiviral activity against Influenza A virus (...          F
# 2335  Antiviral activity against Influenza A virus (...          F
# 2336  Antiviral activity against Influenza A virus (...          F
# 2337  Antiviral activity against Influenza A virus (...          F
#
#      assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                       None                   None  BAO_0000190  BAO_0000218
# 1                       None                   None  BAO_0000190  BAO_0000218
# 2                       None                   None  BAO_0000190  BAO_0000218
# 3                       None                   None  BAO_0000190  BAO_0000218
# 4                       None                   None  BAO_0000190  BAO_0000218
# ...                      ...                    ...          ...          ...
# 2333                    None                   None  BAO_0000190  BAO_0000218
# 2334                    None                   None  BAO_0000190  BAO_0000218
# 2335                    None                   None  BAO_0000190  BAO_0000218
# 2336                    None                   None  BAO_0000190  BAO_0000218
# 2337                    None                   None  BAO_0000190  BAO_0000218
#
#       ...    target_organism   target_pref_name target_tax_id text_value  \
# 0     ...  Influenza A virus  Influenza A virus         11320       None
# 1     ...  Influenza A virus  Influenza A virus         11320       None
# 2     ...  Influenza A virus  Influenza A virus         11320       None
# 3     ...  Influenza A virus  Influenza A virus         11320       None
# 4     ...  Influenza A virus  Influenza A virus         11320       None
# ...   ...                ...                ...           ...        ...
# 2333  ...  Influenza A virus  Influenza A virus         11320       None
# 2334  ...  Influenza A virus  Influenza A virus         11320       None
# 2335  ...  Influenza A virus  Influenza A virus         11320       None
# 2336  ...  Influenza A virus  Influenza A virus         11320       None
# 2337  ...  Influenza A virus  Influenza A virus         11320       None
#
#       toid  type  units    uo_units upper_value  value
# 0     None  IC50     mM  UO_0000065        None    4.0
# 1     None  IC50     mM  UO_0000065        None   10.0
# 2     None  IC50     mM  UO_0000065        None   0.75
# 3     None  IC50     mM  UO_0000065        None    1.0
# 4     None  IC50     mM  UO_0000065        None    5.0
# ...    ...   ...    ...         ...         ...    ...
# 2333  None  IC50     uM  UO_0000065        None   1.71
# 2334  None  IC50     uM  UO_0000065        None    1.2
# 2335  None  IC50     uM  UO_0000065        None   2.67
# 2336  None  IC50     uM  UO_0000065        None   4.58
# 2337  None  IC50     uM  UO_0000065        None  100.0
#
# [1901 rows x 45 columns]

# %%
df = df[df.canonical_smiles.notna()]
df
# Out:
#      activity_comment  activity_id activity_properties assay_chembl_id  \
# 0                None        76866                  []    CHEMBL808323
# 1                None        76868                  []    CHEMBL808324
# 2                None        77906                  []    CHEMBL808323
# 3                None        77908                  []    CHEMBL808324
# 4                None        79067                  []    CHEMBL808323
# ...               ...          ...                 ...             ...
# 2333             None     23316997                  []   CHEMBL4845561
# 2334             None     23316998                  []   CHEMBL4845561
# 2335             None     23316999                  []   CHEMBL4845561
# 2336             None     23317000                  []   CHEMBL4845561
# 2337             None     23317001                  []   CHEMBL4845561
#
#                                       assay_description assay_type  \
# 0     The compound was tested in vitro for the inhib...          F
# 1     The compound was tested in vitro for the inhib...          F
# 2     The compound was tested in vitro for the inhib...          F
# 3     The compound was tested in vitro for the inhib...          F
# 4     The compound was tested in vitro for the inhib...          F
# ...                                                 ...        ...
# 2333  Antiviral activity against Influenza A virus (...          F
# 2334  Antiviral activity against Influenza A virus (...          F
# 2335  Antiviral activity against Influenza A virus (...          F
# 2336  Antiviral activity against Influenza A virus (...          F
# 2337  Antiviral activity against Influenza A virus (...          F
#
#      assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                       None                   None  BAO_0000190  BAO_0000218
# 1                       None                   None  BAO_0000190  BAO_0000218
# 2                       None                   None  BAO_0000190  BAO_0000218
# 3                       None                   None  BAO_0000190  BAO_0000218
# 4                       None                   None  BAO_0000190  BAO_0000218
# ...                      ...                    ...          ...          ...
# 2333                    None                   None  BAO_0000190  BAO_0000218
# 2334                    None                   None  BAO_0000190  BAO_0000218
# 2335                    None                   None  BAO_0000190  BAO_0000218
# 2336                    None                   None  BAO_0000190  BAO_0000218
# 2337                    None                   None  BAO_0000190  BAO_0000218
#
#       ...    target_organism   target_pref_name target_tax_id text_value  \
# 0     ...  Influenza A virus  Influenza A virus         11320       None
# 1     ...  Influenza A virus  Influenza A virus         11320       None
# 2     ...  Influenza A virus  Influenza A virus         11320       None
# 3     ...  Influenza A virus  Influenza A virus         11320       None
# 4     ...  Influenza A virus  Influenza A virus         11320       None
# ...   ...                ...                ...           ...        ...
# 2333  ...  Influenza A virus  Influenza A virus         11320       None
# 2334  ...  Influenza A virus  Influenza A virus         11320       None
# 2335  ...  Influenza A virus  Influenza A virus         11320       None
# 2336  ...  Influenza A virus  Influenza A virus         11320       None
# 2337  ...  Influenza A virus  Influenza A virus         11320       None
#
#       toid  type  units    uo_units upper_value  value
# 0     None  IC50     mM  UO_0000065        None    4.0
# 1     None  IC50     mM  UO_0000065        None   10.0
# 2     None  IC50     mM  UO_0000065        None   0.75
# 3     None  IC50     mM  UO_0000065        None    1.0
# 4     None  IC50     mM  UO_0000065        None    5.0
# ...    ...   ...    ...         ...         ...    ...
# 2333  None  IC50     uM  UO_0000065        None   1.71
# 2334  None  IC50     uM  UO_0000065        None    1.2
# 2335  None  IC50     uM  UO_0000065        None   2.67
# 2336  None  IC50     uM  UO_0000065        None   4.58
# 2337  None  IC50     uM  UO_0000065        None  100.0
#
# [1901 rows x 45 columns]

# %% [markdown]
# Define the activity
#
# <=1000 nM active
# rather inactive

# %%
fix = []

for i in df.standard_value:
    fix.append(float(i))

# %%
STATUS = []

for i in fix:
    if i <=10000:
        STATUS.append("Yes") #active
        
    #elif i >=10000:
        #STATUS.append("No") #inactive
        
    else:
        STATUS.append("No") #intermediate

# %%
df = df.drop('value', 1)
df['value'] = fix
df['Activity'] = STATUS
df.head(3)
# Out:
# <ipython-input-72-90299a80648f>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df = df.drop('value', 1)
#   activity_comment  activity_id activity_properties assay_chembl_id  \
# 0             None        76866                  []    CHEMBL808323
# 1             None        76868                  []    CHEMBL808324
# 2             None        77906                  []    CHEMBL808323
#
#                                    assay_description assay_type  \
# 0  The compound was tested in vitro for the inhib...          F
# 1  The compound was tested in vitro for the inhib...          F
# 2  The compound was tested in vitro for the inhib...          F
#
#   assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                    None                   None  BAO_0000190  BAO_0000218
# 1                    None                   None  BAO_0000190  BAO_0000218
# 2                    None                   None  BAO_0000190  BAO_0000218
#
#    ...   target_pref_name target_tax_id text_value  toid  type units  \
# 0  ...  Influenza A virus         11320       None  None  IC50    mM
# 1  ...  Influenza A virus         11320       None  None  IC50    mM
# 2  ...  Influenza A virus         11320       None  None  IC50    mM
#
#      uo_units upper_value       value Activity
# 0  UO_0000065        None   4000000.0       No
# 1  UO_0000065        None  10000000.0       No
# 2  UO_0000065        None    750000.0       No
#
# [3 rows x 46 columns]

# %%
selection = ['molecule_chembl_id', 'canonical_smiles', 'standard_type', 'standard_value', 'standard_units', 'Activity']
df2 = df[selection]
df2
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL327097                    CC(=O)Nc1ccc(C(=O)O)cc1NC(=O)CO
# 1          CHEMBL327097                    CC(=O)Nc1ccc(C(=O)O)cc1NC(=O)CO
# 2          CHEMBL324455             CC(=O)Nc1c(O)cc(C(=O)O)cc1[N+](=O)[O-]
# 3          CHEMBL324455             CC(=O)Nc1c(O)cc(C(=O)O)cc1[N+](=O)[O-]
# 4          CHEMBL321393       CC(=O)Nc1c(OC(C)=O)cc(C(=O)O)cc1[N+](=O)[O-]
# ...                 ...                                                ...
# 2333      CHEMBL4870860  CC1(C)CC[C@]2(C(=O)NCCCc3cn(CC(CO)(Cn4cc(CCCNC...
# 2334      CHEMBL4866899  CC1(C)CC[C@]2(C(=O)NCCCCCc3cn(CC(CO)(Cn4cc(CCC...
# 2335      CHEMBL4872826  CC1(C)CC[C@]2(C(=O)NCCCc3cn(Cc4cc(Cn5cc(CCCNC(...
# 2336      CHEMBL4855404  CC1(C)CC[C@]2(C(=O)NCCCCc3cn(Cc4cc(Cn5cc(CCCCN...
# 2337      CHEMBL1200340  CCOC(=O)C1=C[C@@H](OC(CC)CC)[C@H](NC(C)=O)[C@@...
#
#      standard_type standard_value standard_units Activity
# 0             IC50      4000000.0             nM       No
# 1             IC50     10000000.0             nM       No
# 2             IC50       750000.0             nM       No
# 3             IC50      1000000.0             nM       No
# 4             IC50      5000000.0             nM       No
# ...            ...            ...            ...      ...
# 2333          IC50         1710.0             nM      Yes
# 2334          IC50         1200.0             nM      Yes
# 2335          IC50         2670.0             nM      Yes
# 2336          IC50         4580.0             nM      Yes
# 2337          IC50       100000.0             nM       No
#
# [1901 rows x 6 columns]

# %%
df2.to_csv('bioactivity_preprocessed_data_INA_IC50_nM.csv', index=False)

# %%
# find the duplicate and unique molecule_chembl_id
import pandas as pd

df_dup = pd.concat(g for _, 
                    g in df.groupby("molecule_chembl_id") 
                      if len(g) > 1)
df_non = df.loc[~df.index.isin(df_dup.index)]

print (str(len(df_non)), 
       str(len(df_dup)), 
       str(len(df_dup)+len(df_non)))
# Out:
# 713 1188 1901

# %%
len(df_non), len(df_non['molecule_chembl_id'].unique())
# Out:
# (713, 713)

# %%
df_dup
# Out:
#      activity_comment  activity_id  \
# 22               None        94448
# 23               None        94450
# 18               None        93522
# 19               None        93524
# 6                None        85582
# ...               ...          ...
# 1883             None     22434735
# 26               None       104437
# 27               None       104439
# 108              None       682664
# 153              None      1044605
#
#                                     activity_properties assay_chembl_id  \
# 22                                                   []    CHEMBL808323
# 23                                                   []    CHEMBL808324
# 18                                                   []    CHEMBL808323
# 19                                                   []    CHEMBL808324
# 6                                                    []    CHEMBL808323
# ...                                                 ...             ...
# 1883  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4677355
# 26                                                   []    CHEMBL808323
# 27                                                   []    CHEMBL808324
# 108                                                  []    CHEMBL802978
# 153                                                  []    CHEMBL802979
#
#                                       assay_description assay_type  \
# 22    The compound was tested in vitro for the inhib...          F
# 23    The compound was tested in vitro for the inhib...          F
# 18    The compound was tested in vitro for the inhib...          F
# 19    The compound was tested in vitro for the inhib...          F
# 6     The compound was tested in vitro for the inhib...          F
# ...                                                 ...        ...
# 1883  Antiviral activity against Influenza A virus (...          F
# 26    The compound was tested in vitro for the inhib...          F
# 27    The compound was tested in vitro for the inhib...          F
# 108   Inhibitory activity against sialidase of influ...          F
# 153   Inhibitory activity against sialidase of influ...          F
#
#      assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 22                      None                   None  BAO_0000190  BAO_0000218
# 23                      None                   None  BAO_0000190  BAO_0000218
# 18                      None                   None  BAO_0000190  BAO_0000218
# 19                      None                   None  BAO_0000190  BAO_0000218
# 6                       None                   None  BAO_0000190  BAO_0000218
# ...                      ...                    ...          ...          ...
# 1883                    None                   None  BAO_0000190  BAO_0000218
# 26                      None                   None  BAO_0000190  BAO_0000218
# 27                      None                   None  BAO_0000190  BAO_0000218
# 108                     None                   None  BAO_0000190  BAO_0000218
# 153                     None                   None  BAO_0000190  BAO_0000218
#
#       ...   target_pref_name target_tax_id text_value  toid  type units  \
# 22    ...  Influenza A virus         11320       None  None  IC50    mM
# 23    ...  Influenza A virus         11320       None  None  IC50    mM
# 18    ...  Influenza A virus         11320       None  None  IC50    mM
# 19    ...  Influenza A virus         11320       None  None  IC50    mM
# 6     ...  Influenza A virus         11320       None  None  IC50    mM
# ...   ...                ...           ...        ...   ...   ...   ...
# 1883  ...  Influenza A virus         11320       None  None  IC50    uM
# 26    ...  Influenza A virus         11320       None  None  IC50    mM
# 27    ...  Influenza A virus         11320       None  None  IC50    mM
# 108   ...  Influenza A virus         11320       None  None  IC50    uM
# 153   ...  Influenza A virus         11320       None  None  IC50    uM
#
#         uo_units upper_value       value Activity
# 22    UO_0000065        None  10000000.0       No
# 23    UO_0000065        None  10000000.0       No
# 18    UO_0000065        None  10000000.0       No
# 19    UO_0000065        None  10000000.0       No
# 6     UO_0000065        None  10000000.0       No
# ...          ...         ...         ...      ...
# 1883  UO_0000065        None     69000.0       No
# 26    UO_0000065        None     15000.0       No
# 27    UO_0000065        None     15000.0       No
# 108   UO_0000065        None      2800.0      Yes
# 153   UO_0000065        None      2800.0      Yes
#
# [1188 rows x 46 columns]

# %%
# mean and std of all duplicate
import numpy as np
import pandas as pd
from time import time

from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
import seaborn as sns
# %matplotlib inline

mean_std = df_dup.groupby(['molecule_chembl_id'], as_index=False).agg({'value':['mean', 'std']})
mean_std.head()
# Out:
#   molecule_chembl_id       value
#                             mean  std
# 0       CHEMBL109004  10000000.0  0.0
# 1       CHEMBL109005  10000000.0  0.0
# 2       CHEMBL109162  10000000.0  0.0
# 3       CHEMBL109781  10000000.0  0.0
# 4       CHEMBL109939   5000000.0  0.0

# %%
len(mean_std)
# Out:
# 259

# %%
df_dup = df_dup.merge(mean_std, on='molecule_chembl_id', how='inner')
len(df_dup)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:9190: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   return merge(
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py:4150: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# 1188

# %%
#keep only SD less thab 2SD for duplicate chemblID

df_dup = df_dup[(df_dup[('value', 'std')] < 2)]
len(df_dup), len(df_dup['molecule_chembl_id'].unique())
# Out:
# (93, 30)

# %%
df_dup['select'] = (df_dup['value']- df_dup[('value', 'mean')]).abs()
#value_median = keep.groupby('chemblId')['value'].transform('median')

df_dup = df_dup.groupby(["molecule_chembl_id"]).apply(lambda x: x.sort_values(["select"], ascending = True)).reset_index(drop=True)
df_dup
# Out:
#    activity_comment  activity_id  \
# 0              None        94448
# 1              None        94450
# 2              None        93522
# 3              None        93524
# 4              None        85582
# ..              ...          ...
# 88             None     22958945
# 89             None        87558
# 90             None        87560
# 91             None     13932236
# 92             None     13932867
#
#                                   activity_properties assay_chembl_id  \
# 0                                                  []    CHEMBL808323
# 1                                                  []    CHEMBL808324
# 2                                                  []    CHEMBL808323
# 3                                                  []    CHEMBL808324
# 4                                                  []    CHEMBL808323
# ..                                                ...             ...
# 88  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4768320
# 89                                                 []    CHEMBL808323
# 90                                                 []    CHEMBL808324
# 91                                                 []   CHEMBL3124118
# 92                                                 []   CHEMBL3124125
#
#                                     assay_description assay_type  \
# 0   The compound was tested in vitro for the inhib...          F
# 1   The compound was tested in vitro for the inhib...          F
# 2   The compound was tested in vitro for the inhib...          F
# 3   The compound was tested in vitro for the inhib...          F
# 4   The compound was tested in vitro for the inhib...          F
# ..                                                ...        ...
# 88  Antiviral activity against Influenza A virus (...          F
# 89  The compound was tested in vitro for the inhib...          F
# 90  The compound was tested in vitro for the inhib...          F
# 91  Antiviral activity against Influenza A virus H3N2          F
# 92  Antiviral activity against Influenza A virus H1N1          F
#
#    assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                     None                   None  BAO_0000190  BAO_0000218
# 1                     None                   None  BAO_0000190  BAO_0000218
# 2                     None                   None  BAO_0000190  BAO_0000218
# 3                     None                   None  BAO_0000190  BAO_0000218
# 4                     None                   None  BAO_0000190  BAO_0000218
# ..                     ...                    ...          ...          ...
# 88                    None                   None  BAO_0000190  BAO_0000218
# 89                    None                   None  BAO_0000190  BAO_0000218
# 90                    None                   None  BAO_0000190  BAO_0000218
# 91                    None                   None  BAO_0000190  BAO_0000218
# 92                    None                   None  BAO_0000190  BAO_0000218
#
#     ...  toid  type units    uo_units upper_value        value  Activity  \
# 0   ...  None  IC50    mM  UO_0000065        None  10000000.00        No
# 1   ...  None  IC50    mM  UO_0000065        None  10000000.00        No
# 2   ...  None  IC50    mM  UO_0000065        None  10000000.00        No
# 3   ...  None  IC50    mM  UO_0000065        None  10000000.00        No
# 4   ...  None  IC50    mM  UO_0000065        None  10000000.00        No
# ..  ...   ...   ...   ...         ...         ...          ...       ...
# 88  ...  None  IC50    uM  UO_0000065        None     10000.00       Yes
# 89  ...  None  IC50    mM  UO_0000065        None     10000.00       Yes
# 90  ...  None  IC50    mM  UO_0000065        None     10000.00       Yes
# 91  ...  None  IC50    nM  UO_0000065        None         0.80       Yes
# 92  ...  None  IC50    nM  UO_0000065        None         0.22       Yes
#
#    (value, mean) (value, std) select
# 0    10000000.00     0.000000   0.00
# 1    10000000.00     0.000000   0.00
# 2    10000000.00     0.000000   0.00
# 3    10000000.00     0.000000   0.00
# 4    10000000.00     0.000000   0.00
# ..           ...          ...    ...
# 88      10000.00     0.000000   0.00
# 89      10000.00     0.000000   0.00
# 90      10000.00     0.000000   0.00
# 91          0.51     0.410122   0.29
# 92          0.51     0.410122   0.29
#
# [93 rows x 49 columns]

# %%
df_dup = df_dup.drop_duplicates(subset='molecule_chembl_id', keep='first')
df_dup
# Out:
#    activity_comment  activity_id  \
# 0              None        94448
# 2              None        93522
# 4              None        85582
# 6              None        92531
# 8              None        93526
# 10             None        86454
# 12             None        95432
# 14             None      5294560
# 16             None      5294477
# 18             None      8057973
# 20             None      8057955
# 22             None      8057917
# 24             None      8057892
# 26             None      8057905
# 28             None      8057920
# 30             None      8057981
# 32             None      8057991
# 34             None      8057987
# 36             None      8057967
# 38             None     10883412
# 40             None     10883415
# 42             None     10883416
# 44             None     10969705
# 46             None     11023800
# 48             None     13932221
# 50             None     18670702
# 52             None      5185188
# 85             None     22958819
# 89             None        87558
# 91             None     13932236
#
#                                   activity_properties assay_chembl_id  \
# 0                                                  []    CHEMBL808323
# 2                                                  []    CHEMBL808323
# 4                                                  []    CHEMBL808323
# 6                                                  []    CHEMBL808323
# 8                                                  []    CHEMBL808323
# 10                                                 []    CHEMBL808323
# 12                                                 []    CHEMBL808323
# 14                                                 []   CHEMBL1697296
# 16                                                 []   CHEMBL1697296
# 18                                                 []   CHEMBL1960696
# 20                                                 []   CHEMBL1960696
# 22                                                 []   CHEMBL1960696
# 24                                                 []   CHEMBL1960696
# 26                                                 []   CHEMBL1960696
# 28                                                 []   CHEMBL1960697
# 30                                                 []   CHEMBL1960696
# 32                                                 []   CHEMBL1960696
# 34                                                 []   CHEMBL1960696
# 36                                                 []   CHEMBL1960696
# 38                                                 []   CHEMBL2033222
# 40                                                 []   CHEMBL2033222
# 42                                                 []   CHEMBL2033222
# 44                                                 []   CHEMBL2065304
# 46                                                 []   CHEMBL2090870
# 48                                                 []   CHEMBL3124118
# 50                                                 []   CHEMBL4234600
# 52                                                 []   CHEMBL1664575
# 85  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4768317
# 89                                                 []    CHEMBL808323
# 91                                                 []   CHEMBL3124118
#
#                                     assay_description assay_type  \
# 0   The compound was tested in vitro for the inhib...          F
# 2   The compound was tested in vitro for the inhib...          F
# 4   The compound was tested in vitro for the inhib...          F
# 6   The compound was tested in vitro for the inhib...          F
# 8   The compound was tested in vitro for the inhib...          F
# 10  The compound was tested in vitro for the inhib...          F
# 12  The compound was tested in vitro for the inhib...          F
# 14  Antiviral activity against Influenza A virus H...          F
# 16  Antiviral activity against Influenza A virus H...          F
# 18  Antiinfluenza activity against influenza A vir...          F
# 20  Antiinfluenza activity against influenza A vir...          F
# 22  Antiinfluenza activity against influenza A vir...          F
# 24  Antiinfluenza activity against influenza A vir...          F
# 26  Antiinfluenza activity against influenza A vir...          F
# 28  Antiinfluenza activity against influenza A vir...          F
# 30  Antiinfluenza activity against influenza A vir...          F
# 32  Antiinfluenza activity against influenza A vir...          F
# 34  Antiinfluenza activity against influenza A vir...          F
# 36  Antiinfluenza activity against influenza A vir...          F
# 38  Antiviral activity against Influenza A virus A...          F
# 40  Antiviral activity against Influenza A virus A...          F
# 42  Antiviral activity against Influenza A virus A...          F
# 44  Antiviral activity against Influenza A virus (...          F
# 46  Antiviral activity against Influenza A virus (...          F
# 48  Antiviral activity against Influenza A virus H3N2          F
# 50  Antiviral activity against Influenza A virus (...          F
# 52  Antiviral activity against influenza A (A/Nort...          F
# 85  Antiviral activity against Influenza A virus (...          F
# 89  The compound was tested in vitro for the inhib...          F
# 91  Antiviral activity against Influenza A virus H3N2          F
#
#    assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                     None                   None  BAO_0000190  BAO_0000218
# 2                     None                   None  BAO_0000190  BAO_0000218
# 4                     None                   None  BAO_0000190  BAO_0000218
# 6                     None                   None  BAO_0000190  BAO_0000218
# 8                     None                   None  BAO_0000190  BAO_0000218
# 10                    None                   None  BAO_0000190  BAO_0000218
# 12                    None                   None  BAO_0000190  BAO_0000218
# 14                    None                   None  BAO_0000190  BAO_0000218
# 16                    None                   None  BAO_0000190  BAO_0000218
# 18                    None                   None  BAO_0000190  BAO_0000218
# 20                    None                   None  BAO_0000190  BAO_0000218
# 22                    None                   None  BAO_0000190  BAO_0000218
# 24                    None                   None  BAO_0000190  BAO_0000218
# 26                    None                   None  BAO_0000190  BAO_0000218
# 28                    None                   None  BAO_0000190  BAO_0000218
# 30                    None                   None  BAO_0000190  BAO_0000218
# 32                    None                   None  BAO_0000190  BAO_0000218
# 34                    None                   None  BAO_0000190  BAO_0000218
# 36                    None                   None  BAO_0000190  BAO_0000218
# 38                    None                   None  BAO_0000190  BAO_0000218
# 40                    None                   None  BAO_0000190  BAO_0000218
# 42                    None                   None  BAO_0000190  BAO_0000218
# 44                    None                   None  BAO_0000190  BAO_0000218
# 46                    None                   None  BAO_0000190  BAO_0000218
# 48                    None                   None  BAO_0000190  BAO_0000218
# 50                    None                   None  BAO_0000190  BAO_0000218
# 52                    None                   None  BAO_0000190  BAO_0000218
# 85                    None                   None  BAO_0000190  BAO_0000218
# 89                    None                   None  BAO_0000190  BAO_0000218
# 91                    None                   None  BAO_0000190  BAO_0000218
#
#     ...  toid  type units    uo_units upper_value        value  Activity  \
# 0   ...  None  IC50    mM  UO_0000065        None  10000000.00        No
# 2   ...  None  IC50    mM  UO_0000065        None  10000000.00        No
# 4   ...  None  IC50    mM  UO_0000065        None  10000000.00        No
# 6   ...  None  IC50    mM  UO_0000065        None  10000000.00        No
# 8   ...  None  IC50    mM  UO_0000065        None   5000000.00        No
# 10  ...  None  IC50    mM  UO_0000065        None   5000000.00        No
# 12  ...  None  IC50    mM  UO_0000065        None  10000000.00        No
# 14  ...  None  IC50    uM  UO_0000065        None     14800.00        No
# 16  ...  None  IC50    uM  UO_0000065        None      9900.00       Yes
# 18  ...  None  IC50    uM  UO_0000065        None    313800.00        No
# 20  ...  None  IC50    uM  UO_0000065        None    100700.00        No
# 22  ...  None  IC50    uM  UO_0000065        None     75200.00        No
# 24  ...  None  IC50    uM  UO_0000065        None     19300.00        No
# 26  ...  None  IC50    uM  UO_0000065        None     49400.00        No
# 28  ...  None  IC50    uM  UO_0000065        None     79800.00        No
# 30  ...  None  IC50    uM  UO_0000065        None     56500.00        No
# 32  ...  None  IC50    uM  UO_0000065        None     95500.00        No
# 34  ...  None  IC50    uM  UO_0000065        None      9600.00       Yes
# 36  ...  None  IC50    uM  UO_0000065        None     26900.00        No
# 38  ...  None  IC50    uM  UO_0000065        None     50000.00        No
# 40  ...  None  IC50    uM  UO_0000065        None     50000.00        No
# 42  ...  None  IC50    uM  UO_0000065        None     50000.00        No
# 44  ...  None  IC50    uM  UO_0000065        None     23700.00        No
# 46  ...  None  IC50    uM  UO_0000065        None     27030.00        No
# 48  ...  None  IC50    nM  UO_0000065        None         1.82       Yes
# 50  ...  None  IC50    uM  UO_0000065        None     74300.00        No
# 52  ...  None  IC50    nM  UO_0000065        None         0.92       Yes
# 85  ...  None  IC50    uM  UO_0000065        None     10000.00       Yes
# 89  ...  None  IC50    mM  UO_0000065        None     10000.00       Yes
# 91  ...  None  IC50    nM  UO_0000065        None         0.80       Yes
#
#    (value, mean) (value, std)    select
# 0   1.000000e+07     0.000000  0.000000
# 2   1.000000e+07     0.000000  0.000000
# 4   1.000000e+07     0.000000  0.000000
# 6   1.000000e+07     0.000000  0.000000
# 8   5.000000e+06     0.000000  0.000000
# 10  5.000000e+06     0.000000  0.000000
# 12  1.000000e+07     0.000000  0.000000
# 14  1.480000e+04     0.000000  0.000000
# 16  9.900000e+03     0.000000  0.000000
# 18  3.138000e+05     0.000000  0.000000
# 20  1.007000e+05     0.000000  0.000000
# 22  7.520000e+04     0.000000  0.000000
# 24  1.930000e+04     0.000000  0.000000
# 26  4.940000e+04     0.000000  0.000000
# 28  7.980000e+04     0.000000  0.000000
# 30  5.650000e+04     0.000000  0.000000
# 32  9.550000e+04     0.000000  0.000000
# 34  9.600000e+03     0.000000  0.000000
# 36  2.690000e+04     0.000000  0.000000
# 38  5.000000e+04     0.000000  0.000000
# 40  5.000000e+04     0.000000  0.000000
# 42  5.000000e+04     0.000000  0.000000
# 44  2.370000e+04     0.000000  0.000000
# 46  2.703000e+04     0.000000  0.000000
# 48  1.110000e+00     1.004092  0.710000
# 50  7.430000e+04     0.000000  0.000000
# 52  9.178788e-01     0.637239  0.002121
# 85  1.000000e+04     0.000000  0.000000
# 89  1.000000e+04     0.000000  0.000000
# 91  5.100000e-01     0.410122  0.290000
#
# [30 rows x 49 columns]

# %%
len(df_dup), len(df_dup['molecule_chembl_id'].unique())
# Out:
# (30, 30)

# %%
df_dup = df_dup.drop('select', 1)
df_dup = df_dup.drop(('value', 'mean'), 1)
df_dup = df_dup.drop(('value', 'std'), 1)
# Out:
# <ipython-input-85-aca2d7831475>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df_dup = df_dup.drop('select', 1)
# <ipython-input-85-aca2d7831475>:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df_dup = df_dup.drop(('value', 'mean'), 1)
# <ipython-input-85-aca2d7831475>:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df_dup = df_dup.drop(('value', 'std'), 1)

# %%
df_final = pd.concat([df_non, df_dup])
len(df_dup), len(df_non), len(df_final)
# Out:
# (30, 713, 743)

# %%
df_final
# Out:
#    activity_comment  activity_id  \
# 54             None       401275
# 55             None       407948
# 59             None       425352
# 60             None       427861
# 70             None       633170
# ..              ...          ...
# 50             None     18670702
# 52             None      5185188
# 85             None     22958819
# 89             None        87558
# 91             None     13932236
#
#                                   activity_properties assay_chembl_id  \
# 54                                                 []    CHEMBL802977
# 55                                                 []    CHEMBL802977
# 59                                                 []    CHEMBL802977
# 60                                                 []    CHEMBL802977
# 70                                                 []    CHEMBL873999
# ..                                                ...             ...
# 50                                                 []   CHEMBL4234600
# 52                                                 []   CHEMBL1664575
# 85  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4768317
# 89                                                 []    CHEMBL808323
# 91                                                 []   CHEMBL3124118
#
#                                     assay_description assay_type  \
# 54  Inhibitory activity against sialidase of influ...          F
# 55  Inhibitory activity against sialidase of influ...          F
# 59  Inhibitory activity against sialidase of influ...          F
# 60  Inhibitory activity against sialidase of influ...          F
# 70  Antiviral activity against Influenza virus (A/...          F
# ..                                                ...        ...
# 50  Antiviral activity against Influenza A virus (...          F
# 52  Antiviral activity against influenza A (A/Nort...          F
# 85  Antiviral activity against Influenza A virus (...          F
# 89  The compound was tested in vitro for the inhib...          F
# 91  Antiviral activity against Influenza A virus H3N2          F
#
#    assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 54                    None                   None  BAO_0000190  BAO_0000218
# 55                    None                   None  BAO_0000190  BAO_0000218
# 59                    None                   None  BAO_0000190  BAO_0000218
# 60                    None                   None  BAO_0000190  BAO_0000218
# 70                    None                   None  BAO_0000190  BAO_0000218
# ..                     ...                    ...          ...          ...
# 50                    None                   None  BAO_0000190  BAO_0000218
# 52                    None                   None  BAO_0000190  BAO_0000218
# 85                    None                   None  BAO_0000190  BAO_0000218
# 89                    None                   None  BAO_0000190  BAO_0000218
# 91                    None                   None  BAO_0000190  BAO_0000218
#
#     ...   target_pref_name target_tax_id text_value  toid  type units  \
# 54  ...  Influenza A virus         11320       None  None  IC50    uM
# 55  ...  Influenza A virus         11320       None  None  IC50    uM
# 59  ...  Influenza A virus         11320       None  None  IC50    uM
# 60  ...  Influenza A virus         11320       None  None  IC50    uM
# 70  ...  Influenza A virus         11320       None  None  IC50    uM
# ..  ...                ...           ...        ...   ...   ...   ...
# 50  ...  Influenza A virus         11320       None  None  IC50    uM
# 52  ...  Influenza A virus         11320       None  None  IC50    nM
# 85  ...  Influenza A virus         11320       None  None  IC50    uM
# 89  ...  Influenza A virus         11320       None  None  IC50    mM
# 91  ...  Influenza A virus         11320       None  None  IC50    nM
#
#       uo_units upper_value      value Activity
# 54  UO_0000065        None       2.00      Yes
# 55  UO_0000065        None      39.00      Yes
# 59  UO_0000065        None     770.00      Yes
# 60  UO_0000065        None       3.00      Yes
# 70  UO_0000065        None  100000.00       No
# ..         ...         ...        ...      ...
# 50  UO_0000065        None   74300.00       No
# 52  UO_0000065        None       0.92      Yes
# 85  UO_0000065        None   10000.00      Yes
# 89  UO_0000065        None   10000.00      Yes
# 91  UO_0000065        None       0.80      Yes
#
# [743 rows x 46 columns]

# %%
df_final.to_csv('bioactivity_preprocessed_data_Mtb_nodup_MIC_nM.csv', index=False)

# %%
selection = ['molecule_chembl_id', 'canonical_smiles', 'value', 'Activity']
df3 = df_final[selection]
df3
# Out:
#    molecule_chembl_id                                   canonical_smiles  \
# 54       CHEMBL345674  CCC(CC)C(=O)[C@@H]1OC(C(=O)O)=C[C@H](N)[C@H]1N...
# 55       CHEMBL436422  CCC(CC)C(O)[C@@H]1OC(C(=O)O)=C[C@H](N)[C@H]1NC...
# 59       CHEMBL156342   CCC(CC)O[C@@H]1OC(C(=O)O)=C[C@H](N)[C@H]1NC(C)=O
# 60       CHEMBL317645  CCN(CC)C(=O)[C@@H]1OC(C(=O)O)=C[C@H](N)[C@H]1N...
# 70      CHEMBL3143557  OC[C@H]1O[C@@H](n2cnc3c(NC4CC4)ncnc32)[C@H](F)...
# ..                ...                                                ...
# 50      CHEMBL4248255                            CCCCCCCc1coc(=O)c(C)c1O
# 52       CHEMBL466246  CO[C@H]([C@H](O)CO)[C@@H]1OC(C(=O)O)=C[C@H](NC...
# 85      CHEMBL4798296  CCC(CC)O[C@@H]1C=C(C(=O)O)C[C@H](NC(=O)c2ccccc...
# 89        CHEMBL55440                     CC(=O)Nc1ccc(C(=O)O)cc1NC(=N)N
# 91        CHEMBL81717  CCC(CC)O[C@@H]1C=C(C(=O)O)C[C@H](NC(=N)N)[C@H]...
#
#         value Activity
# 54       2.00      Yes
# 55      39.00      Yes
# 59     770.00      Yes
# 60       3.00      Yes
# 70  100000.00       No
# ..        ...      ...
# 50   74300.00       No
# 52       0.92      Yes
# 85   10000.00      Yes
# 89   10000.00      Yes
# 91       0.80      Yes
#
# [743 rows x 4 columns]

# %%
! wget https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
! chmod +x Miniconda3-py37_4.8.2-Linux-x86_64.sh
! bash ./Miniconda3-py37_4.8.2-Linux-x86_64.sh -b -f -p /usr/local
! conda install -c rdkit rdkit -y
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')
# Out:
# --2023-02-02 18:32:22--  https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.130.3, 104.16.131.3, 2606:4700::6810:8303, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.130.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85055499 (81M) [application/x-sh]
# Saving to: ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh.1’
#
# Miniconda3-py37_4.8 100%[===================>]  81.12M   245MB/s    in 0.3s
#
# 2023-02-02 18:32:23 (245 MB/s) - ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh.1’ saved [85055499/85055499]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# /
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/linux-64::certifi==2022.12.7=py37h06a4308_0
#   - defaults/linux-64::cffi==1.14.0=py37h2e261b9_0
#   - defaults/linux-64::lcms2==2.12=h3be6417_0
#   - defaults/linux-64::libffi==3.4.2=h6a678d5_6
#   - defaults/linux-64::mkl_random==1.2.2=py37h51133e4_0
#   - defaults/linux-64::numpy==1.21.5=py37h6c91a56_3
#   - defaults/linux-64::setuptools==45.2.0=py37_0
#   - defaults/linux-64::ruamel_yaml==0.15.87=py37h7b6447c_0
#   - defaults/linux-64::giflib==5.2.1=h5eee18b_1
#   - defaults/linux-64::libstdcxx-ng==11.2.0=h1234567_1
#   - defaults/linux-64::packaging==22.0=py37h06a4308_0
#   - defaults/linux-64::libedit==3.1.20181209=hc058e9b_0
#   - defaults/linux-64::libxml2==2.9.14=h74e7548_0
#   - defaults/linux-64::cryptography==2.8=py37h1ba5d50_0
#   - defaults/linux-64::pcre==8.45=h295c915_0
#   - defaults/linux-64::conda-package-handling==1.6.0=py37h7b6447c_0
#   - defaults/linux-64::pysocks==1.7.1=py37_0
#   - defaults/linux-64::pandas==1.3.5=py37h8c16a72_0
#   - defaults/linux-64::typing_extensions==4.4.0=py37h06a4308_0
#   - defaults/linux-64::mkl-service==2.4.0=py37h7f8727e_0
#   - defaults/linux-64::zstd==1.5.2=ha4553b6_0
#   - defaults/linux-64::numexpr==2.8.4=py37he184ba9_0
#   - defaults/linux-64::sqlite==3.31.1=h7b6447c_0
#   - defaults/linux-64::libxcb==1.15=h7f8727e_0
#   - defaults/linux-64::wheel==0.34.2=py37_0
#   - defaults/linux-64::libboost==1.73.0=h28710b8_12
#   - defaults/linux-64::libdeflate==1.8=h7f8727e_5
#   - defaults/linux-64::freetype==2.12.1=h4a9f257_0
#   - defaults/linux-64::six==1.14.0=py37_0
#   - defaults/linux-64::conda==23.1.0=py37h06a4308_0
#   - defaults/linux-64::cairo==1.16.0=hb05425b_3
#   - defaults/linux-64::importlib-metadata==4.11.3=py37h06a4308_0
#   - defaults/linux-64::pycparser==2.19=py37_0
#   - defaults/linux-64::requests==2.22.0=py37_1
#   - defaults/linux-64::libwebp==1.2.4=h11a3e52_0
#   - defaults/linux-64::pyopenssl==19.1.0=py37_0
#   - defaults/linux-64::urllib3==1.25.8=py37_0
#   - defaults/linux-64::lerc==3.0=h295c915_0
#   - defaults/linux-64::chardet==3.0.4=py37_1003
#   - defaults/linux-64::idna==2.8=py37_0
#   - rdkit/linux-64::rdkit==2020.09.1.0=py37hd50e099_1
#   - defaults/linux-64::bzip2==1.0.8=h7b6447c_0
#   - defaults/linux-64::ruamel.yaml==0.17.21=py37h5eee18b_0
#   - defaults/linux-64::pluggy==1.0.0=py37h06a4308_1
#   - defaults/linux-64::pip==20.0.2=py37_1
#   - defaults/linux-64::ncurses==6.2=he6710b0_0
#   - defaults/linux-64::openssl==1.1.1s=h7f8727e_0
#   - defaults/linux-64::readline==7.0=h7b6447c_5
#   - defaults/linux-64::fontconfig==2.14.1=h52c9d5c_1
#   - defaults/linux-64::libuuid==1.41.5=h5eee18b_0
#   - defaults/linux-64::ruamel.yaml.clib==0.2.6=py37h5eee18b_1
#   - defaults/linux-64::zlib==1.2.13=h5eee18b_0
#   - defaults/linux-64::tk==8.6.8=hbc83047_0
#   - defaults/linux-64::pycosat==0.6.3=py37h7b6447c_0
#   - defaults/linux-64::asn1crypto==1.3.0=py37_0
#   - defaults/linux-64::xz==5.2.10=h5eee18b_1
#   - defaults/linux-64::python==3.7.6=h0371630_2
#   - defaults/linux-64::libpng==1.6.37=hbc83047_0
#   - defaults/linux-64::icu==58.2=he6710b0_3
#   - defaults/noarch::tqdm==4.42.1=py_0
#   - defaults/linux-64::lz4-c==1.9.4=h6a678d5_0
#   - defaults/linux-64::pixman==0.40.0=h7f8727e_1
#   - defaults/linux-64::glib==2.69.1=he621ea3_2
#   - defaults/linux-64::bottleneck==1.3.5=py37h7deecbd_0
#   - defaults/linux-64::libgcc-ng==11.2.0=h1234567_1
#   - defaults/linux-64::expat==2.4.9=h6a678d5_0
#   - defaults/noarch::flit-core==3.6.0=pyhd3eb1b0_0
#   - defaults/linux-64::toolz==0.12.0=py37h06a4308_0
#   - defaults/linux-64::numpy-base==1.21.5=py37ha15fc14_3
#   - defaults/linux-64::libwebp-base==1.2.4=h5eee18b_0
#   - defaults/linux-64::libtiff==4.5.0=h6a678d5_1
#   - defaults/noarch::python-dateutil==2.8.2=pyhd3eb1b0_0
#   - defaults/linux-64::py-boost==1.73.0=py37h51133e4_12
#   - defaults/linux-64::mkl_fft==1.3.1=py37hd3c417c_0
#   - defaults/linux-64::pillow==9.3.0=py37hace64e9_1
#   - defaults/linux-64::jpeg==9e=h7f8727e_0
#   - defaults/linux-64::yaml==0.1.7=had09818_2
#   - defaults/linux-64::zipp==3.11.0=py37h06a4308_0
#   - defaults/linux-64::pytz==2022.7=py37h06a4308_0
#   - defaults/noarch::importlib_metadata==4.11.3=hd3eb1b0_0
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - asn1crypto==1.3.0=py37_0
#     - ca-certificates==2020.1.1=0
#     - certifi==2019.11.28=py37_0
#     - cffi==1.14.0=py37h2e261b9_0
#     - chardet==3.0.4=py37_1003
#     - conda-package-handling==1.6.0=py37h7b6447c_0
#     - conda==4.8.2=py37_0
#     - cryptography==2.8=py37h1ba5d50_0
#     - idna==2.8=py37_0
#     - ld_impl_linux-64==2.33.1=h53a641e_7
#     - libedit==3.1.20181209=hc058e9b_0
#     - libffi==3.2.1=hd88cf55_4
#     - libgcc-ng==9.1.0=hdf63c60_0
#     - libstdcxx-ng==9.1.0=hdf63c60_0
#     - ncurses==6.2=he6710b0_0
#     - openssl==1.1.1d=h7b6447c_4
#     - pip==20.0.2=py37_1
#     - pycosat==0.6.3=py37h7b6447c_0
#     - pycparser==2.19=py37_0
#     - pyopenssl==19.1.0=py37_0
#     - pysocks==1.7.1=py37_0
#     - python==3.7.6=h0371630_2
#     - readline==7.0=h7b6447c_5
#     - requests==2.22.0=py37_1
#     - ruamel_yaml==0.15.87=py37h7b6447c_0
#     - setuptools==45.2.0=py37_0
#     - six==1.14.0=py37_0
#     - sqlite==3.31.1=h7b6447c_0
#     - tk==8.6.8=hbc83047_0
#     - tqdm==4.42.1=py_0
#     - urllib3==1.25.8=py37_0
#     - wheel==0.34.2=py37_0
#     - xz==5.2.4=h14c3975_4
#     - yaml==0.1.7=had09818_2
#     - zlib==1.2.11=h7b6447c_3
#
#
# The following packages will be DOWNGRADED:
#
#   ca-certificates                     2023.01.10-h06a4308_0 --> 2020.1.1-0
#
#
# done
# done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local
# KeyError('pkgs_dirs')
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/site-packages/conda/exceptions.py", line 1124, in __call__
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.7/site-packages/conda/cli/main.py", line 57, in main_subshell
#     p = generate_parser()
#   File "/usr/local/lib/python3.7/site-packages/conda/cli/conda_argparse.py", line 41, in generate_parser
#     description='conda is a tool for managing and deploying applications,'
#   File "/usr/local/lib/python3.7/site-packages/conda/cli/conda_argparse.py", line 117, in __init__
#     self._subcommands = context.plugin_manager.get_hook_results("subcommands")
#   File "/usr/local/lib/python3.7/site-packages/conda/base/context.py", line 422, in plugin_manager
#     from ..plugins.manager import get_plugin_manager
#   File "/usr/local/lib/python3.7/site-packages/conda/plugins/manager.py", line 9, in <module>
#     from . import solvers, virtual_packages
#   File "/usr/local/lib/python3.7/site-packages/conda/plugins/virtual_packages/__init__.py", line 5, in <module>
#     from . import archspec, cuda, linux, osx, windows
#   File "/usr/local/lib/python3.7/site-packages/conda/plugins/virtual_packages/cuda.py", line 3, in <module>
#     import ctypes
#   File "/usr/local/lib/python3.7/ctypes/__init__.py", line 7, in <module>
#     from _ctypes import Union, Structure, Array
# ImportError: libffi.so.6: cannot open shared object file: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/site-packages/conda/exceptions.py", line 1244, in print_unexpected_error_report
#     message_builder.append(get_main_info_str(error_report['conda_info']))
#   File "/usr/local/lib/python3.7/site-packages/conda/cli/main_info.py", line 236, in get_main_info_str
#     info_dict['_' + key] = ('\n' + 26 * ' ').join(info_dict[key])
# KeyError: 'pkgs_dirs'
#
# # >>>>>>>>>>>>>>>>>>>>>> ERROR REPORT <<<<<<<<<<<<<<<<<<<<<<
#
#     Traceback (most recent call last):
#       File "/usr/local/lib/python3.7/site-packages/conda/exceptions.py", line 1124, in __call__
#         return func(*args, **kwargs)
#       File "/usr/local/lib/python3.7/site-packages/conda/cli/main.py", line 57, in main_subshell
#         p = generate_parser()
#       File "/usr/local/lib/python3.7/site-packages/conda/cli/conda_argparse.py", line 41, in generate_parser
#         description='conda is a tool for managing and deploying applications,'
#       File "/usr/local/lib/python3.7/site-packages/conda/cli/conda_argparse.py", line 117, in __init__
#         self._subcommands = context.plugin_manager.get_hook_results("subcommands")
#       File "/usr/local/lib/python3.7/site-packages/conda/base/context.py", line 422, in plugin_manager
#         from ..plugins.manager import get_plugin_manager
#       File "/usr/local/lib/python3.7/site-packages/conda/plugins/manager.py", line 9, in <module>
#         from . import solvers, virtual_packages
#       File "/usr/local/lib/python3.7/site-packages/conda/plugins/virtual_packages/__init__.py", line 5, in <module>
#         from . import archspec, cuda, linux, osx, windows
#       File "/usr/local/lib/python3.7/site-packages/conda/plugins/virtual_packages/cuda.py", line 3, in <module>
#         import ctypes
#       File "/usr/local/lib/python3.7/ctypes/__init__.py", line 7, in <module>
#         from _ctypes import Union, Structure, Array
#     ImportError: libffi.so.6: cannot open shared object file: No such file or directory
#
# `$ /usr/local/bin/conda install -c rdkit rdkit -y`
#
#   environment variables:
# conda info could not be constructed.
# KeyError('pkgs_dirs')
#
# An unexpected error has occurred. Conda has prepared the above report.
#
# If submitted, this report will be used by core maintainers to improve
# future releases of conda.
# Would you like conda to send this report to the core maintainers? [y/N]:
# Timeout reached. No report sent.

# %% [markdown]
# # Lipniski's Rule of 5

# %%
import numpy as np
from rdkit import Chem
from rdkit.Chem import Descriptors, Lipinski
import pandas as pd

# %% [markdown]
# Molecular Descriptors calculation

# %%
def lipinski(smiles, verbose=False):

    moldata= []
    for elem in smiles:
        mol=Chem.MolFromSmiles(elem) 
        moldata.append(mol)
       
    baseData= np.arange(1,1)
    i=0  
    for mol in moldata:        
       
        desc_MolWt = Descriptors.MolWt(mol)
        desc_MolLogP = Descriptors.MolLogP(mol)
        desc_NumHDonors = Lipinski.NumHDonors(mol)
        desc_NumHAcceptors = Lipinski.NumHAcceptors(mol)
           
        row = np.array([desc_MolWt,
                        desc_MolLogP,
                        desc_NumHDonors,
                        desc_NumHAcceptors])   
    
        if(i==0):
            baseData=row
        else:
            baseData=np.vstack([baseData, row])
        i=i+1      
    
    columnNames=["MW","LogP","NumHDonors","NumHAcceptors"]   
    descriptors = pd.DataFrame(data=baseData,columns=columnNames)
    
    return descriptors

# %%
df_lipinski = lipinski(df3.canonical_smiles)

# %%
df_final2 = df_final.reset_index()
df_final2
# Out:
#      index activity_comment  activity_id  \
# 0       54             None       401275
# 1       55             None       407948
# 2       59             None       425352
# 3       60             None       427861
# 4       70             None       633170
# ..     ...              ...          ...
# 738     50             None     18670702
# 739     52             None      5185188
# 740     85             None     22958819
# 741     89             None        87558
# 742     91             None     13932236
#
#                                    activity_properties assay_chembl_id  \
# 0                                                   []    CHEMBL802977
# 1                                                   []    CHEMBL802977
# 2                                                   []    CHEMBL802977
# 3                                                   []    CHEMBL802977
# 4                                                   []    CHEMBL873999
# ..                                                 ...             ...
# 738                                                 []   CHEMBL4234600
# 739                                                 []   CHEMBL1664575
# 740  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4768317
# 741                                                 []    CHEMBL808323
# 742                                                 []   CHEMBL3124118
#
#                                      assay_description assay_type  \
# 0    Inhibitory activity against sialidase of influ...          F
# 1    Inhibitory activity against sialidase of influ...          F
# 2    Inhibitory activity against sialidase of influ...          F
# 3    Inhibitory activity against sialidase of influ...          F
# 4    Antiviral activity against Influenza virus (A/...          F
# ..                                                 ...        ...
# 738  Antiviral activity against Influenza A virus (...          F
# 739  Antiviral activity against influenza A (A/Nort...          F
# 740  Antiviral activity against Influenza A virus (...          F
# 741  The compound was tested in vitro for the inhib...          F
# 742  Antiviral activity against Influenza A virus H3N2          F
#
#     assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0                      None                   None  BAO_0000190  ...
# 1                      None                   None  BAO_0000190  ...
# 2                      None                   None  BAO_0000190  ...
# 3                      None                   None  BAO_0000190  ...
# 4                      None                   None  BAO_0000190  ...
# ..                      ...                    ...          ...  ...
# 738                    None                   None  BAO_0000190  ...
# 739                    None                   None  BAO_0000190  ...
# 740                    None                   None  BAO_0000190  ...
# 741                    None                   None  BAO_0000190  ...
# 742                    None                   None  BAO_0000190  ...
#
#       target_pref_name target_tax_id text_value  toid  type units    uo_units  \
# 0    Influenza A virus         11320       None  None  IC50    uM  UO_0000065
# 1    Influenza A virus         11320       None  None  IC50    uM  UO_0000065
# 2    Influenza A virus         11320       None  None  IC50    uM  UO_0000065
# 3    Influenza A virus         11320       None  None  IC50    uM  UO_0000065
# 4    Influenza A virus         11320       None  None  IC50    uM  UO_0000065
# ..                 ...           ...        ...   ...   ...   ...         ...
# 738  Influenza A virus         11320       None  None  IC50    uM  UO_0000065
# 739  Influenza A virus         11320       None  None  IC50    nM  UO_0000065
# 740  Influenza A virus         11320       None  None  IC50    uM  UO_0000065
# 741  Influenza A virus         11320       None  None  IC50    mM  UO_0000065
# 742  Influenza A virus         11320       None  None  IC50    nM  UO_0000065
#
#      upper_value      value Activity
# 0           None       2.00      Yes
# 1           None      39.00      Yes
# 2           None     770.00      Yes
# 3           None       3.00      Yes
# 4           None  100000.00       No
# ..           ...        ...      ...
# 738         None   74300.00       No
# 739         None       0.92      Yes
# 740         None   10000.00      Yes
# 741         None   10000.00      Yes
# 742         None       0.80      Yes
#
# [743 rows x 47 columns]

# %%
df_lipinski
# Out:
#           MW     LogP  NumHDonors  NumHAcceptors
# 0    298.339  0.19100         3.0            5.0
# 1    300.355 -0.01720         4.0            5.0
# 2    286.328  0.34840         3.0            5.0
# 3    299.327 -0.94590         3.0            5.0
# 4    309.301 -0.01070         3.0            8.0
# ..       ...      ...         ...            ...
# 738  224.300  3.16672         1.0            3.0
# 739  346.340 -2.92173         7.0            7.0
# 740  388.464  2.27820         3.0            4.0
# 741  236.231  0.64857         5.0            3.0
# 742  326.397  0.33127         5.0            4.0
#
# [743 rows x 4 columns]

# %%
df_combined = pd.concat([df_final2,df_lipinski], axis=1)

# %%
df_combined
# Out:
#      index activity_comment  activity_id  \
# 0       54             None       401275
# 1       55             None       407948
# 2       59             None       425352
# 3       60             None       427861
# 4       70             None       633170
# ..     ...              ...          ...
# 738     50             None     18670702
# 739     52             None      5185188
# 740     85             None     22958819
# 741     89             None        87558
# 742     91             None     13932236
#
#                                    activity_properties assay_chembl_id  \
# 0                                                   []    CHEMBL802977
# 1                                                   []    CHEMBL802977
# 2                                                   []    CHEMBL802977
# 3                                                   []    CHEMBL802977
# 4                                                   []    CHEMBL873999
# ..                                                 ...             ...
# 738                                                 []   CHEMBL4234600
# 739                                                 []   CHEMBL1664575
# 740  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4768317
# 741                                                 []    CHEMBL808323
# 742                                                 []   CHEMBL3124118
#
#                                      assay_description assay_type  \
# 0    Inhibitory activity against sialidase of influ...          F
# 1    Inhibitory activity against sialidase of influ...          F
# 2    Inhibitory activity against sialidase of influ...          F
# 3    Inhibitory activity against sialidase of influ...          F
# 4    Antiviral activity against Influenza virus (A/...          F
# ..                                                 ...        ...
# 738  Antiviral activity against Influenza A virus (...          F
# 739  Antiviral activity against influenza A (A/Nort...          F
# 740  Antiviral activity against Influenza A virus (...          F
# 741  The compound was tested in vitro for the inhib...          F
# 742  Antiviral activity against Influenza A virus H3N2          F
#
#     assay_variant_accession assay_variant_mutation bao_endpoint  ...  type  \
# 0                      None                   None  BAO_0000190  ...  IC50
# 1                      None                   None  BAO_0000190  ...  IC50
# 2                      None                   None  BAO_0000190  ...  IC50
# 3                      None                   None  BAO_0000190  ...  IC50
# 4                      None                   None  BAO_0000190  ...  IC50
# ..                      ...                    ...          ...  ...   ...
# 738                    None                   None  BAO_0000190  ...  IC50
# 739                    None                   None  BAO_0000190  ...  IC50
# 740                    None                   None  BAO_0000190  ...  IC50
# 741                    None                   None  BAO_0000190  ...  IC50
# 742                    None                   None  BAO_0000190  ...  IC50
#
#     units    uo_units upper_value      value Activity       MW     LogP  \
# 0      uM  UO_0000065        None       2.00      Yes  298.339  0.19100
# 1      uM  UO_0000065        None      39.00      Yes  300.355 -0.01720
# 2      uM  UO_0000065        None     770.00      Yes  286.328  0.34840
# 3      uM  UO_0000065        None       3.00      Yes  299.327 -0.94590
# 4      uM  UO_0000065        None  100000.00       No  309.301 -0.01070
# ..    ...         ...         ...        ...      ...      ...      ...
# 738    uM  UO_0000065        None   74300.00       No  224.300  3.16672
# 739    nM  UO_0000065        None       0.92      Yes  346.340 -2.92173
# 740    uM  UO_0000065        None   10000.00      Yes  388.464  2.27820
# 741    mM  UO_0000065        None   10000.00      Yes  236.231  0.64857
# 742    nM  UO_0000065        None       0.80      Yes  326.397  0.33127
#
#     NumHDonors NumHAcceptors
# 0          3.0           5.0
# 1          4.0           5.0
# 2          3.0           5.0
# 3          3.0           5.0
# 4          3.0           8.0
# ..         ...           ...
# 738        1.0           3.0
# 739        7.0           7.0
# 740        3.0           4.0
# 741        5.0           3.0
# 742        5.0           4.0
#
# [743 rows x 51 columns]

# %%
df_combined.to_csv('Mtb_IC50_nm_MolDes.csv', sep=',' ,index=False)
