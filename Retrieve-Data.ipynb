# %% [markdown]
# <a href="https://colab.research.google.com/github/Jahan08/Amber-tutorial/blob/main/Retrieve-Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install chembl_webresource_client
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.8-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 KB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: easydict in /usr/local/lib/python3.8/dist-packages (from chembl_webresource_client) (1.10)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.8/dist-packages (from chembl_webresource_client) (1.24.3)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.8/dist-packages (from chembl_webresource_client) (2.25.1)
# Collecting requests-cache~=0.7.0
#   Downloading requests_cache-0.7.5-py3-none-any.whl (39 kB)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.18.4->chembl_webresource_client) (4.0.0)
# Collecting itsdangerous>=2.0.1
#   Downloading itsdangerous-2.1.2-py3-none-any.whl (15 kB)
# Requirement already satisfied: pyyaml>=5.4 in /usr/local/lib/python3.8/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (6.0)
# Collecting url-normalize<2.0,>=1.4
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Collecting attrs<22.0,>=21.2
#   Downloading attrs-21.4.0-py2.py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 KB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from url-normalize<2.0,>=1.4->requests-cache~=0.7.0->chembl_webresource_client) (1.15.0)
# Installing collected packages: url-normalize, itsdangerous, attrs, requests-cache, chembl_webresource_client
#   Attempting uninstall: itsdangerous
#     Found existing installation: itsdangerous 1.1.0
#     Uninstalling itsdangerous-1.1.0:
#       Successfully uninstalled itsdangerous-1.1.0
#   Attempting uninstall: attrs
#     Found existing installation: attrs 22.2.0
#     Uninstalling attrs-22.2.0:
#       Successfully uninstalled attrs-22.2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# flask 1.1.4 requires itsdangerous<2.0,>=0.24, but you have itsdangerous 2.1.2 which is incompatible.
# Successfully installed attrs-21.4.0 chembl_webresource_client-0.10.8 itsdangerous-2.1.2 requests-cache-0.7.5 url-normalize-1.4.3

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %%
target = new_client.target
target_query = target.search('DU-145')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                      cross_references      organism  \
# 0                                                  []  Homo sapiens
# 1   [{'xref_id': 'SF3B2', 'xref_name': None, 'xref...  Homo sapiens
# 2                                                  []          None
# 3   [{'xref_id': 'APOBEC3A', 'xref_name': None, 'x...  Homo sapiens
# 4                                                  []  Homo sapiens
# 5                                                  []  Homo sapiens
# 6                                                  []  Homo sapiens
# 7                                                  []  Homo sapiens
# 8   [{'xref_id': 'INPP5D', 'xref_name': None, 'xre...  Homo sapiens
# 9   [{'xref_id': 'Q969V1', 'xref_name': None, 'xre...  Homo sapiens
# 10  [{'xref_id': 'APOBEC3F', 'xref_name': None, 'x...  Homo sapiens
# 11                                                 []  Homo sapiens
# 12                                                 []          None
# 13                                                 []  Homo sapiens
# 14                                                 []  Homo sapiens
#
#                                             pref_name  score  \
# 0                                              DU-145   31.0
# 1                        Splicing factor 3B subunit 2   19.0
# 2                                              PD-145   17.0
# 3        Probable DNA dC->dU-editing enzyme APOBEC-3A   16.0
# 4                 DNA dC->dU-editing enzyme APOBEC-3F   14.0
# 5                                             DU-4475   14.0
# 6   Histone deacetylase complex subunit SAP130/Spl...   14.0
# 7                 DNA dC->dU-editing enzyme APOBEC-3B   14.0
# 8   Phosphatidylinositol-3,4,5-trisphosphate 5-pho...   13.0
# 9            Melanin-concentrating hormone receptor 2   12.0
# 10                DNA dC->dU-editing enzyme APOBEC-3G   12.0
# 11   Zinc finger and BTB domain-containing protein 16   12.0
# 12                         Poly(dA-dU)oligonucleotide   11.0
# 13             Melanin-concentrating hormone receptor    8.0
# 14      Melanin-concentrating hormone receptor 2/HERG    6.0
#
#     species_group_flag target_chembl_id  \
# 0                False     CHEMBL613508
# 1                False    CHEMBL1229011
# 2                False     CHEMBL614845
# 3                False    CHEMBL1741179
# 4                False    CHEMBL2007626
# 5                False    CHEMBL2366246
# 6                False    CHEMBL3885592
# 7                False    CHEMBL4523487
# 8                False    CHEMBL1781870
# 9                False       CHEMBL5038
# 10               False    CHEMBL1741217
# 11               False    CHEMBL4105726
# 12               False    CHEMBL4483922
# 13               False    CHEMBL2111437
# 14               False    CHEMBL4106188
#
#                                     target_components        target_type  \
# 0                                                  []          CELL-LINE
# 1   [{'accession': 'Q13435', 'component_descriptio...     SINGLE PROTEIN
# 2                                                  []          CELL-LINE
# 3   [{'accession': 'P31941', 'component_descriptio...     SINGLE PROTEIN
# 4   [{'accession': 'Q8IUX4', 'component_descriptio...     SINGLE PROTEIN
# 5                                                  []          CELL-LINE
# 6   [{'accession': 'Q13435', 'component_descriptio...    PROTEIN COMPLEX
# 7   [{'accession': 'Q9UH17', 'component_descriptio...     SINGLE PROTEIN
# 8   [{'accession': 'Q92835', 'component_descriptio...     SINGLE PROTEIN
# 9   [{'accession': 'Q969V1', 'component_descriptio...     SINGLE PROTEIN
# 10  [{'accession': 'Q9HC16', 'component_descriptio...     SINGLE PROTEIN
# 11  [{'accession': 'Q05516', 'component_descriptio...     SINGLE PROTEIN
# 12                                                 []       NUCLEIC-ACID
# 13  [{'accession': 'Q969V1', 'component_descriptio...     PROTEIN FAMILY
# 14  [{'accession': 'Q12809', 'component_descriptio...  SELECTIVITY GROUP
#
#     tax_id
# 0   9606.0
# 1   9606.0
# 2      NaN
# 3   9606.0
# 4   9606.0
# 5   9606.0
# 6   9606.0
# 7   9606.0
# 8   9606.0
# 9   9606.0
# 10  9606.0
# 11  9606.0
# 12     NaN
# 13  9606.0
# 14  9606.0

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL613508'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)
df
# Out:
#      activity_comment  activity_id  \
# 0                None       117200
# 1      Not calculable       118456
# 2                None       123345
# 3      Not calculable       136075
# 4                None       138488
# ...               ...          ...
# 8207             None     24422709
# 8208             None     24422710
# 8209             None     24513169
# 8210             None     24513170
# 8211             None     24513171
#
#                                     activity_properties assay_chembl_id  \
# 0                                                    []    CHEMBL667652
# 1                                                    []    CHEMBL668502
# 2                                                    []    CHEMBL667652
# 3                                                    []    CHEMBL668502
# 4                                                    []    CHEMBL667652
# ...                                                 ...             ...
# 8207  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5049248
# 8208  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5049248
# 8209  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5056340
# 8210  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5056340
# 8211  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5056340
#
#                                       assay_description assay_type  \
# 0     In vitro cytotoxic activity against prostate c...          F
# 1     In vitro cytotoxic activity against prostate c...          F
# 2     In vitro cytotoxic activity against prostate c...          F
# 3     In vitro cytotoxic activity against prostate c...          F
# 4     In vitro cytotoxic activity against prostate c...          F
# ...                                                 ...        ...
# 8207  Antiproliferative activity against human DU145...          F
# 8208  Antiproliferative activity against human DU145...          F
# 8209  Antitumor activity against human DU-145 cells ...          F
# 8210  Antitumor activity against human DU-145 cells ...          F
# 8211  Antitumor activity against human DU-145 cells ...          F
#
#      assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                       None                   None  BAO_0000190  BAO_0000219
# 1                       None                   None  BAO_0000190  BAO_0000219
# 2                       None                   None  BAO_0000190  BAO_0000219
# 3                       None                   None  BAO_0000190  BAO_0000219
# 4                       None                   None  BAO_0000190  BAO_0000219
# ...                      ...                    ...          ...          ...
# 8207                    None                   None  BAO_0000190  BAO_0000219
# 8208                    None                   None  BAO_0000190  BAO_0000219
# 8209                    None                   None  BAO_0000190  BAO_0000219
# 8210                    None                   None  BAO_0000190  BAO_0000219
# 8211                    None                   None  BAO_0000190  BAO_0000219
#
#       ... target_organism target_pref_name target_tax_id text_value  toid  \
# 0     ...    Homo sapiens           DU-145          9606       None  None
# 1     ...    Homo sapiens           DU-145          9606       None  None
# 2     ...    Homo sapiens           DU-145          9606       None  None
# 3     ...    Homo sapiens           DU-145          9606       None  None
# 4     ...    Homo sapiens           DU-145          9606       None  None
# ...   ...             ...              ...           ...        ...   ...
# 8207  ...    Homo sapiens           DU-145          9606       None  None
# 8208  ...    Homo sapiens           DU-145          9606       None  None
# 8209  ...    Homo sapiens           DU-145          9606       None  None
# 8210  ...    Homo sapiens           DU-145          9606       None  None
# 8211  ...    Homo sapiens           DU-145          9606       None  None
#
#       type  units    uo_units upper_value    value
# 0     IC50     uM  UO_0000065        None   0.0356
# 1     IC50     uM  UO_0000065        None     None
# 2     IC50     uM  UO_0000065        None   19.855
# 3     IC50     uM  UO_0000065        None     None
# 4     IC50     uM  UO_0000065        None  0.00112
# ...    ...    ...         ...         ...      ...
# 8207  IC50     uM  UO_0000065        None    200.0
# 8208  IC50     uM  UO_0000065        None    200.0
# 8209  IC50     uM  UO_0000065        None      3.0
# 8210  IC50     uM  UO_0000065        None      3.0
# 8211  IC50     uM  UO_0000065        None     1.56
#
# [8212 rows x 45 columns]

# %%
# considering nM unit for MIC
df = df[(df['standard_units'] == 'nM')]
df = df[(df['relation'] == '=')]
len(df)
# Out:
# 6158

# %%
# considering nM unit for MIC
df = df[(df['standard_units'] == '%')]
df = df[(df['relation'] == '=')]
len(df)

# %%
fix = []

for i in df.standard_value:
    fix.append(float(i))

STATUS = []

for i in fix:
    if i < 1000:
        STATUS.append("Yes") #active
        
    elif 10000 <= i <= 10000:
        STATUS.append("No") #inactive
        
    else:
        STATUS.append("IN") #intermediate     

df = df.drop('value', 1)
df['value'] = fix
df['Activity'] = STATUS
df.head(3)
# Out:
# <ipython-input-51-38befbaf8c31>:18: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df = df.drop('value', 1)
#   activity_comment  activity_id activity_properties assay_chembl_id  \
# 0             None       117200                  []    CHEMBL667652
# 2             None       123345                  []    CHEMBL667652
# 4             None       138488                  []    CHEMBL667652
#
#                                    assay_description assay_type  \
# 0  In vitro cytotoxic activity against prostate c...          F
# 2  In vitro cytotoxic activity against prostate c...          F
# 4  In vitro cytotoxic activity against prostate c...          F
#
#   assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                    None                   None  BAO_0000190  BAO_0000219
# 2                    None                   None  BAO_0000190  BAO_0000219
# 4                    None                   None  BAO_0000190  BAO_0000219
#
#    ... target_pref_name target_tax_id text_value  toid  type units  \
# 0  ...           DU-145          9606       None  None  IC50    uM
# 2  ...           DU-145          9606       None  None  IC50    uM
# 4  ...           DU-145          9606       None  None  IC50    uM
#
#      uo_units upper_value     value Activity
# 0  UO_0000065        None     35.60      Yes
# 2  UO_0000065        None  19855.00       IN
# 4  UO_0000065        None      1.12      Yes
#
# [3 rows x 46 columns]

# %%
fix = []

for i in df.standard_value:
    fix.append(float(i))

STATUS = []

for i in fix:
    if i > 80:
        STATUS.append("Yes") #active
        
    elif i == 0:
        STATUS.append("No") #inactive
        
    else:
        STATUS.append("IN") #intermediate     

df = df.drop('value', 1)
df['value'] = fix
df['Activity'] = STATUS
df.head(3)

# %%
# considering nM unit for MIC
df = df[(df['Activity'] != 'IN')]
len(df)
# Out:
# 1192

# %%
df.to_csv('bioactivity_data_DU-145_IC50_nM.csv', index=False)
