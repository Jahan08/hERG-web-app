# %% [markdown]
# <a href="https://colab.research.google.com/github/Jahan08/Amber-tutorial/blob/main/Retrieve-Data-prostate-cancer-data_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install chembl_webresource_client
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 KB 6.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 KB 6.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: attrs
#     Found existing installation: attrs 22.2.0
#     Uninstalling attrs-22.2.0:
#       Successfully uninstalled attrs-22.2.0
# ...

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %%
target = new_client.target
target_query = target.search('PPC-1')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                        cross_references  \
# 0                                                    []
# 1                                                    []
# 2     [{'xref_id': 'P30411', 'xref_name': None, 'xre...
# 3     [{'xref_id': 'P13497', 'xref_name': None, 'xre...
# 4     [{'xref_id': 'P25023', 'xref_name': None, 'xre...
# ...                                                 ...
# 3765                                                 []
# 3766                                                 []
# 3767                                                 []
# 3768                                                 []
# 3769                                                 []
#
#                                                organism  \
# 0                                          Homo sapiens
# 1     Mycobacterium tuberculosis (strain ATCC 25618 ...
# 2                                          Homo sapiens
# 3                                          Homo sapiens
# ...

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL1626502'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)
df
# Out:
#     activity_comment  activity_id activity_properties assay_chembl_id  \
# 0               None      1500952                  []    CHEMBL825133
# 1               None      1500964                  []    CHEMBL825133
# 2               None      1501075                  []    CHEMBL825133
# 3               None      1501084                  []    CHEMBL825133
# 4               None      1501090                  []    CHEMBL825133
# ..               ...          ...                 ...             ...
# 278             None     12656486                  []   CHEMBL2330841
# 279             None     12656487                  []   CHEMBL2330841
# 280             None     12656488                  []   CHEMBL2330841
# 281             None     12656489                  []   CHEMBL2330841
# 282             None     12656490                  []   CHEMBL2330841
#
#                                      assay_description assay_type  \
# ...

# %%
# considering nM unit for MIC
df = df[(df['standard_units'] == 'nM')]
df = df[(df['relation'] == '=')]
len(df)
# Out:
# 192

# %%
df = df[df.canonical_smiles.notna()]
df = df[df.standard_value.notna()]

# %%
# considering nM unit for MIC
df = df[(df['standard_units'] == '%')]
df = df[(df['relation'] == '=')]
len(df)

# %%
df = pd.read_csv('/content/bioactivity_data_CWR22R_IC50_nM.csv', header = 0)

# %%
fix = []

for i in df.standard_value:
    fix.append(float(i))

STATUS = []

for i in fix:
    if i < 1000:
        STATUS.append("Yes") #active
        
    elif 30000 <= i <= 100000:
        STATUS.append("No") #inactive
        
    else:
        STATUS.append("IN") #intermediate     

df = df.drop('standard_value', 1)
df['standard_value'] = fix
df['Activity'] = STATUS
df.head(3)
# Out:
# <ipython-input-84-fe79c51760bc>:18: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df = df.drop('standard_value', 1)
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL860886  Cytotoxicity against human CWR22R cell line by...
# 1    CHEMBL860886  Cytotoxicity against human CWR22R cell line by...
# 2   CHEMBL1110243  Cytotoxicity against human 22Rv1 cells after 4...
#
#                                     canonical_smiles document_journal  \
# 0       Nc1ccccc1C(=O)NC(=O)Nc1ccc(Sc2ncc(Br)cn2)cc1       J Med Chem
# 1  O=C(NC(=O)c1ccccc1[N+](=O)[O-])Nc1ccc(Sc2ncc(B...       J Med Chem
# 2                      CNC1=CC(=O)c2c(cnc(C)c2C)C1=O       J Nat Prod
#
#   molecule_chembl_id  IC50_uM Activity  standard_value
# 0       CHEMBL203996     0.50      Yes           500.0
# 1       CHEMBL205487     0.05      Yes            50.0
# ...

# %%
fix = []

for i in df.standard_value:
    fix.append(float(i))

STATUS = []

for i in fix:
    if i > 80:
        STATUS.append("Yes") #active
        
    elif i == 0:
        STATUS.append("No") #inactive
        
    else:
        STATUS.append("IN") #intermediate     

df = df.drop('value', 1)
df['value'] = fix
df['Activity'] = STATUS
df.head(3)

# %%
# considering nM unit for MIC
df = df[(df['Activity'] != 'IN')]
len(df)
# Out:
# 229

# %%
df.to_csv('/content/bioactivity_data_CWR22R_IC50_30_100.csv', index=False)
